# %% [markdown]
# # Average Body Weight Prediction
#
# ### Business Understanding
#
# The Average Body Weight (ABW) prediction task involves leveraging a comprehensive dataset from shrimp aquaculture to predict the average weight of shrimp in grams. The ABW is a critical metric in shrimp farming, representing the average weight of sampled shrimp during harvesting. It provides valuable insights into the growth and health of shrimp populations in aquaculture ponds. By accurately predicting ABW, shrimp farmers and aquaculture professionals can optimize feeding strategies, monitor growth patterns, and assess the overall performance of their farming operations.
#
# ### Problem Statement
#
# Given the Shrimp Aquaculture dataset, our objective is to develop a machine learning regression model capable of accurately predicting the Average Body Weight (ABW) of shrimp in grams. The model will utilize various features such as environmental factors, feeding regimes, and cultivation duration to make predictions. The primary evaluation metric for the model will be the Mean Absolute Error (MAE), which measures the average absolute difference between predicted and actual ABW values.
#
# ### Business Objective
#
# The primary business objective is to create a reliable predictive model for estimating the Average Body Weight (ABW) of shrimp in aquaculture ponds. This model will enable stakeholders to:
#
# 1. Optimize feeding practices and nutrition management to achieve target ABW.
# 2. Monitor shrimp growth patterns and detect deviations from expected weight.
# 3. Improve decision-making regarding harvesting schedules and market readiness.
#
# ### Business Metrics
#
# To assess the effectiveness of our predictive model and its impact on business objectives, we will focus on the following metrics:
#
# 1. **Prediction Accuracy**: The degree to which the predicted ABW values align with actual ABW measurements, ensuring reliable estimates for farm management decisions.
# 2. **Growth Optimization**: The improvements in shrimp growth rates and overall farm productivity resulting from optimized feeding strategies guided by the model predictions.
# 3. **Operational Efficiency**: The streamlining of harvesting schedules and resource allocation based on accurate ABW predictions, leading to cost savings and enhanced operational efficiency.
#
# ### Machine Learning Metrics
#
# For evaluating and fine-tuning our machine learning model, we will primarily rely on the following metric:
#
# 1. **Mean Absolute Error (MAE)**: The primary evaluation metric, MAE measures the average absolute difference between predicted and actual ABW values. A lower MAE indicates higher prediction accuracy and model performance.

# %%
# Import libraries for data preparation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Import libraries for saving and loading model and column files
import pickle
import copy

# Import train_test_split for splitting data
from sklearn.model_selection import train_test_split

# %%
# Read Data
df = pd.read_csv('Data/2_processed_data/abw_prediction_data.csv')

# %%
# Sanity Check
df
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 0         331920  4030.00          0.0                   2.00
# 1         357570  2000.00          0.0                   1.25
# 2         168275  1512.00          0.0                   1.25
# 3         188000  1225.00          0.0                   1.25
# 4         200128   803.84          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1839      226284  1400.00          0.0                   1.25
# 1840      300000  4999.90          0.0                   1.25
# 1841      100000   900.00          0.0                   1.25
# 1842       30716    86.00          0.0                   1.25
# 1843      384000  2915.00          0.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 0                      110.0         35.0        65.00       62.00
# 1                      120.0         20.0        50.00       40.00
# 2                      100.0         55.0        54.00       28.00
# 3                      100.0         55.0        35.00       35.00
# 4                      120.0         55.0        32.00       32.00
# ...                      ...          ...          ...         ...
# 1839                   120.0         55.0        40.00       35.00
# 1840                    88.0         55.0        70.71       70.71
# 1841                   120.0         55.0        45.00       20.00
# 1842                   120.0         20.0        10.71        8.03
# 1843                   100.0         40.0        55.00       53.00
#
#       pond_depth  total_harvested  ...   ammonia   nitrate   nitrite  \
# 0            1.0      144046.5000  ...  0.000000  0.000000  0.000000
# 1            1.4       67723.8624  ...  0.000000  0.011111  0.008200
# 2            1.5       14703.4126  ...  0.005370  0.000000  0.030822
# 3            1.2       12090.0000  ...  0.006827  0.000000  0.044667
# 4            1.5       37227.3584  ...  0.000000  0.000000  0.000000
# ...          ...              ...  ...       ...       ...       ...
# 1839         1.2       22185.0000  ...  0.000000  0.000000  0.000000
# 1840         1.5       95312.0000  ...  0.000000  0.000000  0.097528
# 1841         1.5       36120.0000  ...  0.014636  0.000000  0.004145
# 1842         1.0       11200.0000  ...  0.000000  0.125000  0.000208
# 1843         1.7      256942.3500  ...  0.000000  0.000000  0.000000
#
#       alkalinity    hardness     calcium   magnesium  carbonate  bicarbonate  \
# 0       0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 1      17.044444  680.555556  119.855556  575.700000   0.000000    15.777778
# 2      17.671233  126.602740   50.753425  140.136986   0.821918    16.849315
# 3       9.813333  176.000000   29.333333  146.666667   0.160000     9.733333
# 4       0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# ...          ...         ...         ...         ...        ...          ...
# 1839   13.072165    0.000000    0.000000    0.000000   0.000000     6.845361
# 1840   23.820225    0.000000    0.000000    0.000000   0.000000     0.000000
# 1841   22.309091  771.454545   95.890909  300.436364   0.436364    16.418182
# 1842    5.416667    0.000000    3.437500    9.479167   1.166667     9.208333
# 1843   24.000000    0.000000    0.000000    0.000000   0.857143     6.571429
#
#       transparency
# 0        45.327103
# 1        68.916667
# 2        45.205479
# 3         0.000000
# 4        41.421569
# ...            ...
# 1839     58.314433
# 1840     41.853933
# 1841      0.000000
# 1842      0.000000
# 1843      0.000000
#
# [1844 rows x 31 columns]

# %%
# Check Null Values
df.isnull().sum()
# Out:
# total_seed                0
# area                      0
# initial_age               0
# limit_weight_per_area     0
# target_cultivation_day    0
# target_size               0
# pond_length               0
# pond_width                0
# pond_depth                0
# total_harvested           0
# cycle_duration_days       0
# average_daily_gain        0
# average_body_weight       0
# feed_quantity_kg          0
# feed_conversion_ratio     0
# morning_temperature       0
# evening_temperature       0
# morning_do                0
# evening_do                0
# morning_salinity          0
# evening_salinity          0
# ammonia                   0
# nitrate                   0
# nitrite                   0
# alkalinity                0
# hardness                  0
# calcium                   0
# magnesium                 0
# carbonate                 0
# bicarbonate               0
# transparency              0
# dtype: int64

# %%
# Check Duplicated Value
df.duplicated().sum()
# Out:
# 0

# %%
# Check Data Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_seed              1844 non-null   int64
#  1   area                    1844 non-null   float64
#  2   initial_age             1844 non-null   float64
#  3   limit_weight_per_area   1844 non-null   float64
#  4   target_cultivation_day  1844 non-null   float64
#  5   target_size             1844 non-null   float64
#  6   pond_length             1844 non-null   float64
#  7   pond_width              1844 non-null   float64
#  8   pond_depth              1844 non-null   float64
#  9   total_harvested         1844 non-null   float64
#  10  cycle_duration_days     1844 non-null   int64
#  11  average_daily_gain      1844 non-null   float64
#  12  average_body_weight     1844 non-null   float64
#  13  feed_quantity_kg        1844 non-null   float64
#  14  feed_conversion_ratio   1844 non-null   float64
#  15  morning_temperature     1844 non-null   float64
#  16  evening_temperature     1844 non-null   float64
#  17  morning_do              1844 non-null   float64
#  18  evening_do              1844 non-null   float64
#  19  morning_salinity        1844 non-null   float64
#  20  evening_salinity        1844 non-null   float64
#  21  ammonia                 1844 non-null   float64
#  22  nitrate                 1844 non-null   float64
#  23  nitrite                 1844 non-null   float64
#  24  alkalinity              1844 non-null   float64
#  25  hardness                1844 non-null   float64
#  26  calcium                 1844 non-null   float64
#  27  magnesium               1844 non-null   float64
#  28  carbonate               1844 non-null   float64
#  29  bicarbonate             1844 non-null   float64
#  30  transparency            1844 non-null   float64
# dtypes: float64(29), int64(2)
# memory usage: 446.7 KB

# %% [markdown]
# ## Data Definition

# %% [markdown]
# # Average Body Weight Prediction in Shrimp Aquaculture
#
# ### Brief Narrative about the Shrimp Aquaculture Average Body Weight (ABW) Dataset:
#
# The Shrimp Aquaculture Average Body Weight (ABW) dataset is a comprehensive dataset used for regression tasks, specifically to predict the average weight of shrimp in grams in aquaculture ponds. This dataset captures various attributes related to pond characteristics, water quality, feeding practices, and other environmental factors. The primary objective of utilizing this dataset is to develop predictive models that can accurately estimate the ABW of shrimp, which is crucial for monitoring shrimp growth, optimizing feeding strategies, and ensuring the overall health and productivity of shrimp populations in aquaculture ponds.
#
# The dataset contains 1844 entries and 31 columns, with attributes such as total seed, pond dimensions, cultivation duration, feed quantity, water temperature, dissolved oxygen levels, salinity, and nutrient concentrations. The target variable, `average_body_weight`, represents the average body weight of sampled shrimp at harvest in grams. This dataset serves as a valuable resource for researchers, aquaculture professionals, and shrimp farmers to enhance production efficiency, improve farm management practices, and maximize profitability in shrimp aquaculture operations.
#
# ### Data Definitions:
#
# 1. **total_seed**: Total number of shrimp seeds stocked in the pond. Data type: `int64`.
# 2. **area**: Area of the pond in square meters. Data type: `float64`.
# 3. **initial_age**: Initial age of the shrimp seeds in days. Data type: `float64`.
# 4. **limit_weight_per_area**: Limit weight of shrimp per unit area in kg/m². Data type: `float64`.
# 5. **target_cultivation_day**: Target number of cultivation days. Data type: `float64`.
# 6. **target_size**: Target size of shrimp at harvest in grams. Data type: `float64`.
# 7. **pond_length**: Length of the pond in meters. Data type: `float64`.
# 8. **pond_width**: Width of the pond in meters. Data type: `float64`.
# 9. **pond_depth**: Depth of the pond in meters. Data type: `float64`.
# 10. **total_harvested**: Total number of shrimp harvested. Data type: `float64`.
# 11. **cycle_duration_days**: Duration of the cultivation cycle in days. Data type: `int64`.
# 12. **average_daily_gain**: Average daily weight gain of shrimp in grams. Data type: `float64`.
# 13. **average_body_weight**: Average body weight of shrimp at harvest in grams (target variable). Data type: `float64`.
# 14. **feed_quantity_kg**: Total feed quantity used during the cycle in kilograms. Data type: `float64`.
# 15. **feed_conversion_ratio**: Feed conversion ratio, a measure of the efficiency of feed usage. Data type: `float64`.
# 16. **morning_temperature**: Morning water temperature in degrees Celsius. Data type: `float64`.
# 17. **evening_temperature**: Evening water temperature in degrees Celsius. Data type: `float64`.
# 18. **morning_do**: Morning dissolved oxygen level in mg/L. Data type: `float64`.
# 19. **evening_do**: Evening dissolved oxygen level in mg/L. Data type: `float64`.
# 20. **morning_salinity**: Morning water salinity in ppt (parts per thousand). Data type: `float64`.
# 21. **evening_salinity**: Evening water salinity in ppt (parts per thousand). Data type: `float64`.
# 22. **ammonia**: Ammonia concentration in the water in mg/L. Data type: `float64`.
# 23. **nitrate**: Nitrate concentration in the water in mg/L. Data type: `float64`.
# 24. **nitrite**: Nitrite concentration in the water in mg/L. Data type: `float64`.
# 25. **alkalinity**: Water alkalinity in mg/L CaCO3. Data type: `float64`.
# 26. **hardness**: Water hardness in mg/L CaCO3. Data type: `float64`.
# 27. **calcium**: Calcium concentration in the water in mg/L. Data type: `float64`.
# 28. **magnesium**: Magnesium concentration in the water in mg/L. Data type: `float64`.
# 29. **carbonate**: Carbonate concentration in the water in mg/L. Data type: `float64`.
# 30. **bicarbonate**: Bicarbonate concentration in the water in mg/L. Data type: `float64`.
# 31. **transparency**: Water transparency in centimeters. Data type: `float64`.
#
# This dataset provides valuable insights into the factors influencing the average body weight of shrimp in aquaculture ponds, facilitating the development of predictive models for optimizing shrimp farming pratices and enhancing overall productivity.
# y factors that affect shrimp survival rates.

# %%
# Iterate through each column in the DataFrame
for column in df.columns:
    # Print the column name along with its minimum and maximum values
    print(f"{column}: min = {df[column].min()}, max = {df[column].max()}")
# Out:
# total_seed: min = 1272, max = 1800000
# area: min = 1.02, max = 249998.0
# initial_age: min = 0.0, max = 69.0
# limit_weight_per_area: min = 0.6, max = 270.0
# target_cultivation_day: min = 0.0, max = 348.0
# target_size: min = 0.0, max = 120.0
# pond_length: min = 3.0, max = 577.35
# pond_width: min = 1.5, max = 433.01
# pond_depth: min = 0.7, max = 300.0
# total_harvested: min = 0.0, max = 752840.0
# cycle_duration_days: min = 19, max = 348
# average_daily_gain: min = -0.2250000000000001, max = 2.066666666666667
# average_body_weight: min = 0.02, max = 85.0
# feed_quantity_kg: min = 3.0, max = 219525.5
# feed_conversion_ratio: min = 0.0, max = inf
# morning_temperature: min = 0.0, max = 543.305396226415
# evening_temperature: min = 0.0, max = 75.968125
# morning_do: min = -0.0665376344086021, max = 605.935925
# evening_do: min = 0.0, max = 71.40357
# morning_salinity: min = 0.0, max = 181.059320754717
# evening_salinity: min = 0.0, max = 411.6472349397591
# ammonia: min = 0.0, max = 23.11573033707865
# nitrate: min = 0.0, max = 29.58139534883721
# nitrite: min = 0.0, max = 527.8157582417583
# alkalinity: min = 0.0, max = 388.2332075471698
# hardness: min = 0.0, max = 22349.84946236559
# calcium: min = 0.0, max = 1877.7777777777776
# magnesium: min = 0.0, max = 4533.333333333333
# carbonate: min = 0.0, max = 127.5
# bicarbonate: min = 0.0, max = 373.9811320754717
# transparency: min = 0.0, max = 80.0

# %%
# Viewing descriptive statistics using describe()
df.describe()
# Out:
#          total_seed           area  initial_age  limit_weight_per_area  \
# count  1.844000e+03    1844.000000  1844.000000            1844.000000
# mean   2.312755e+05    1956.546372     0.405098               1.671838
# std    1.668845e+05    6134.900851     3.367232               7.891358
# min    1.272000e+03       1.020000     0.000000               0.600000
# 25%    1.073812e+05     900.000000     0.000000               1.250000
# 50%    2.000000e+05    1483.890000     0.000000               1.250000
# 75%    3.125000e+05    2381.030000     0.000000               1.250000
# max    1.800000e+06  249998.000000    69.000000             270.000000
#
#        target_cultivation_day  target_size  pond_length   pond_width  \
# count             1844.000000  1844.000000  1844.000000  1844.000000
# mean               114.105206    51.217462    44.179225    36.736876
# std                 17.869388    10.358045    22.467105    17.417913
# min                  0.000000     0.000000     3.000000     1.500000
# 25%                100.000000    45.000000    32.000000    27.390000
# 50%                120.000000    55.000000    43.200000    35.000000
# 75%                120.000000    55.000000    51.900000    45.000000
# max                348.000000   120.000000   577.350000   433.010000
#
#         pond_depth  total_harvested  ...      ammonia      nitrate  \
# count  1844.000000      1844.000000  ...  1844.000000  1844.000000
# mean      4.533286     64620.066566  ...     0.029872     0.294301
# std      20.914900     81335.993698  ...     0.555360     1.625180
# min       0.700000         0.000000  ...     0.000000     0.000000
# 25%       1.100000     19742.100000  ...     0.000000     0.000000
# 50%       1.300000     41672.184000  ...     0.000000     0.000000
# 75%       1.500000     72464.805000  ...     0.000000     0.000000
# max     300.000000    752840.000000  ...    23.115730    29.581395
#
#            nitrite   alkalinity      hardness      calcium    magnesium  \
# count  1844.000000  1844.000000   1844.000000  1844.000000  1844.000000
# mean      1.059649    12.145470    214.294393    31.277816   104.635494
# std      17.461910    22.315192    712.476011    86.575328   274.404552
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%       0.000000     0.000000      0.000000     0.000000     0.000000
# 50%       0.000000     4.840734      0.000000     0.000000     0.000000
# 75%       0.020152    17.297517    163.591270    41.701299   117.466685
# max     527.815758   388.233208  22349.849462  1877.777778  4533.333333
#
#          carbonate  bicarbonate  transparency
# count  1844.000000  1844.000000   1844.000000
# mean      0.679188     7.643328     21.294418
# std       4.175689    17.812209     21.731054
# min       0.000000     0.000000      0.000000
# 25%       0.000000     0.000000      0.000000
# 50%       0.000000     0.000000     17.916667
# 75%       0.134576    12.193106     40.611358
# max     127.500000   373.981132     80.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Data Splitting

# %%
# Separating the feature variables (X) and the target variable (y)
X = df.drop(columns=['feed_conversion_ratio', 'total_harvested', 'average_body_weight','average_daily_gain'])
y = df['average_body_weight']

# %%
# Split the data into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=123)

# %%
# Sanity Check
X_train
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 1373      200000  2660.00          0.0                   1.25
# 1186      325000  2500.00          0.0                   1.25
# 814        50000  1000.00          0.0                   1.25
# 1244      383358  2560.00          1.0                   1.25
# 410       400000  1500.00          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1122      436424  1962.50          0.0                   1.25
# 1346       72314   600.00          0.0                   1.25
# 1406      115000  1000.00          0.0                   1.20
# 1389       84000  1064.18          0.0                   1.25
# 1534        9820    19.62          1.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                   100.0         55.0        95.00       28.00
# 1186                   120.0         55.0        50.00       50.00
# 814                    120.0         45.0        36.51       27.39
# 1244                   120.0         55.0        50.60       50.60
# 410                    100.0         55.0        44.72       33.54
# ...                      ...          ...          ...         ...
# 1122                   120.0         50.0        50.00       50.00
# 1346                   120.0         45.0        28.28       21.21
# 1406                   110.0         30.0        37.67       28.25
# 1389                   130.0         55.0        37.67       28.25
# 1534                   100.0         55.0         5.00        5.00
#
#       pond_depth  cycle_duration_days  ...   ammonia   nitrate    nitrite  \
# 1373        1.50                   66  ...  0.002606  0.000000   0.001409
# 1186        1.20                  110  ...  0.000000  0.000000   0.469855
# 814         1.30                  109  ...  0.000000  0.000000   0.000000
# 1244        1.20                   93  ...  0.000000  0.000000   0.000000
# 410         1.50                   91  ...  0.000000  0.002895  55.283026
# ...          ...                  ...  ...       ...       ...        ...
# 1122        1.20                   85  ...  0.000000  0.000000   0.015541
# 1346        1.25                  120  ...  0.000000  0.000000   0.000000
# 1406        1.10                   87  ...  0.000000  0.000000   0.013000
# 1389        1.10                   58  ...  0.000000  0.000000   0.012754
# 1534        1.00                   67  ...  0.000000  0.000000   0.000000
#
#       alkalinity    hardness     calcium   magnesium  carbonate  bicarbonate  \
# 1373    2.909091   37.878788    9.090909   28.787879   0.363636     2.545455
# 1186   23.772727  881.818182   65.818182  165.214545   0.036364    23.736364
# 814     0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 1244    0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 410     8.671053  209.013158   64.105263  200.157895   0.815789     9.592105
# ...          ...         ...         ...         ...        ...          ...
# 1122   23.581081    0.000000   67.554054  135.810811   0.000000     0.000000
# 1346    0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 1406   25.129630  932.907407   13.555556   42.018519   1.333333     3.111111
# 1389   12.114754  409.245902  111.606557  381.360656   1.180328    10.934426
# 1534    0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency
# 1373      0.000000
# 1186     41.636364
# 814       0.000000
# 1244     44.000000
# 410      48.766447
# ...            ...
# 1122      9.162162
# 1346      0.000000
# 1406     50.092593
# 1389     49.139344
# 1534     30.955882
#
# [1475 rows x 27 columns]

# %%
# Sanity Check
X_test
# Out:
#       total_seed    area  initial_age  limit_weight_per_area  \
# 12        100000  1050.0          0.0                   2.00
# 533       123816  1600.0          0.0                   1.25
# 1227      325000  2500.0          0.0                   1.25
# 319       340200  4030.0          0.0                   2.00
# 1386      600000  1023.0          4.0                   1.25
# ...          ...     ...          ...                    ...
# 988        50000   256.0          0.0                   2.25
# 938       183464  2319.0          0.0                   1.25
# 0         331920  4030.0          0.0                   2.00
# 637       102609  1300.0          0.0                   1.25
# 798        75000   500.0          0.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 12                     120.0         45.0        35.00       30.00
# 533                    100.0         55.0        40.00       40.00
# 1227                   100.0         55.0        50.00       50.00
# 319                    111.0         35.0        65.00       62.00
# 1386                   120.0         55.0        31.00       33.00
# ...                      ...          ...          ...         ...
# 988                     99.0         45.0        16.00       16.00
# 938                    100.0         55.0        54.59       40.94
# 0                      110.0         35.0        65.00       62.00
# 637                    100.0         55.0        40.00       40.00
# 798                    120.0         55.0        25.00       20.00
#
#       pond_depth  cycle_duration_days  ...   ammonia   nitrate   nitrite  \
# 12           1.0                  108  ...  0.000000  0.000000  0.000000
# 533          1.0                   54  ...  0.006897  0.000000  0.000741
# 1227         1.2                   74  ...  0.000000  0.000000  0.004786
# 319          1.0                  111  ...  0.000000  0.000000  0.000000
# 1386         1.5                  110  ...  0.000000  0.000000  1.657895
# ...          ...                  ...  ...       ...       ...       ...
# 988          1.2                   55  ...  0.000000  0.000000  0.000000
# 938          1.2                   72  ...  0.000000  0.000000  0.010519
# 0            1.0                  107  ...  0.000000  0.000000  0.000000
# 637          1.0                   68  ...  0.018571  0.142857  0.002614
# 798          1.3                   71  ...  0.000000  0.000000  0.000000
#
#       alkalinity     hardness     calcium   magnesium  carbonate  bicarbonate  \
# 12      0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 533    19.740000    51.206897   34.293103   79.844828  27.034483    10.385690
# 1227   19.957143  1015.328571  178.400000  836.957143   1.014286    18.885714
# 319     0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 1386   13.484211     0.000000    0.000000    0.000000   0.000000     2.294737
# ...          ...          ...         ...         ...        ...          ...
# 988     0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 938    21.123457   831.481481   64.962963  186.271605   2.308642    18.790123
# 0       0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 637    23.919143    63.171429   40.821429   94.592857   0.000000     7.802000
# 798     0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency
# 12       39.150000
# 533      13.431034
# 1227     36.285714
# 319      40.486486
# 1386      0.000000
# ...            ...
# 988      39.528302
# 938      66.851852
# 0        45.327103
# 637      20.507143
# 798       0.000000
#
# [369 rows x 27 columns]

# %%
# Sanity Check
y_train
# Out:
# 1373     4.850000
# 1186    11.190000
# 814     11.325000
# 1244    12.035714
# 410     11.747143
#           ...
# 1122    10.815714
# 1346    15.860000
# 1406     8.150000
# 1389     7.850000
# 1534     5.582500
# Name: average_body_weight, Length: 1475, dtype: float64

# %%
# Sanity Check
y_test
# Out:
# 12      14.142222
# 533      7.233333
# 1227     7.738333
# 319     11.250000
# 1386    85.000000
#           ...
# 988      5.745000
# 938      5.230000
# 0        7.256364
# 637     10.700000
# 798      5.850000
# Name: average_body_weight, Length: 369, dtype: float64

# %%
# create x_train_copy
X_train_copy = X_train.copy()

# %%
# create x_test_copy
X_test_copy = X_test.copy()

# %% [markdown]
# ## Simple EDA

# %%
# Combine X_train and y_train for EDA purposes
train_set = pd.merge(X_train, y_train, left_index=True, right_index=True)

# Sanity check the data
train_set
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 1373      200000  2660.00          0.0                   1.25
# 1186      325000  2500.00          0.0                   1.25
# 814        50000  1000.00          0.0                   1.25
# 1244      383358  2560.00          1.0                   1.25
# 410       400000  1500.00          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1122      436424  1962.50          0.0                   1.25
# 1346       72314   600.00          0.0                   1.25
# 1406      115000  1000.00          0.0                   1.20
# 1389       84000  1064.18          0.0                   1.25
# 1534        9820    19.62          1.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                   100.0         55.0        95.00       28.00
# 1186                   120.0         55.0        50.00       50.00
# 814                    120.0         45.0        36.51       27.39
# 1244                   120.0         55.0        50.60       50.60
# 410                    100.0         55.0        44.72       33.54
# ...                      ...          ...          ...         ...
# 1122                   120.0         50.0        50.00       50.00
# 1346                   120.0         45.0        28.28       21.21
# 1406                   110.0         30.0        37.67       28.25
# 1389                   130.0         55.0        37.67       28.25
# 1534                   100.0         55.0         5.00        5.00
#
#       pond_depth  cycle_duration_days  ...   nitrate    nitrite  alkalinity  \
# 1373        1.50                   66  ...  0.000000   0.001409    2.909091
# 1186        1.20                  110  ...  0.000000   0.469855   23.772727
# 814         1.30                  109  ...  0.000000   0.000000    0.000000
# 1244        1.20                   93  ...  0.000000   0.000000    0.000000
# 410         1.50                   91  ...  0.002895  55.283026    8.671053
# ...          ...                  ...  ...       ...        ...         ...
# 1122        1.20                   85  ...  0.000000   0.015541   23.581081
# 1346        1.25                  120  ...  0.000000   0.000000    0.000000
# 1406        1.10                   87  ...  0.000000   0.013000   25.129630
# 1389        1.10                   58  ...  0.000000   0.012754   12.114754
# 1534        1.00                   67  ...  0.000000   0.000000    0.000000
#
#         hardness     calcium   magnesium  carbonate  bicarbonate  \
# 1373   37.878788    9.090909   28.787879   0.363636     2.545455
# 1186  881.818182   65.818182  165.214545   0.036364    23.736364
# 814     0.000000    0.000000    0.000000   0.000000     0.000000
# 1244    0.000000    0.000000    0.000000   0.000000     0.000000
# 410   209.013158   64.105263  200.157895   0.815789     9.592105
# ...          ...         ...         ...        ...          ...
# 1122    0.000000   67.554054  135.810811   0.000000     0.000000
# 1346    0.000000    0.000000    0.000000   0.000000     0.000000
# 1406  932.907407   13.555556   42.018519   1.333333     3.111111
# 1389  409.245902  111.606557  381.360656   1.180328    10.934426
# 1534    0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency  average_body_weight
# 1373      0.000000             4.850000
# 1186     41.636364            11.190000
# 814       0.000000            11.325000
# 1244     44.000000            12.035714
# 410      48.766447            11.747143
# ...            ...                  ...
# 1122      9.162162            10.815714
# 1346      0.000000            15.860000
# 1406     50.092593             8.150000
# 1389     49.139344             7.850000
# 1534     30.955882             5.582500
#
# [1475 rows x 28 columns]

# %%
# Setting the number of rows and columns for subplots
num_rows = 12 
num_cols = 3 

# Calculating the total number of subplots
total_subplots = num_rows * num_cols

# Adjusting aspect ratio based on number of rows and columns
fig_width = 15 
fig_height = 5 * num_rows  

# Adjusting the figure size with aspect ratio
plt.figure(figsize=(fig_width, fig_height))

# Initializing the subplot index
subplot_index = 1

# Looping through each column to visualize the data distribution
for col in train_set.columns:
    if train_set[col].dtype != 'object':
        # Creating a subplot
        plt.subplot(num_rows, num_cols, subplot_index)

        # Using kdeplot to visualize the distribution
        ax = sns.kdeplot(train_set[col], shade=True)

        # Calculating mean, median, and mode
        mean_val = train_set[col].mean()
        median_val = train_set[col].median()
        mode_val = stats.mode(train_set[col])[0]

        # Adding lines for mean, median, and mode
        ax.axvline(mean_val, color='red', linestyle='--', label=f'Mean ({mean_val:.2f})')
        ax.axvline(median_val, color='green', linestyle='--', label=f'Median ({median_val:.2f})')
        ax.axvline(mode_val, color='blue', linestyle='--', label=f'Mode ({mode_val[0]:.2f})')

        # Setting the title
        ax.set_title(col, fontsize=14)

        # Adding a legend
        plt.legend(fontsize=12)

        # Incrementing the subplot index
        subplot_index += 1

        # Stop creating subplots if already reached the total number of subplots
        if subplot_index > total_subplots:
            break

# Adjusting the layout of subplots for better readability
plt.tight_layout(pad=3.0)

# Showing the plot
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_2772\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]

# %%
# List of provided features
features = [
       'total_seed', 'area', 'initial_age', 'limit_weight_per_area',
       'target_cultivation_day', 'target_size', 'pond_length', 'pond_width',
       'pond_depth', 'cycle_duration_days', 'feed_quantity_kg', 'morning_temperature', 'evening_temperature',
       'morning_do', 'evening_do', 'morning_salinity', 'evening_salinity',
       'ammonia', 'nitrate', 'nitrite', 'alkalinity', 'hardness', 'calcium',
       'magnesium', 'carbonate', 'bicarbonate', 'transparency',
       'average_body_weight'
]

# Calculate the correlation matrix using the Spearman method
correlation_matrix = train_set[features].corr(method='spearman')

# Flatten the correlation matrix and convert it to a DataFrame
correlation_df = correlation_matrix.unstack().reset_index()

# Rename columns
correlation_df.columns = ['Feature 1', 'Feature 2', 'Correlation']

# Remove duplicate pairs and self-correlations
correlation_df = correlation_df[correlation_df['Feature 1'] != correlation_df['Feature 2']]

# Remove duplicates (reverse correlations) by keeping one side of the pair
correlation_df['abs_correlation'] = correlation_df['Correlation'].abs()
correlation_df = correlation_df.drop_duplicates(subset=['Feature 1', 'abs_correlation'])

# Sort the DataFrame by correlation values in descending order
correlation_df_sorted = correlation_df.sort_values(by='Correlation', ascending=False)

# Display the sorted correlation DataFrame
print(correlation_df_sorted[['Feature 1', 'Feature 2', 'Correlation']])
# Out:
#                   Feature 1               Feature 2  Correlation
# 639                 calcium               magnesium     0.993671
# 666               magnesium                 calcium     0.993671
# 611                hardness               magnesium     0.885802
# 665               magnesium                hardness     0.885802
# 637                 calcium                hardness     0.881018
# ..                      ...                     ...          ...
# 620                 calcium  target_cultivation_day    -0.240464
# 648               magnesium  target_cultivation_day    -0.246973
# 135  target_cultivation_day               magnesium    -0.246973
# 133  target_cultivation_day                hardness    -0.259470
# 592                hardness  target_cultivation_day    -0.259470
#
# [756 rows x 3 columns]

# %%
# Sanity Check
correlation_df_sorted
# Out:
#                   Feature 1               Feature 2  Correlation  \
# 639                 calcium               magnesium     0.993671
# 666               magnesium                 calcium     0.993671
# 611                hardness               magnesium     0.885802
# 665               magnesium                hardness     0.885802
# 637                 calcium                hardness     0.881018
# ..                      ...                     ...          ...
# 620                 calcium  target_cultivation_day    -0.240464
# 648               magnesium  target_cultivation_day    -0.246973
# 135  target_cultivation_day               magnesium    -0.246973
# 133  target_cultivation_day                hardness    -0.259470
# 592                hardness  target_cultivation_day    -0.259470
#
#      abs_correlation
# 639         0.993671
# 666         0.993671
# 611         0.885802
# 665         0.885802
# 637         0.881018
# ..               ...
# 620         0.240464
# 648         0.246973
# 135         0.246973
# 133         0.259470
# 592         0.259470
#
# [756 rows x 4 columns]

# %%
# Filter the correlation dataframe for rows where 'Feature 1' or 'Feature 2' is 'survival_rate'
survival_rate_correlations = correlation_df_sorted[(correlation_df_sorted['Feature 1'] == 'average_body_weight') | (correlation_df_sorted['Feature 2'] == 'average_body_weight')]

# Display the filtered dataframe
survival_rate_correlations.head(30)
# Out:
#                   Feature 1               Feature 2  Correlation  \
# 765     average_body_weight     cycle_duration_days     0.618094
# 279     cycle_duration_days     average_body_weight     0.618094
# 307        feed_quantity_kg     average_body_weight     0.486593
# 766     average_body_weight        feed_quantity_kg     0.486593
# 763     average_body_weight              pond_width     0.235480
# 223              pond_width     average_body_weight     0.235480
# 757     average_body_weight                    area     0.227495
# 55                     area     average_body_weight     0.227495
# 760     average_body_weight  target_cultivation_day     0.194392
# 139  target_cultivation_day     average_body_weight     0.194392
# 762     average_body_weight             pond_length     0.191342
# 195             pond_length     average_body_weight     0.191342
# 251              pond_depth     average_body_weight     0.168063
# 764     average_body_weight              pond_depth     0.168063
# 756     average_body_weight              total_seed     0.160090
# 27               total_seed     average_body_weight     0.160090
# 775     average_body_weight                 nitrite     0.100438
# 559                 nitrite     average_body_weight     0.100438
# 755            transparency     average_body_weight     0.064303
# 782     average_body_weight            transparency     0.064303
# 587              alkalinity     average_body_weight     0.049642
# 776     average_body_weight              alkalinity     0.049642
# 83              initial_age     average_body_weight     0.032612
# 758     average_body_weight             initial_age     0.032612
# 503                 ammonia     average_body_weight     0.012309
# 773     average_body_weight                 ammonia     0.012309
# 781     average_body_weight             bicarbonate    -0.003444
# 727             bicarbonate     average_body_weight    -0.003444
# 774     average_body_weight                 nitrate    -0.018045
# 531                 nitrate     average_body_weight    -0.018045
#
#      abs_correlation
# 765         0.618094
# 279         0.618094
# 307         0.486593
# 766         0.486593
# 763         0.235480
# 223         0.235480
# 757         0.227495
# 55          0.227495
# 760         0.194392
# 139         0.194392
# 762         0.191342
# 195         0.191342
# 251         0.168063
# 764         0.168063
# 756         0.160090
# 27          0.160090
# 775         0.100438
# 559         0.100438
# 755         0.064303
# 782         0.064303
# 587         0.049642
# 776         0.049642
# 83          0.032612
# 758         0.032612
# 503         0.012309
# 773         0.012309
# 781         0.003444
# 727         0.003444
# 774         0.018045
# 531         0.018045

# %% [markdown]
# ## Data Preprocessing

# %%
# Import necessary libraries
import os
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# %%
import os
import pickle
from sklearn.preprocessing import RobustScaler

# Columns to scale
columns_to_scale = [
       'total_seed', 'area', 'initial_age', 'limit_weight_per_area',
       'target_cultivation_day', 'target_size', 'pond_length', 'pond_width',
       'pond_depth', 'cycle_duration_days', 
       'feed_quantity_kg', 'morning_temperature', 'evening_temperature',
       'morning_do', 'evening_do', 'morning_salinity', 'evening_salinity',
       'ammonia', 'nitrate', 'nitrite', 'alkalinity', 'hardness', 'calcium',
       'magnesium', 'carbonate', 'bicarbonate', 'transparency'
]

def fit_scaler(train_data):
    """
    Fit a RobustScaler to the training data.

    Parameters:
    train_data (DataFrame): The training data.

    Returns:
    scaler (RobustScaler): The fitted scaler object.
    """
    scaler = RobustScaler()
    scaler.fit(train_data.loc[:, columns_to_scale])
    # Save scaler
    with open('model/abw_scaler_first.pkl', 'wb') as f:
        pickle.dump(scaler, f)
    return scaler

def load_scaler(folder_path):
    """
    Load a saved scaler object from a folder.

    Parameters:
    folder_path (str): The path to the folder containing the saved scaler.

    Returns:
    scaler (RobustScaler): The loaded scaler object.
    """
    # Load scaler
    file_path = os.path.join(folder_path, 'abw_scaler_first.pkl')
    with open(file_path, 'rb') as f:
        scaler = pickle.load(f)
    return scaler

def transform_data(data, scaler):
    """
    Scale the data using a given scaler.

    Parameters:
    data (DataFrame): The data to be scaled.
    scaler (RobustScaler): The scaler object to use for scaling.

    Returns:
    scaled_data (DataFrame): The scaled data.
    """
    scaled_data = scaler.transform(data.loc[:, columns_to_scale])
    data.loc[:, columns_to_scale] = scaled_data
    return data

# %%
# Fit a RobustScaler to the training data
scaler = fit_scaler(X_train_copy)

# %%
# Load the scaler from the specified folder path
scaling = load_scaler('model/')

# %%
# Transform the training and testing data using the loaded scaler
X_train_scaled = transform_data(X_train_copy, scaling)
X_test_scaled = transform_data(X_test_copy, scaling)

# %%
# Sanity check
X_train_scaled
# Out:
#       total_seed      area  initial_age  limit_weight_per_area  \
# 1373   -0.019512  0.793333          0.0                   0.00
# 1186    0.590244  0.686667          0.0                   0.00
# 814    -0.751220 -0.313333          0.0                   0.00
# 1244    0.874917  0.726667          1.0                   0.00
# 410     0.956098  0.020000          0.0                   0.00
# ...          ...       ...          ...                    ...
# 1122    1.133776  0.328333          0.0                   0.00
# 1346   -0.642371 -0.580000          0.0                   0.00
# 1406   -0.434146 -0.313333          0.0                  -0.05
# 1389   -0.585366 -0.270547          0.0                   0.00
# 1534   -0.947220 -0.966920          1.0                   0.00
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                    -1.0          0.0     2.397711   -0.397501
# 1186                     0.0          0.0     0.251788    0.851789
# 814                      0.0         -1.0    -0.391512   -0.432141
# 1244                     0.0          0.0     0.280401    0.885860
# 410                     -1.0          0.0     0.000000   -0.082907
# ...                      ...          ...          ...         ...
# 1122                     0.0         -0.5     0.251788    0.851789
# 1346                     0.0         -1.0    -0.783977   -0.783078
# 1406                    -0.5         -2.5    -0.336195   -0.383305
# 1389                     0.5          0.0    -0.336195   -0.383305
# 1534                    -1.0          0.0    -1.894134   -1.703578
#
#       pond_depth  cycle_duration_days  ...   ammonia   nitrate      nitrite  \
# 1373       0.500            -0.558824  ...  0.002606  0.000000     0.073480
# 1186      -0.250             0.735294  ...  0.000000  0.000000    24.501642
# 814        0.000             0.705882  ...  0.000000  0.000000     0.000000
# 1244      -0.250             0.235294  ...  0.000000  0.000000     0.000000
# 410        0.500             0.176471  ...  0.000000  0.002895  2882.860053
# ...          ...                  ...  ...       ...       ...          ...
# 1122      -0.250             0.000000  ...  0.000000  0.000000     0.810397
# 1346      -0.125             1.029412  ...  0.000000  0.000000     0.000000
# 1406      -0.500             0.058824  ...  0.000000  0.000000     0.677915
# 1389      -0.500            -0.794118  ...  0.000000  0.000000     0.665092
# 1534      -0.750            -0.529412  ...  0.000000  0.000000     0.000000
#
#       alkalinity  hardness   calcium  magnesium  carbonate  bicarbonate  \
# 1373   -0.104713  0.230550  0.218482   0.240157   2.556768     0.210595
# 1186    1.117233  5.367208  1.581809   1.378267   0.255677     1.963797
# 814    -0.275093  0.000000  0.000000   0.000000   0.000000     0.000000
# 1244   -0.275093  0.000000  0.000000   0.000000   0.000000     0.000000
# 410     0.232755  1.272164  1.540643   1.669775   5.735906     0.793590
# ...          ...       ...       ...        ...        ...          ...
# 1122    1.106009  0.000000  1.623528   1.132973   0.000000     0.000000
# 1346   -0.275093  0.000000  0.000000   0.000000   0.000000     0.000000
# 1406    1.196704  5.678163  0.325781   0.350531   9.374815     0.257394
# 1389    0.434446  2.490885  2.682242   3.181420   8.299016     0.904645
# 1534   -0.275093  0.000000  0.000000   0.000000   0.000000     0.000000
#
#       transparency
# 1373     -0.371293
# 1186      0.659327
# 814      -0.371293
# 1244      0.717834
# 410       0.835817
# ...            ...
# 1122     -0.144503
# 1346     -0.371293
# 1406      0.868643
# 1389      0.845048
# 1534      0.394954
#
# [1475 rows x 27 columns]

# %%
# Sanity Check
X_test_scaled
# Out:
#       total_seed      area  initial_age  limit_weight_per_area  \
# 12     -0.507317 -0.280000          0.0                   0.75
# 533    -0.391141  0.086667          0.0                   0.00
# 1227    0.590244  0.686667          0.0                   0.00
# 319     0.664390  1.706667          0.0                   0.75
# 1386    1.931707 -0.298000          4.0                   0.00
# ...          ...       ...          ...                    ...
# 988    -0.751220 -0.809333          0.0                   1.00
# 938    -0.100176  0.566000          0.0                   0.00
# 0       0.624000  1.706667          0.0                   0.75
# 637    -0.494590 -0.113333          0.0                   0.00
# 798    -0.629268 -0.646667          0.0                   0.00
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 12                      0.00         -1.0    -0.463519   -0.283930
# 533                    -1.00          0.0    -0.225083    0.283930
# 1227                   -1.00          0.0     0.251788    0.851789
# 319                    -0.45         -2.0     0.967096    1.533220
# 1386                    0.00          0.0    -0.654268   -0.113572
# ...                      ...          ...          ...         ...
# 988                    -1.05         -1.0    -1.369576   -1.078932
# 938                    -1.00          0.0     0.470672    0.337308
# 0                      -0.50         -2.0     0.967096    1.533220
# 637                    -1.00          0.0    -0.225083    0.283930
# 798                     0.00          0.0    -0.940391   -0.851789
#
#       pond_depth  cycle_duration_days  ...   ammonia   nitrate    nitrite  \
# 12         -0.75             0.676471  ...  0.000000  0.000000   0.000000
# 533        -0.75            -0.911765  ...  0.006897  0.000000   0.038661
# 1227       -0.25            -0.323529  ...  0.000000  0.000000   0.249562
# 319        -0.75             0.764706  ...  0.000000  0.000000   0.000000
# 1386        0.50             0.735294  ...  0.000000  0.000000  86.454719
# ...          ...                  ...  ...       ...       ...        ...
# 988        -0.25            -0.882353  ...  0.000000  0.000000   0.000000
# 938        -0.25            -0.382353  ...  0.000000  0.000000   0.548512
# 0          -0.75             0.647059  ...  0.000000  0.000000   0.000000
# 637        -0.75            -0.500000  ...  0.018571  0.142857   0.136328
# 798         0.00            -0.411765  ...  0.000000  0.000000   0.000000
#
#       alkalinity  hardness   calcium  magnesium   carbonate  bicarbonate  \
# 12     -0.275093  0.000000  0.000000   0.000000    0.000000     0.000000
# 533     0.881043  0.311672  0.824167   0.666088  190.082452     0.859246
# 1227    0.893761  6.179822  4.287490   6.982136    7.131556     1.562485
# 319    -0.275093  0.000000  0.000000   0.000000    0.000000     0.000000
# 1386    0.514653  0.000000  0.000000   0.000000    0.000000     0.189852
# ...          ...       ...       ...        ...         ...          ...
# 988    -0.275093  0.000000  0.000000   0.000000    0.000000     0.000000
# 938     0.962070  5.060832  1.561256   1.553931   16.232318     1.554576
# 0      -0.275093  0.000000  0.000000   0.000000    0.000000     0.000000
# 637     1.125808  0.384494  0.981062   0.789121    0.000000     0.645488
# 798    -0.275093  0.000000  0.000000   0.000000    0.000000     0.000000
#
#       transparency
# 12        0.597782
# 533      -0.038836
# 1227      0.526883
# 319       0.630864
# 1386     -0.371293
# ...            ...
# 988       0.607146
# 938       1.283483
# 0         0.750684
# 637       0.136318
# 798      -0.371293
#
# [369 rows x 27 columns]

# %% [markdown]
# ## Feature Selection

# %%
# Copy X_train_scaled
X_train_clean = X_train_scaled.copy()

# %%
# Copy X_test_clean
X_test_clean = X_test_scaled.copy()

# %%
# Import necessary libraries for data preparation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import libraries for data splitting
from sklearn.model_selection import train_test_split

# Import library for data scaling
from sklearn.preprocessing import StandardScaler

# Import library for calculating mean absolute error (MAE)
from sklearn.metrics import mean_absolute_error

# Import libraries for model creation
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE

# %%
# Initialize RandomForestRegressor model with specified parameters
random_forest = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=123)

# Initialize RFE with RandomForestRegressor as estimator and desired number of features
rfe = RFE(estimator=random_forest, n_features_to_select=24)

# Train RFE on the training data
rfe.fit(X_train_clean, y_train)

# Get the mask of selected features
selected_features = rfe.support_

# Get the ranking of each feature
feature_ranking = rfe.ranking_

# Selected features
selected_feature_names = X_train_clean.columns[selected_features]

print(f"Selected features: {selected_feature_names}")

# Transform the training and testing data using the selected features
X_train_rfe = rfe.transform(X_train_clean)
X_test_rfe = rfe.transform(X_test_clean)

# Fit the RandomForestRegressor model on the transformed training data
random_forest.fit(X_train_rfe, y_train)

# Make predictions on the training data
y_pred_train = random_forest.predict(X_train_rfe)

# Make predictions on the testing data
y_pred_test = random_forest.predict(X_test_rfe)

# Calculate Mean Absolute Error (MAE) for training and testing data
mae_train_rf = mean_absolute_error(y_train, y_pred_train)
mae_test_rf = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_rf:.4f}")
print(f"MAE Test  : {mae_test_rf:.4f}")
# Out:
# Selected features: Index(['total_seed', 'area', 'initial_age', 'target_cultivation_day',
#        'target_size', 'pond_length', 'pond_width', 'pond_depth',
#        'cycle_duration_days', 'feed_quantity_kg', 'morning_temperature',
#        'evening_temperature', 'morning_do', 'evening_do', 'morning_salinity',
#        'evening_salinity', 'ammonia', 'nitrate', 'nitrite', 'alkalinity',
#        'hardness', 'carbonate', 'bicarbonate', 'transparency'],
#       dtype='object')
# MAE Train : 1.1272
# MAE Test  : 2.0002

# %%
# Assume random_forest has been trained and selected_feature_names is available
# Get feature importance from the model
feature_importances = random_forest.feature_importances_

# Create a DataFrame for feature importance
feature_importance_df = pd.DataFrame({
    'Feature': selected_feature_names,
    'Importance': feature_importances
})

# Sort the feature importance from most to least important
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the top 20 important features
top_20_feature_importance_df = feature_importance_df.head(24)
print(top_20_feature_importance_df)

# Visualize the top 20 important features
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=top_20_feature_importance_df)
plt.title('Top 20 Feature Importances')
plt.show()
# Out:
#                    Feature  Importance
# 8      cycle_duration_days    0.414803
# 9         feed_quantity_kg    0.073890
# 0               total_seed    0.056193
# 2              initial_age    0.051184
# 15        evening_salinity    0.039758
# 11     evening_temperature    0.036358
# 6               pond_width    0.034148
# 10     morning_temperature    0.028952
# 5              pond_length    0.028051
# 1                     area    0.026835
# 13              evening_do    0.026188
# 7               pond_depth    0.025030
# 12              morning_do    0.021093
# 14        morning_salinity    0.019657
# 23            transparency    0.017810
# 3   target_cultivation_day    0.016295
# 19              alkalinity    0.013847
# 4              target_size    0.013449
# 22             bicarbonate    0.013296
# 16                 ammonia    0.011946
# 18                 nitrite    0.010307
# 21               carbonate    0.008180
# 20                hardness    0.006514
# 17                 nitrate    0.006216

# %%
# Using the variable feature_importances and RFE
feature_importances = top_20_feature_importance_df['Feature'].unique()
RFE = selected_feature_names

# Convert lists to sets for easier set operations
set_feature_importances = set(feature_importances)
set_RFE = set(RFE)

# Features that are in 'feature_importances' but not in 'RFE'
only_in_feature_importances = set_feature_importances - set_RFE

# Features that are in 'RFE' but not in 'feature_importances'
only_in_RFE = set_RFE - set_feature_importances

# Features that are in both sets
in_both = set_feature_importances & set_RFE

print("Features only in 'feature_importances':", only_in_feature_importances)
print("Features only in 'RFE':", only_in_RFE)
print("Features in both sets:", in_both)
# Out:
# Features only in 'feature_importances': set()
# Features only in 'RFE': set()
# Features in both sets: {'evening_do', 'transparency', 'carbonate', 'area', 'morning_temperature', 'evening_salinity', 'ammonia', 'nitrate', 'pond_length', 'target_cultivation_day', 'target_size', 'morning_do', 'bicarbonate', 'cycle_duration_days', 'evening_temperature', 'morning_salinity', 'nitrite', 'pond_depth', 'feed_quantity_kg', 'alkalinity', 'initial_age', 'hardness', 'total_seed', 'pond_width'}

# %% [markdown]
# ## Training Data

# %%
# Sanity Check (selected feature)
feature_importance_df.Feature.unique()
# Out:
# array(['cycle_duration_days', 'feed_quantity_kg', 'total_seed',
#        'initial_age', 'evening_salinity', 'evening_temperature',
#        'pond_width', 'morning_temperature', 'pond_length', 'area',
#        'evening_do', 'pond_depth', 'morning_do', 'morning_salinity',
#        'transparency', 'target_cultivation_day', 'alkalinity',
#        'target_size', 'bicarbonate', 'ammonia', 'nitrite', 'carbonate',
#        'hardness', 'nitrate'], dtype=object)

# %%
# Sanity Check
X_train
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 1373      200000  2660.00          0.0                   1.25
# 1186      325000  2500.00          0.0                   1.25
# 814        50000  1000.00          0.0                   1.25
# 1244      383358  2560.00          1.0                   1.25
# 410       400000  1500.00          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1122      436424  1962.50          0.0                   1.25
# 1346       72314   600.00          0.0                   1.25
# 1406      115000  1000.00          0.0                   1.20
# 1389       84000  1064.18          0.0                   1.25
# 1534        9820    19.62          1.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                   100.0         55.0        95.00       28.00
# 1186                   120.0         55.0        50.00       50.00
# 814                    120.0         45.0        36.51       27.39
# 1244                   120.0         55.0        50.60       50.60
# 410                    100.0         55.0        44.72       33.54
# ...                      ...          ...          ...         ...
# 1122                   120.0         50.0        50.00       50.00
# 1346                   120.0         45.0        28.28       21.21
# 1406                   110.0         30.0        37.67       28.25
# 1389                   130.0         55.0        37.67       28.25
# 1534                   100.0         55.0         5.00        5.00
#
#       pond_depth  cycle_duration_days  ...   ammonia   nitrate    nitrite  \
# 1373        1.50                   66  ...  0.002606  0.000000   0.001409
# 1186        1.20                  110  ...  0.000000  0.000000   0.469855
# 814         1.30                  109  ...  0.000000  0.000000   0.000000
# 1244        1.20                   93  ...  0.000000  0.000000   0.000000
# 410         1.50                   91  ...  0.000000  0.002895  55.283026
# ...          ...                  ...  ...       ...       ...        ...
# 1122        1.20                   85  ...  0.000000  0.000000   0.015541
# 1346        1.25                  120  ...  0.000000  0.000000   0.000000
# 1406        1.10                   87  ...  0.000000  0.000000   0.013000
# 1389        1.10                   58  ...  0.000000  0.000000   0.012754
# 1534        1.00                   67  ...  0.000000  0.000000   0.000000
#
#       alkalinity    hardness     calcium   magnesium  carbonate  bicarbonate  \
# 1373    2.909091   37.878788    9.090909   28.787879   0.363636     2.545455
# 1186   23.772727  881.818182   65.818182  165.214545   0.036364    23.736364
# 814     0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 1244    0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 410     8.671053  209.013158   64.105263  200.157895   0.815789     9.592105
# ...          ...         ...         ...         ...        ...          ...
# 1122   23.581081    0.000000   67.554054  135.810811   0.000000     0.000000
# 1346    0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
# 1406   25.129630  932.907407   13.555556   42.018519   1.333333     3.111111
# 1389   12.114754  409.245902  111.606557  381.360656   1.180328    10.934426
# 1534    0.000000    0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency
# 1373      0.000000
# 1186     41.636364
# 814       0.000000
# 1244     44.000000
# 410      48.766447
# ...            ...
# 1122      9.162162
# 1346      0.000000
# 1406     50.092593
# 1389     49.139344
# 1534     30.955882
#
# [1475 rows x 27 columns]

# %%
# Sanity Check
X_test
# Out:
#       total_seed    area  initial_age  limit_weight_per_area  \
# 12        100000  1050.0          0.0                   2.00
# 533       123816  1600.0          0.0                   1.25
# 1227      325000  2500.0          0.0                   1.25
# 319       340200  4030.0          0.0                   2.00
# 1386      600000  1023.0          4.0                   1.25
# ...          ...     ...          ...                    ...
# 988        50000   256.0          0.0                   2.25
# 938       183464  2319.0          0.0                   1.25
# 0         331920  4030.0          0.0                   2.00
# 637       102609  1300.0          0.0                   1.25
# 798        75000   500.0          0.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 12                     120.0         45.0        35.00       30.00
# 533                    100.0         55.0        40.00       40.00
# 1227                   100.0         55.0        50.00       50.00
# 319                    111.0         35.0        65.00       62.00
# 1386                   120.0         55.0        31.00       33.00
# ...                      ...          ...          ...         ...
# 988                     99.0         45.0        16.00       16.00
# 938                    100.0         55.0        54.59       40.94
# 0                      110.0         35.0        65.00       62.00
# 637                    100.0         55.0        40.00       40.00
# 798                    120.0         55.0        25.00       20.00
#
#       pond_depth  cycle_duration_days  ...   ammonia   nitrate   nitrite  \
# 12           1.0                  108  ...  0.000000  0.000000  0.000000
# 533          1.0                   54  ...  0.006897  0.000000  0.000741
# 1227         1.2                   74  ...  0.000000  0.000000  0.004786
# 319          1.0                  111  ...  0.000000  0.000000  0.000000
# 1386         1.5                  110  ...  0.000000  0.000000  1.657895
# ...          ...                  ...  ...       ...       ...       ...
# 988          1.2                   55  ...  0.000000  0.000000  0.000000
# 938          1.2                   72  ...  0.000000  0.000000  0.010519
# 0            1.0                  107  ...  0.000000  0.000000  0.000000
# 637          1.0                   68  ...  0.018571  0.142857  0.002614
# 798          1.3                   71  ...  0.000000  0.000000  0.000000
#
#       alkalinity     hardness     calcium   magnesium  carbonate  bicarbonate  \
# 12      0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 533    19.740000    51.206897   34.293103   79.844828  27.034483    10.385690
# 1227   19.957143  1015.328571  178.400000  836.957143   1.014286    18.885714
# 319     0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 1386   13.484211     0.000000    0.000000    0.000000   0.000000     2.294737
# ...          ...          ...         ...         ...        ...          ...
# 988     0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 938    21.123457   831.481481   64.962963  186.271605   2.308642    18.790123
# 0       0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
# 637    23.919143    63.171429   40.821429   94.592857   0.000000     7.802000
# 798     0.000000     0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency
# 12       39.150000
# 533      13.431034
# 1227     36.285714
# 319      40.486486
# 1386      0.000000
# ...            ...
# 988      39.528302
# 938      66.851852
# 0        45.327103
# 637      20.507143
# 798       0.000000
#
# [369 rows x 27 columns]

# %%
import os
import pickle
from sklearn.preprocessing import RobustScaler

# Columns to scale
columns_to_scale = [
      'cycle_duration_days', 'feed_quantity_kg', 'total_seed',
       'initial_age', 'evening_salinity', 'evening_temperature',
       'pond_width', 'morning_temperature', 'pond_length', 'area',
       'evening_do', 'pond_depth', 'morning_do', 'morning_salinity',
       'transparency', 'target_cultivation_day', 'alkalinity',
       'target_size', 'bicarbonate', 'ammonia', 'nitrite', 'carbonate',
       'hardness', 'nitrate'
]

def fit_scaler(train_data):
    """
    Fit a RobustScaler to the training data.

    Parameters:
    train_data (DataFrame): The training data.

    Returns:
    scaler (RobustScaler): The fitted scaler object.
    """
    scaler = RobustScaler()
    scaler.fit(train_data.loc[:, columns_to_scale])
    # Save scaler
    with open('model/abw_scaler.pkl', 'wb') as f:
        pickle.dump(scaler, f)
    return scaler

def load_scaler(folder_path):
    """
    Load a saved scaler object from a folder.

    Parameters:
    folder_path (str): The path to the folder containing the saved scaler.

    Returns:
    scaler (RobustScaler): The loaded scaler object.
    """
    # Load scaler
    file_path = os.path.join(folder_path, 'abw_scaler.pkl')
    with open(file_path, 'rb') as f:
        scaler = pickle.load(f)
    return scaler

def transform_data(data, scaler):
    """
    Scale the data using a given scaler.

    Parameters:
    data (DataFrame): The data to be scaled.
    scaler (RobustScaler): The scaler object to use for scaling.

    Returns:
    scaled_data (DataFrame): The scaled data.
    """
    scaled_data = scaler.transform(data.loc[:, columns_to_scale])
    data.loc[:, columns_to_scale] = scaled_data
    return data

# %%
X_train_feature_importances = X_train[['cycle_duration_days', 'feed_quantity_kg', 'total_seed',
       'initial_age', 'evening_salinity', 'evening_temperature',
       'pond_width', 'morning_temperature', 'pond_length', 'area',
       'evening_do', 'pond_depth', 'morning_do', 'morning_salinity',
       'transparency', 'target_cultivation_day', 'alkalinity',
       'target_size', 'bicarbonate', 'ammonia', 'nitrite', 'carbonate',
       'hardness', 'nitrate']].copy()
X_test_feature_importances = X_test[['cycle_duration_days', 'feed_quantity_kg', 'total_seed',
       'initial_age', 'evening_salinity', 'evening_temperature',
       'pond_width', 'morning_temperature', 'pond_length', 'area',
       'evening_do', 'pond_depth', 'morning_do', 'morning_salinity',
       'transparency', 'target_cultivation_day', 'alkalinity',
       'target_size', 'bicarbonate', 'ammonia', 'nitrite', 'carbonate',
       'hardness', 'nitrate']].copy()

# %%
# Sorted Columns
X_train_feature_importances = X_train_feature_importances[sorted(X_train_feature_importances.columns)]

# %%
# Sorted Columns
X_test_feature_importances = X_test_feature_importances[sorted(X_test_feature_importances.columns)]

# %%
# Fit a RobustScaler to the training data
scaler = fit_scaler(X_train_feature_importances)

# %%
# Load the scaler from the specified folder path
scaling = load_scaler('model/')

# %%
# Transform the training and testing data using the loaded scaler
X_train_clean = transform_data(X_train_feature_importances, scaling)
X_test_clean = transform_data(X_test_feature_importances, scaling)

# %%
X_train_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1475 entries, 1373 to 1534
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   alkalinity              1475 non-null   float64
#  1   ammonia                 1475 non-null   float64
#  2   area                    1475 non-null   float64
#  3   bicarbonate             1475 non-null   float64
#  4   carbonate               1475 non-null   float64
#  5   cycle_duration_days     1475 non-null   float64
#  6   evening_do              1475 non-null   float64
#  7   evening_salinity        1475 non-null   float64
#  8   evening_temperature     1475 non-null   float64
#  9   feed_quantity_kg        1475 non-null   float64
#  10  hardness                1475 non-null   float64
#  11  initial_age             1475 non-null   float64
#  12  morning_do              1475 non-null   float64
#  13  morning_salinity        1475 non-null   float64
#  14  morning_temperature     1475 non-null   float64
#  15  nitrate                 1475 non-null   float64
#  16  nitrite                 1475 non-null   float64
#  17  pond_depth              1475 non-null   float64
#  18  pond_length             1475 non-null   float64
#  19  pond_width              1475 non-null   float64
#  20  target_cultivation_day  1475 non-null   float64
#  21  target_size             1475 non-null   float64
#  22  total_seed              1475 non-null   float64
#  23  transparency            1475 non-null   float64
# dtypes: float64(24)
# memory usage: 320.4 KB

# %% [markdown]
# ## Baseline

# %%
# Baseline
y_baseline_predict = y_train.mean()
y_baseline_predict
# Out:
# 9.806218608950623

# %%
# Viewing Mean Absolute Error for the baseline Model
mae_train_baseline = mean_absolute_error(y_train, y_baseline_predict * np.ones(len(y_train)))
mae_test_baseline = mean_absolute_error(y_test, y_baseline_predict * np.ones(len(y_test)))

# Viewing mae train baseline and mae test baseline
mae_train_baseline, mae_test_baseline
# Out:
# (3.3961745842465647, 3.446653530686994)

# %% [markdown]
# ## Linear Regression

# %%
# Build LinearRegression
lin_reg = LinearRegression()

# %%
#Fitting Model LinearRegression
lin_reg.fit(X_train_clean, y_train)
# Out:
# LinearRegression()

# %%
# Predict
y_pred_train = lin_reg.predict(X_train_clean)
y_pred_test = lin_reg.predict(X_test_clean)

# MAE
mae_train_lg = mean_absolute_error(y_train, y_pred_train)
mae_test_lg = mean_absolute_error(y_test, y_pred_test)

# Viewing the results of mae train lg and mae test lg
mae_train_lg, mae_test_lg
# Out:
# (2.5429205902048437, 2.6284795809026646)

# %% [markdown]
# ## Dectree

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

# Initialize the DecisionTreeRegressor model with specified parameters
dec_tree = DecisionTreeRegressor(max_depth=10, random_state=123)

# Train the model on the training data
dec_tree.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = dec_tree.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = dec_tree.predict(X_test_clean)

# Calculate the Mean Absolute Error (MAE) for the training and test data
mae_train_dt = mean_absolute_error(y_train, y_pred_train)
mae_test_dt = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_dt:.4f}")
print(f"MAE Test  : {mae_test_dt:.4f}")
# Out:
# MAE Train : 1.1039
# MAE Test  : 2.2898

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for key parameters of DecisionTreeRegressor
params = {
    "max_depth": [3, 5, 7, 9, 11],
    "min_samples_split": [2, 10, 20],
    "min_samples_leaf": [1, 5, 10]
}

# Initialize the DecisionTreeRegressor model
dec_tree = DecisionTreeRegressor(random_state=123)

# Initialize GridSearchCV
dec_tree_cv = GridSearchCV(estimator=dec_tree,
                           param_grid=params,
                           cv=7,
                           scoring="neg_mean_absolute_error")

# Train GridSearchCV
dec_tree_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = dec_tree_cv.best_params_

# Train the model with the best parameters
best_dec_tree = DecisionTreeRegressor(max_depth=best_params["max_depth"],
                                      min_samples_split=best_params["min_samples_split"],
                                      min_samples_leaf=best_params["min_samples_leaf"],
                                      random_state=123)

best_dec_tree.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_dec_tree.predict(X_train_clean)
y_pred_test = best_dec_tree.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_dt_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_dt_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and best parameters
print(f"MAE Train : {mae_train_dt_cv:.4f}")
print(f"MAE Test  : {mae_test_dt_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 1.4080
# MAE Test  : 2.3054
# Best Parameters: {'max_depth': 11, 'min_samples_leaf': 1, 'min_samples_split': 20}

# %% [markdown]
# ## RandomForest

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Initialize the RandomForestRegressor model with specified parameters
random_forest = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=123)

# Train the model on the training data
random_forest.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = random_forest.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = random_forest.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_rf = mean_absolute_error(y_train, y_pred_train)
mae_test_rf = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_rf:.4f}")
print(f"MAE Test  : {mae_test_rf:.4f}")
# Out:
# MAE Train : 1.1243
# MAE Test  : 1.9958

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for RandomForestRegressor
params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 5, 7, 9, 11],
    "min_samples_split": [2, 10, 20],
    "min_samples_leaf": [1, 5, 10]
}

# Initialize RandomForestRegressor model
random_forest = RandomForestRegressor(random_state=123)

# Initialize RandomizedSearchCV
rf_cv = RandomizedSearchCV(estimator=random_forest,
                           param_distributions=params,
                           n_iter=50,
                           cv=7,
                           scoring="neg_mean_absolute_error",
                           random_state=123,
                           n_jobs=-1)

# Train RandomizedSearchCV
rf_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = rf_cv.best_params_

# Train the model with the best parameters
best_rf = RandomForestRegressor(n_estimators=best_params["n_estimators"],
                                max_depth=best_params["max_depth"],
                                min_samples_split=best_params["min_samples_split"],
                                min_samples_leaf=best_params["min_samples_leaf"],
                                random_state=123)

best_rf.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_rf.predict(X_train_clean)
y_pred_test = best_rf.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_rf_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_rf_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and best parameters
print(f"MAE Train : {mae_train_rf_cv:.4f}")
print(f"MAE Test  : {mae_test_rf_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 1.1776
# MAE Test  : 1.9986
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 11}

# %% [markdown]
# ## Adaboost

# %%
import numpy as np
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_absolute_error

# Initialize AdaBoostRegressor model with specified parameters
adaboost = AdaBoostRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
adaboost.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = adaboost.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = adaboost.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_ab = mean_absolute_error(y_train, y_pred_train)
mae_test_ab = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_ab:.4f}")
print(f"MAE Test  : {mae_test_ab:.4f}")
# Out:
# MAE Train : 2.6355
# MAE Test  : 2.6942

# %%
import numpy as np
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for some key parameters of AdaBoostRegressor
params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0]
}

# Initialize AdaBoostRegressor model
adaboost = AdaBoostRegressor(random_state=123)

# Initialize GridSearchCV
ab_cv = GridSearchCV(estimator=adaboost,
                     param_grid=params,
                     cv=7,
                     scoring="neg_mean_absolute_error")

# Train GridSearchCV
ab_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = ab_cv.best_params_

# Train the model with the best parameters
best_ab = AdaBoostRegressor(n_estimators=best_params["n_estimators"],
                            learning_rate=best_params["learning_rate"],
                            random_state=123)

best_ab.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_ab.predict(X_train_clean)
y_pred_test = best_ab.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_ab_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_ab_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and best parameters
print(f"MAE Train : {mae_train_ab_cv:.4f}")
print(f"MAE Test  : {mae_test_ab_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 2.4223
# MAE Test  : 2.4977
# Best Parameters: {'learning_rate': 0.01, 'n_estimators': 50}

# %% [markdown]
# ## Gradient Boosting

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# Initialize the GradientBoostingRegressor model with specified parameters
gradient_boosting = GradientBoostingRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
gradient_boosting.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = gradient_boosting.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = gradient_boosting.predict(X_test_clean)

# Calculate the Mean Absolute Error (MAE) for the training and test data
mae_train_gb = mean_absolute_error(y_train, y_pred_train)
mae_test_gb = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_gb:.4f}")
print(f"MAE Test  : {mae_test_gb:.4f}")
# Out:
# MAE Train : 1.6066
# MAE Test  : 2.0515

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for key parameters of GradientBoostingRegressor
params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0],
    "max_depth": [3, 5, 7, 9]
}

# Initialize the GradientBoostingRegressor model
gradient_boosting = GradientBoostingRegressor(random_state=123)

# Initialize GridSearchCV
gb_cv = GridSearchCV(estimator=gradient_boosting,
                     param_grid=params,
                     cv=7,
                     scoring="neg_mean_absolute_error")

# Train the GridSearchCV
gb_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = gb_cv.best_params_

# Train the model with the best parameters
best_gb = GradientBoostingRegressor(n_estimators=best_params["n_estimators"],
                                    learning_rate=best_params["learning_rate"],
                                    max_depth=best_params["max_depth"],
                                    random_state=123)

best_gb.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_gb.predict(X_train_clean)
y_pred_test = best_gb.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_gb_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_gb_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and the best parameters
print(f"MAE Train : {mae_train_gb_cv:.4f}")
print(f"MAE Test  : {mae_test_gb_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 0.5552
# MAE Test  : 1.8725
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}

# %% [markdown]
# ## Xgboost

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error

# Initialize the XGBoost model with specified parameters
xgboost = xgb.XGBRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
xgboost.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = xgboost.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = xgboost.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_xgb = mean_absolute_error(y_train, y_pred_train)
mae_test_xgb = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_xgb:.4f}")
print(f"MAE Test  : {mae_test_xgb:.4f}")
# Out:
# MAE Train : 0.2235
# MAE Test  : 1.9096

# %%
import numpy as np
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
from scipy.stats import uniform, randint

# Define distributions for key XGBoost parameters
param_distributions = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.1),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 0.3),
    'reg_alpha': uniform(0, 0.5),
    'reg_lambda': uniform(1, 2)
}

# Initialize the XGBoost model
xgboost = xgb.XGBRegressor(random_state=123)

# Initialize RandomizedSearchCV
xgb_random_cv = RandomizedSearchCV(estimator=xgboost,
                                   param_distributions=param_distributions,
                                   n_iter=50,
                                   cv=7,
                                   scoring="neg_mean_absolute_error",
                                   random_state=123,
                                   n_jobs=-1,
                                   verbose=2)

# Train the RandomizedSearchCV
xgb_random_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = xgb_random_cv.best_params_

# Train the model with the best parameters
best_xgb = xgb.XGBRegressor(**best_params, random_state=123)
best_xgb.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_xgb.predict(X_train_clean)
y_pred_test = best_xgb.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_xgb_random_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_xgb_random_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and the best parameters
print(f"MAE Train : {mae_train_xgb_random_cv:.4f}")
print(f"MAE Test  : {mae_test_xgb_random_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# MAE Train : 0.2257
# MAE Test  : 1.7429
# Best Parameters: {'colsample_bytree': 0.8739318954339452, 'gamma': 0.14427957044530829, 'learning_rate': 0.049211751819415055, 'max_depth': 9, 'n_estimators': 274, 'reg_alpha': 0.3645248536920208, 'reg_lambda': 1.8771444893592488, 'subsample': 0.6238711586438274}

# %% [markdown]
# ## Lightgbm

# %%
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error

# Initialize the LightGBM model with specified parameters
lightgbm = lgb.LGBMRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
lightgbm.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = lightgbm.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = lightgbm.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_lgb = mean_absolute_error(y_train, y_pred_train)
mae_test_lgb = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_lgb:.4f}")
print(f"MAE Test  : {mae_test_lgb:.4f}")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 12.0.1. Please consider upgrading.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000326 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4296
# [LightGBM] [Info] Number of data points in the train set: 1475, number of used features: 24
# [LightGBM] [Info] Start training from score 9.806219
# MAE Train : 0.7322
# MAE Test  : 1.9359

# %%
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for key LightGBM parameters
params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0],
    "max_depth": [3, 5, 7, 9]
}

# Initialize the LightGBM model
lightgbm = lgb.LGBMRegressor(random_state=123)

# Initialize GridSearchCV
lgb_cv = GridSearchCV(estimator=lightgbm,
                      param_grid=params,
                      cv=7,
                      scoring="neg_mean_absolute_error")

# Train the GridSearchCV
lgb_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = lgb_cv.best_params_

# Train the model with the best parameters
best_lgb = lgb.LGBMRegressor(n_estimators=best_params["n_estimators"],
                             learning_rate=best_params["learning_rate"],
                             max_depth=best_params["max_depth"],
                             random_state=123)

best_lgb.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_lgb.predict(X_train_clean)
y_pred_test = best_lgb.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_lgb_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_lgb_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and the best parameters
print(f"MAE Train : {mae_train_lgb_cv:.4f}")
print(f"MAE Test  : {mae_test_lgb_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3996
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.790419
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4008
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.855845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4037
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.786156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000633 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4012
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.813418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000552 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3986
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.755781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3990
# [LightGBM] [Info] Number of data points in the train set: 1265, number of used features: 24
# [LightGBM] [Info] Start training from score 9.789454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000441 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4009
# [LightGBM] [Info] Number of data points in the train set: 1265, number of used features: 24
# [LightGBM] [Info] Start training from score 9.852433
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000494 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3996
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.790419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4008
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.855845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000353 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4037
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.786156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000242 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4012
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.813418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000349 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3986
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.755781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3990
# [LightGBM] [Info] Number of data points in the train set: 1265, number of used features: 24
# [LightGBM] [Info] Start training from score 9.789454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4009
# [LightGBM] [Info] Number of data points in the train set: 1265, number of used features: 24
# [LightGBM] [Info] Start training from score 9.852433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000317 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3996
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.790419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4008
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.855845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4037
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 9.786156
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000824 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4296
# [LightGBM] [Info] Number of data points in the train set: 1475, number of used features: 24
# [LightGBM] [Info] Start training from score 9.806219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# MAE Train : 0.5569
# MAE Test  : 1.8986
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 200}

# %% [markdown]
# ## Simple Deep Leaning

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.metrics import MeanAbsoluteError as MAE
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(123)
tf.random.set_seed(123)

# Determine input dimension
input_dim = X_train_clean.shape[1]

# Build the model
model = Sequential()
model.add(Dense(128, input_dim=input_dim, activation='relu'))  # First hidden layer
model.add(Dense(64, activation='relu'))  # Second hidden layer
model.add(Dense(32, activation='relu'))  # Third hidden layer
model.add(Dense(1))  # Output layer

# Compile the model with specified learning rate
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanAbsoluteError(), metrics=[MAE()])

# Train the model with specified number of epochs
history = model.fit(X_train_clean, y_train, epochs=500, batch_size=64, validation_split=0.2, verbose=1)

# Make predictions on the training and test data
y_pred_train = model.predict(X_train_clean)
y_pred_test = model.predict(X_test_clean)

# Flatten the predictions
y_pred_train_flat = y_pred_train.flatten()
y_pred_test_flat = y_pred_test.flatten()

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_dl = np.mean(np.abs(y_train - y_pred_train_flat))
mae_test_dl = np.mean(np.abs(y_test - y_pred_test_flat))

# Print the MAE results
print(f"MAE Train : {mae_train_dl:.4f}")
print(f"MAE Test  : {mae_test_dl:.4f}")

# Visualize model performance over epochs
# Plot loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title('Model MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

plt.show()
# Out:
# Epoch 1/500
# 19/19 [==============================] - 2s 21ms/step - loss: 11.1778 - mean_absolute_error: 11.1778 - val_loss: 9.0306 - val_mean_absolute_error: 9.0306
# Epoch 2/500
# 19/19 [==============================] - 0s 5ms/step - loss: 9.7919 - mean_absolute_error: 9.7919 - val_loss: 7.7314 - val_mean_absolute_error: 7.7314
# Epoch 3/500
# 19/19 [==============================] - 0s 7ms/step - loss: 8.3919 - mean_absolute_error: 8.3919 - val_loss: 6.7328 - val_mean_absolute_error: 6.7328
# Epoch 4/500
# 19/19 [==============================] - 0s 4ms/step - loss: 7.4224 - mean_absolute_error: 7.4224 - val_loss: 5.9025 - val_mean_absolute_error: 5.9025
# Epoch 5/500
# 19/19 [==============================] - 0s 6ms/step - loss: 6.5205 - mean_absolute_error: 6.5205 - val_loss: 4.7028 - val_mean_absolute_error: 4.7028
# Epoch 6/500
# 19/19 [==============================] - 0s 7ms/step - loss: 5.4285 - mean_absolute_error: 5.4285 - val_loss: 4.9176 - val_mean_absolute_error: 4.9176
# Epoch 7/500
# 19/19 [==============================] - 0s 6ms/step - loss: 5.0991 - mean_absolute_error: 5.0991 - val_loss: 4.2894 - val_mean_absolute_error: 4.2894
# Epoch 8/500
# 19/19 [==============================] - 0s 5ms/step - loss: 4.3204 - mean_absolute_error: 4.3204 - val_loss: 4.6951 - val_mean_absolute_error: 4.6951
# Epoch 9/500
# 19/19 [==============================] - 0s 6ms/step - loss: 5.2695 - mean_absolute_error: 5.2695 - val_loss: 4.3619 - val_mean_absolute_error: 4.3619
# Epoch 10/500
# 19/19 [==============================] - 0s 7ms/step - loss: 5.6513 - mean_absolute_error: 5.6513 - val_loss: 5.0415 - val_mean_absolute_error: 5.0415
# Epoch 11/500
# 19/19 [==============================] - 0s 8ms/step - loss: 5.7495 - mean_absolute_error: 5.7495 - val_loss: 5.4668 - val_mean_absolute_error: 5.4668
# Epoch 12/500
# 19/19 [==============================] - 0s 3ms/step - loss: 4.3073 - mean_absolute_error: 4.3073 - val_loss: 4.2545 - val_mean_absolute_error: 4.2545
# Epoch 13/500
# 19/19 [==============================] - 0s 6ms/step - loss: 4.1289 - mean_absolute_error: 4.1289 - val_loss: 3.5916 - val_mean_absolute_error: 3.5916
# Epoch 14/500
# 19/19 [==============================] - 0s 7ms/step - loss: 3.2839 - mean_absolute_error: 3.2839 - val_loss: 3.6057 - val_mean_absolute_error: 3.6057
# Epoch 15/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.9707 - mean_absolute_error: 2.9707 - val_loss: 3.0904 - val_mean_absolute_error: 3.0904
# Epoch 16/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.9901 - mean_absolute_error: 2.9901 - val_loss: 3.4273 - val_mean_absolute_error: 3.4273
# Epoch 17/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3148 - mean_absolute_error: 3.3148 - val_loss: 3.5132 - val_mean_absolute_error: 3.5132
# Epoch 18/500
# 19/19 [==============================] - 0s 4ms/step - loss: 3.4760 - mean_absolute_error: 3.4760 - val_loss: 3.7781 - val_mean_absolute_error: 3.7781
# Epoch 19/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.3437 - mean_absolute_error: 3.3437 - val_loss: 4.2215 - val_mean_absolute_error: 4.2215
# Epoch 20/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.9822 - mean_absolute_error: 3.9822 - val_loss: 3.1100 - val_mean_absolute_error: 3.1100
# Epoch 21/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.7377 - mean_absolute_error: 2.7377 - val_loss: 2.7282 - val_mean_absolute_error: 2.7282
# Epoch 22/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.6463 - mean_absolute_error: 2.6463 - val_loss: 2.8277 - val_mean_absolute_error: 2.8277
# Epoch 23/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.0870 - mean_absolute_error: 3.0870 - val_loss: 3.0764 - val_mean_absolute_error: 3.0764
# Epoch 24/500
# 19/19 [==============================] - 0s 7ms/step - loss: 3.1350 - mean_absolute_error: 3.1350 - val_loss: 2.7211 - val_mean_absolute_error: 2.7211
# Epoch 25/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.9523 - mean_absolute_error: 2.9523 - val_loss: 3.7383 - val_mean_absolute_error: 3.7383
# Epoch 26/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.9042 - mean_absolute_error: 3.9042 - val_loss: 3.0011 - val_mean_absolute_error: 3.0011
# Epoch 27/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1446 - mean_absolute_error: 3.1446 - val_loss: 3.2405 - val_mean_absolute_error: 3.2405
# Epoch 28/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.7186 - mean_absolute_error: 2.7186 - val_loss: 2.5585 - val_mean_absolute_error: 2.5585
# Epoch 29/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.6783 - mean_absolute_error: 2.6783 - val_loss: 3.2616 - val_mean_absolute_error: 3.2616
# Epoch 30/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.8893 - mean_absolute_error: 2.8893 - val_loss: 2.5796 - val_mean_absolute_error: 2.5796
# Epoch 31/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.5786 - mean_absolute_error: 2.5786 - val_loss: 2.4909 - val_mean_absolute_error: 2.4909
# Epoch 32/500
# 19/19 [==============================] - 0s 6ms/step - loss: 3.7286 - mean_absolute_error: 3.7286 - val_loss: 2.6376 - val_mean_absolute_error: 2.6376
# Epoch 33/500
# 19/19 [==============================] - 0s 9ms/step - loss: 3.5477 - mean_absolute_error: 3.5477 - val_loss: 2.7740 - val_mean_absolute_error: 2.7740
# Epoch 34/500
# 19/19 [==============================] - 0s 4ms/step - loss: 3.0704 - mean_absolute_error: 3.0704 - val_loss: 2.9670 - val_mean_absolute_error: 2.9670
# Epoch 35/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1942 - mean_absolute_error: 3.1942 - val_loss: 4.0407 - val_mean_absolute_error: 4.0407
# Epoch 36/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.8600 - mean_absolute_error: 2.8600 - val_loss: 3.4222 - val_mean_absolute_error: 3.4222
# Epoch 37/500
# 19/19 [==============================] - 0s 7ms/step - loss: 3.5541 - mean_absolute_error: 3.5541 - val_loss: 2.3996 - val_mean_absolute_error: 2.3996
# Epoch 38/500
# 19/19 [==============================] - 0s 8ms/step - loss: 2.6426 - mean_absolute_error: 2.6426 - val_loss: 2.6162 - val_mean_absolute_error: 2.6162
# Epoch 39/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.3064 - mean_absolute_error: 2.3064 - val_loss: 2.4238 - val_mean_absolute_error: 2.4238
# Epoch 40/500
# 19/19 [==============================] - 0s 5ms/step - loss: 3.1563 - mean_absolute_error: 3.1563 - val_loss: 3.3325 - val_mean_absolute_error: 3.3325
# Epoch 41/500
# 19/19 [==============================] - 0s 6ms/step - loss: 3.0183 - mean_absolute_error: 3.0183 - val_loss: 3.0916 - val_mean_absolute_error: 3.0916
# Epoch 42/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.4926 - mean_absolute_error: 2.4926 - val_loss: 2.4043 - val_mean_absolute_error: 2.4043
# Epoch 43/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0908 - mean_absolute_error: 2.0908 - val_loss: 2.5090 - val_mean_absolute_error: 2.5090
# Epoch 44/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.2455 - mean_absolute_error: 2.2455 - val_loss: 2.4875 - val_mean_absolute_error: 2.4875
# Epoch 45/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0168 - mean_absolute_error: 2.0168 - val_loss: 2.4181 - val_mean_absolute_error: 2.4181
# Epoch 46/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0659 - mean_absolute_error: 2.0659 - val_loss: 2.4461 - val_mean_absolute_error: 2.4461
# Epoch 47/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.4201 - mean_absolute_error: 2.4201 - val_loss: 2.6599 - val_mean_absolute_error: 2.6599
# Epoch 48/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.3258 - mean_absolute_error: 2.3258 - val_loss: 2.4982 - val_mean_absolute_error: 2.4982
# Epoch 49/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.2481 - mean_absolute_error: 2.2481 - val_loss: 2.3546 - val_mean_absolute_error: 2.3546
# Epoch 50/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.9353 - mean_absolute_error: 1.9353 - val_loss: 2.3443 - val_mean_absolute_error: 2.3443
# Epoch 51/500
# 19/19 [==============================] - 0s 4ms/step - loss: 2.1748 - mean_absolute_error: 2.1748 - val_loss: 2.5079 - val_mean_absolute_error: 2.5079
# Epoch 52/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.1298 - mean_absolute_error: 2.1298 - val_loss: 2.4591 - val_mean_absolute_error: 2.4591
# Epoch 53/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.9313 - mean_absolute_error: 1.9313 - val_loss: 2.2818 - val_mean_absolute_error: 2.2818
# Epoch 54/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.9275 - mean_absolute_error: 1.9275 - val_loss: 2.7968 - val_mean_absolute_error: 2.7968
# Epoch 55/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.4107 - mean_absolute_error: 2.4107 - val_loss: 2.3751 - val_mean_absolute_error: 2.3751
# Epoch 56/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.1098 - mean_absolute_error: 2.1098 - val_loss: 2.4319 - val_mean_absolute_error: 2.4319
# Epoch 57/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.8961 - mean_absolute_error: 1.8961 - val_loss: 2.2626 - val_mean_absolute_error: 2.2626
# Epoch 58/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9583 - mean_absolute_error: 1.9583 - val_loss: 2.5460 - val_mean_absolute_error: 2.5460
# Epoch 59/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9646 - mean_absolute_error: 1.9646 - val_loss: 2.3813 - val_mean_absolute_error: 2.3813
# Epoch 60/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.7569 - mean_absolute_error: 1.7569 - val_loss: 2.3661 - val_mean_absolute_error: 2.3661
# Epoch 61/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.8123 - mean_absolute_error: 1.8123 - val_loss: 2.4661 - val_mean_absolute_error: 2.4661
# Epoch 62/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.1256 - mean_absolute_error: 2.1256 - val_loss: 2.4404 - val_mean_absolute_error: 2.4404
# Epoch 63/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.9895 - mean_absolute_error: 1.9895 - val_loss: 2.8224 - val_mean_absolute_error: 2.8224
# Epoch 64/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.5589 - mean_absolute_error: 2.5589 - val_loss: 2.6050 - val_mean_absolute_error: 2.6050
# Epoch 65/500
# 19/19 [==============================] - 0s 7ms/step - loss: 2.1326 - mean_absolute_error: 2.1326 - val_loss: 2.6119 - val_mean_absolute_error: 2.6119
# Epoch 66/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.2585 - mean_absolute_error: 2.2585 - val_loss: 2.5454 - val_mean_absolute_error: 2.5454
# Epoch 67/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0371 - mean_absolute_error: 2.0371 - val_loss: 2.5935 - val_mean_absolute_error: 2.5935
# Epoch 68/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.0582 - mean_absolute_error: 2.0582 - val_loss: 2.3237 - val_mean_absolute_error: 2.3237
# Epoch 69/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.8131 - mean_absolute_error: 1.8131 - val_loss: 2.5574 - val_mean_absolute_error: 2.5574
# Epoch 70/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0450 - mean_absolute_error: 2.0450 - val_loss: 2.3059 - val_mean_absolute_error: 2.3059
# Epoch 71/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6894 - mean_absolute_error: 1.6894 - val_loss: 2.3013 - val_mean_absolute_error: 2.3013
# Epoch 72/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.7570 - mean_absolute_error: 1.7570 - val_loss: 2.3456 - val_mean_absolute_error: 2.3456
# Epoch 73/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.8104 - mean_absolute_error: 1.8104 - val_loss: 2.3522 - val_mean_absolute_error: 2.3522
# Epoch 74/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.9417 - mean_absolute_error: 1.9417 - val_loss: 2.3448 - val_mean_absolute_error: 2.3448
# Epoch 75/500
# 19/19 [==============================] - 0s 6ms/step - loss: 2.0576 - mean_absolute_error: 2.0576 - val_loss: 2.3323 - val_mean_absolute_error: 2.3323
# Epoch 76/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.8590 - mean_absolute_error: 1.8590 - val_loss: 2.4799 - val_mean_absolute_error: 2.4799
# Epoch 77/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.9070 - mean_absolute_error: 1.9070 - val_loss: 2.4674 - val_mean_absolute_error: 2.4674
# Epoch 78/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6684 - mean_absolute_error: 1.6684 - val_loss: 2.4110 - val_mean_absolute_error: 2.4110
# Epoch 79/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6123 - mean_absolute_error: 1.6123 - val_loss: 2.3717 - val_mean_absolute_error: 2.3717
# Epoch 80/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.7231 - mean_absolute_error: 1.7231 - val_loss: 2.4742 - val_mean_absolute_error: 2.4742
# Epoch 81/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.6925 - mean_absolute_error: 1.6925 - val_loss: 2.4856 - val_mean_absolute_error: 2.4856
# Epoch 82/500
# 19/19 [==============================] - 0s 5ms/step - loss: 2.1466 - mean_absolute_error: 2.1466 - val_loss: 2.4161 - val_mean_absolute_error: 2.4161
# Epoch 83/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.8106 - mean_absolute_error: 1.8106 - val_loss: 2.4388 - val_mean_absolute_error: 2.4388
# Epoch 84/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.7439 - mean_absolute_error: 1.7439 - val_loss: 2.3054 - val_mean_absolute_error: 2.3054
# Epoch 85/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.7851 - mean_absolute_error: 1.7851 - val_loss: 2.3340 - val_mean_absolute_error: 2.3340
# Epoch 86/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6210 - mean_absolute_error: 1.6210 - val_loss: 2.2837 - val_mean_absolute_error: 2.2837
# Epoch 87/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6728 - mean_absolute_error: 1.6728 - val_loss: 2.3533 - val_mean_absolute_error: 2.3533
# Epoch 88/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6780 - mean_absolute_error: 1.6780 - val_loss: 2.4021 - val_mean_absolute_error: 2.4021
# Epoch 89/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.6871 - mean_absolute_error: 1.6871 - val_loss: 2.3100 - val_mean_absolute_error: 2.3100
# Epoch 90/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6331 - mean_absolute_error: 1.6331 - val_loss: 2.2129 - val_mean_absolute_error: 2.2129
# Epoch 91/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.6092 - mean_absolute_error: 1.6092 - val_loss: 2.3462 - val_mean_absolute_error: 2.3462
# Epoch 92/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5461 - mean_absolute_error: 1.5461 - val_loss: 2.2735 - val_mean_absolute_error: 2.2735
# Epoch 93/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5380 - mean_absolute_error: 1.5380 - val_loss: 2.2090 - val_mean_absolute_error: 2.2090
# Epoch 94/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.5791 - mean_absolute_error: 1.5791 - val_loss: 2.3235 - val_mean_absolute_error: 2.3235
# Epoch 95/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5639 - mean_absolute_error: 1.5639 - val_loss: 2.3057 - val_mean_absolute_error: 2.3057
# Epoch 96/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5121 - mean_absolute_error: 1.5121 - val_loss: 2.3682 - val_mean_absolute_error: 2.3682
# Epoch 97/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4989 - mean_absolute_error: 1.4989 - val_loss: 2.3438 - val_mean_absolute_error: 2.3438
# Epoch 98/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4929 - mean_absolute_error: 1.4929 - val_loss: 2.2968 - val_mean_absolute_error: 2.2968
# Epoch 99/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5583 - mean_absolute_error: 1.5583 - val_loss: 2.3984 - val_mean_absolute_error: 2.3984
# Epoch 100/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.5281 - mean_absolute_error: 1.5281 - val_loss: 2.3474 - val_mean_absolute_error: 2.3474
# Epoch 101/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.5883 - mean_absolute_error: 1.5883 - val_loss: 2.3338 - val_mean_absolute_error: 2.3338
# Epoch 102/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.5077 - mean_absolute_error: 1.5077 - val_loss: 2.2945 - val_mean_absolute_error: 2.2945
# Epoch 103/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5563 - mean_absolute_error: 1.5563 - val_loss: 2.5925 - val_mean_absolute_error: 2.5925
# Epoch 104/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.7330 - mean_absolute_error: 1.7330 - val_loss: 2.3728 - val_mean_absolute_error: 2.3728
# Epoch 105/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5855 - mean_absolute_error: 1.5855 - val_loss: 2.4258 - val_mean_absolute_error: 2.4258
# Epoch 106/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.6822 - mean_absolute_error: 1.6822 - val_loss: 2.2547 - val_mean_absolute_error: 2.2547
# Epoch 107/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.5615 - mean_absolute_error: 1.5615 - val_loss: 2.3682 - val_mean_absolute_error: 2.3682
# Epoch 108/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4824 - mean_absolute_error: 1.4824 - val_loss: 2.3398 - val_mean_absolute_error: 2.3398
# Epoch 109/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5212 - mean_absolute_error: 1.5212 - val_loss: 2.3258 - val_mean_absolute_error: 2.3258
# Epoch 110/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4845 - mean_absolute_error: 1.4845 - val_loss: 2.2492 - val_mean_absolute_error: 2.2492
# Epoch 111/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.5300 - mean_absolute_error: 1.5300 - val_loss: 2.3419 - val_mean_absolute_error: 2.3419
# Epoch 112/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4957 - mean_absolute_error: 1.4957 - val_loss: 2.2762 - val_mean_absolute_error: 2.2762
# Epoch 113/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.5135 - mean_absolute_error: 1.5135 - val_loss: 2.3480 - val_mean_absolute_error: 2.3480
# Epoch 114/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4603 - mean_absolute_error: 1.4603 - val_loss: 2.3882 - val_mean_absolute_error: 2.3882
# Epoch 115/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4845 - mean_absolute_error: 1.4845 - val_loss: 2.3475 - val_mean_absolute_error: 2.3475
# Epoch 116/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.4556 - mean_absolute_error: 1.4556 - val_loss: 2.3556 - val_mean_absolute_error: 2.3556
# Epoch 117/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4436 - mean_absolute_error: 1.4436 - val_loss: 2.3369 - val_mean_absolute_error: 2.3369
# Epoch 118/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4326 - mean_absolute_error: 1.4326 - val_loss: 2.4100 - val_mean_absolute_error: 2.4100
# Epoch 119/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4807 - mean_absolute_error: 1.4807 - val_loss: 2.2582 - val_mean_absolute_error: 2.2582
# Epoch 120/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.5094 - mean_absolute_error: 1.5094 - val_loss: 2.3079 - val_mean_absolute_error: 2.3079
# Epoch 121/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.4312 - mean_absolute_error: 1.4312 - val_loss: 2.2582 - val_mean_absolute_error: 2.2582
# Epoch 122/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3855 - mean_absolute_error: 1.3855 - val_loss: 2.2907 - val_mean_absolute_error: 2.2907
# Epoch 123/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4218 - mean_absolute_error: 1.4218 - val_loss: 2.2530 - val_mean_absolute_error: 2.2530
# Epoch 124/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4544 - mean_absolute_error: 1.4544 - val_loss: 2.3686 - val_mean_absolute_error: 2.3686
# Epoch 125/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4115 - mean_absolute_error: 1.4115 - val_loss: 2.2598 - val_mean_absolute_error: 2.2598
# Epoch 126/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4170 - mean_absolute_error: 1.4170 - val_loss: 2.4076 - val_mean_absolute_error: 2.4076
# Epoch 127/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3888 - mean_absolute_error: 1.3888 - val_loss: 2.2918 - val_mean_absolute_error: 2.2918
# Epoch 128/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4341 - mean_absolute_error: 1.4341 - val_loss: 2.2702 - val_mean_absolute_error: 2.2702
# Epoch 129/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4428 - mean_absolute_error: 1.4428 - val_loss: 2.2173 - val_mean_absolute_error: 2.2173
# Epoch 130/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4049 - mean_absolute_error: 1.4049 - val_loss: 2.3295 - val_mean_absolute_error: 2.3295
# Epoch 131/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4145 - mean_absolute_error: 1.4145 - val_loss: 2.2126 - val_mean_absolute_error: 2.2126
# Epoch 132/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.4039 - mean_absolute_error: 1.4039 - val_loss: 2.3617 - val_mean_absolute_error: 2.3617
# Epoch 133/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3881 - mean_absolute_error: 1.3881 - val_loss: 2.2495 - val_mean_absolute_error: 2.2495
# Epoch 134/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.3607 - mean_absolute_error: 1.3607 - val_loss: 2.2845 - val_mean_absolute_error: 2.2845
# Epoch 135/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4082 - mean_absolute_error: 1.4082 - val_loss: 2.2063 - val_mean_absolute_error: 2.2063
# Epoch 136/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3624 - mean_absolute_error: 1.3624 - val_loss: 2.3614 - val_mean_absolute_error: 2.3614
# Epoch 137/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3987 - mean_absolute_error: 1.3987 - val_loss: 2.2282 - val_mean_absolute_error: 2.2282
# Epoch 138/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3162 - mean_absolute_error: 1.3162 - val_loss: 2.2338 - val_mean_absolute_error: 2.2338
# Epoch 139/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3471 - mean_absolute_error: 1.3471 - val_loss: 2.2425 - val_mean_absolute_error: 2.2425
# Epoch 140/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3681 - mean_absolute_error: 1.3681 - val_loss: 2.1913 - val_mean_absolute_error: 2.1913
# Epoch 141/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3360 - mean_absolute_error: 1.3360 - val_loss: 2.2910 - val_mean_absolute_error: 2.2910
# Epoch 142/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3253 - mean_absolute_error: 1.3253 - val_loss: 2.2526 - val_mean_absolute_error: 2.2526
# Epoch 143/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.5320 - mean_absolute_error: 1.5320 - val_loss: 2.3487 - val_mean_absolute_error: 2.3487
# Epoch 144/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.4639 - mean_absolute_error: 1.4639 - val_loss: 2.2559 - val_mean_absolute_error: 2.2559
# Epoch 145/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.4222 - mean_absolute_error: 1.4222 - val_loss: 2.2884 - val_mean_absolute_error: 2.2884
# Epoch 146/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3943 - mean_absolute_error: 1.3943 - val_loss: 2.3597 - val_mean_absolute_error: 2.3597
# Epoch 147/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3026 - mean_absolute_error: 1.3026 - val_loss: 2.2342 - val_mean_absolute_error: 2.2342
# Epoch 148/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2686 - mean_absolute_error: 1.2686 - val_loss: 2.2621 - val_mean_absolute_error: 2.2621
# Epoch 149/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3096 - mean_absolute_error: 1.3096 - val_loss: 2.2577 - val_mean_absolute_error: 2.2577
# Epoch 150/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3054 - mean_absolute_error: 1.3054 - val_loss: 2.2540 - val_mean_absolute_error: 2.2540
# Epoch 151/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3011 - mean_absolute_error: 1.3011 - val_loss: 2.3064 - val_mean_absolute_error: 2.3064
# Epoch 152/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3171 - mean_absolute_error: 1.3171 - val_loss: 2.3938 - val_mean_absolute_error: 2.3938
# Epoch 153/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3018 - mean_absolute_error: 1.3018 - val_loss: 2.2678 - val_mean_absolute_error: 2.2678
# Epoch 154/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2748 - mean_absolute_error: 1.2748 - val_loss: 2.3131 - val_mean_absolute_error: 2.3131
# Epoch 155/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2897 - mean_absolute_error: 1.2897 - val_loss: 2.2714 - val_mean_absolute_error: 2.2714
# Epoch 156/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2558 - mean_absolute_error: 1.2558 - val_loss: 2.2051 - val_mean_absolute_error: 2.2051
# Epoch 157/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3127 - mean_absolute_error: 1.3127 - val_loss: 2.2557 - val_mean_absolute_error: 2.2557
# Epoch 158/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2317 - mean_absolute_error: 1.2317 - val_loss: 2.2856 - val_mean_absolute_error: 2.2856
# Epoch 159/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2404 - mean_absolute_error: 1.2404 - val_loss: 2.1897 - val_mean_absolute_error: 2.1897
# Epoch 160/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2349 - mean_absolute_error: 1.2349 - val_loss: 2.2973 - val_mean_absolute_error: 2.2973
# Epoch 161/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2308 - mean_absolute_error: 1.2308 - val_loss: 2.2024 - val_mean_absolute_error: 2.2024
# Epoch 162/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3039 - mean_absolute_error: 1.3039 - val_loss: 2.2472 - val_mean_absolute_error: 2.2472
# Epoch 163/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3290 - mean_absolute_error: 1.3290 - val_loss: 2.2193 - val_mean_absolute_error: 2.2193
# Epoch 164/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2772 - mean_absolute_error: 1.2772 - val_loss: 2.2865 - val_mean_absolute_error: 2.2865
# Epoch 165/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2677 - mean_absolute_error: 1.2677 - val_loss: 2.2343 - val_mean_absolute_error: 2.2343
# Epoch 166/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2613 - mean_absolute_error: 1.2613 - val_loss: 2.2861 - val_mean_absolute_error: 2.2861
# Epoch 167/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2570 - mean_absolute_error: 1.2570 - val_loss: 2.3226 - val_mean_absolute_error: 2.3226
# Epoch 168/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2825 - mean_absolute_error: 1.2825 - val_loss: 2.2267 - val_mean_absolute_error: 2.2267
# Epoch 169/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2044 - mean_absolute_error: 1.2044 - val_loss: 2.3470 - val_mean_absolute_error: 2.3470
# Epoch 170/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2592 - mean_absolute_error: 1.2592 - val_loss: 2.4296 - val_mean_absolute_error: 2.4296
# Epoch 171/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2392 - mean_absolute_error: 1.2392 - val_loss: 2.2317 - val_mean_absolute_error: 2.2317
# Epoch 172/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2290 - mean_absolute_error: 1.2290 - val_loss: 2.2579 - val_mean_absolute_error: 2.2579
# Epoch 173/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2227 - mean_absolute_error: 1.2227 - val_loss: 2.2036 - val_mean_absolute_error: 2.2036
# Epoch 174/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2040 - mean_absolute_error: 1.2040 - val_loss: 2.2016 - val_mean_absolute_error: 2.2016
# Epoch 175/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2018 - mean_absolute_error: 1.2018 - val_loss: 2.2586 - val_mean_absolute_error: 2.2586
# Epoch 176/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2274 - mean_absolute_error: 1.2274 - val_loss: 2.3040 - val_mean_absolute_error: 2.3040
# Epoch 177/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2341 - mean_absolute_error: 1.2341 - val_loss: 2.2025 - val_mean_absolute_error: 2.2025
# Epoch 178/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1980 - mean_absolute_error: 1.1980 - val_loss: 2.2970 - val_mean_absolute_error: 2.2970
# Epoch 179/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2385 - mean_absolute_error: 1.2385 - val_loss: 2.3215 - val_mean_absolute_error: 2.3215
# Epoch 180/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2273 - mean_absolute_error: 1.2273 - val_loss: 2.2311 - val_mean_absolute_error: 2.2311
# Epoch 181/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2436 - mean_absolute_error: 1.2436 - val_loss: 2.2673 - val_mean_absolute_error: 2.2673
# Epoch 182/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2321 - mean_absolute_error: 1.2321 - val_loss: 2.1703 - val_mean_absolute_error: 2.1703
# Epoch 183/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2191 - mean_absolute_error: 1.2191 - val_loss: 2.3043 - val_mean_absolute_error: 2.3043
# Epoch 184/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1841 - mean_absolute_error: 1.1841 - val_loss: 2.2851 - val_mean_absolute_error: 2.2851
# Epoch 185/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2722 - mean_absolute_error: 1.2722 - val_loss: 2.3319 - val_mean_absolute_error: 2.3319
# Epoch 186/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1967 - mean_absolute_error: 1.1967 - val_loss: 2.2252 - val_mean_absolute_error: 2.2252
# Epoch 187/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1827 - mean_absolute_error: 1.1827 - val_loss: 2.2711 - val_mean_absolute_error: 2.2711
# Epoch 188/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1696 - mean_absolute_error: 1.1696 - val_loss: 2.2387 - val_mean_absolute_error: 2.2387
# Epoch 189/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1774 - mean_absolute_error: 1.1774 - val_loss: 2.2648 - val_mean_absolute_error: 2.2648
# Epoch 190/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1614 - mean_absolute_error: 1.1614 - val_loss: 2.2650 - val_mean_absolute_error: 2.2650
# Epoch 191/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1932 - mean_absolute_error: 1.1932 - val_loss: 2.2131 - val_mean_absolute_error: 2.2131
# Epoch 192/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2266 - mean_absolute_error: 1.2266 - val_loss: 2.2938 - val_mean_absolute_error: 2.2938
# Epoch 193/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.2044 - mean_absolute_error: 1.2044 - val_loss: 2.2678 - val_mean_absolute_error: 2.2678
# Epoch 194/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1548 - mean_absolute_error: 1.1548 - val_loss: 2.2761 - val_mean_absolute_error: 2.2761
# Epoch 195/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1913 - mean_absolute_error: 1.1913 - val_loss: 2.2877 - val_mean_absolute_error: 2.2877
# Epoch 196/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1739 - mean_absolute_error: 1.1739 - val_loss: 2.2593 - val_mean_absolute_error: 2.2593
# Epoch 197/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1374 - mean_absolute_error: 1.1374 - val_loss: 2.2234 - val_mean_absolute_error: 2.2234
# Epoch 198/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2477 - mean_absolute_error: 1.2477 - val_loss: 2.2511 - val_mean_absolute_error: 2.2511
# Epoch 199/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1893 - mean_absolute_error: 1.1893 - val_loss: 2.2522 - val_mean_absolute_error: 2.2522
# Epoch 200/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2601 - mean_absolute_error: 1.2601 - val_loss: 2.2563 - val_mean_absolute_error: 2.2563
# Epoch 201/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2182 - mean_absolute_error: 1.2182 - val_loss: 2.2689 - val_mean_absolute_error: 2.2689
# Epoch 202/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2085 - mean_absolute_error: 1.2085 - val_loss: 2.2738 - val_mean_absolute_error: 2.2738
# Epoch 203/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1629 - mean_absolute_error: 1.1629 - val_loss: 2.2514 - val_mean_absolute_error: 2.2514
# Epoch 204/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2178 - mean_absolute_error: 1.2178 - val_loss: 2.2512 - val_mean_absolute_error: 2.2512
# Epoch 205/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.3270 - mean_absolute_error: 1.3270 - val_loss: 2.3027 - val_mean_absolute_error: 2.3027
# Epoch 206/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2156 - mean_absolute_error: 1.2156 - val_loss: 2.2544 - val_mean_absolute_error: 2.2544
# Epoch 207/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1605 - mean_absolute_error: 1.1605 - val_loss: 2.3659 - val_mean_absolute_error: 2.3659
# Epoch 208/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2820 - mean_absolute_error: 1.2820 - val_loss: 2.2828 - val_mean_absolute_error: 2.2828
# Epoch 209/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1519 - mean_absolute_error: 1.1519 - val_loss: 2.2095 - val_mean_absolute_error: 2.2095
# Epoch 210/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1916 - mean_absolute_error: 1.1916 - val_loss: 2.2763 - val_mean_absolute_error: 2.2763
# Epoch 211/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1345 - mean_absolute_error: 1.1345 - val_loss: 2.2551 - val_mean_absolute_error: 2.2551
# Epoch 212/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1439 - mean_absolute_error: 1.1439 - val_loss: 2.2394 - val_mean_absolute_error: 2.2394
# Epoch 213/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2133 - mean_absolute_error: 1.2133 - val_loss: 2.1879 - val_mean_absolute_error: 2.1879
# Epoch 214/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1312 - mean_absolute_error: 1.1312 - val_loss: 2.2400 - val_mean_absolute_error: 2.2400
# Epoch 215/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1223 - mean_absolute_error: 1.1223 - val_loss: 2.3001 - val_mean_absolute_error: 2.3001
# Epoch 216/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2271 - mean_absolute_error: 1.2271 - val_loss: 2.3510 - val_mean_absolute_error: 2.3510
# Epoch 217/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.3169 - mean_absolute_error: 1.3169 - val_loss: 2.4076 - val_mean_absolute_error: 2.4076
# Epoch 218/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1577 - mean_absolute_error: 1.1577 - val_loss: 2.2851 - val_mean_absolute_error: 2.2851
# Epoch 219/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1408 - mean_absolute_error: 1.1408 - val_loss: 2.2375 - val_mean_absolute_error: 2.2375
# Epoch 220/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1540 - mean_absolute_error: 1.1540 - val_loss: 2.3182 - val_mean_absolute_error: 2.3182
# Epoch 221/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1181 - mean_absolute_error: 1.1181 - val_loss: 2.3667 - val_mean_absolute_error: 2.3667
# Epoch 222/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1768 - mean_absolute_error: 1.1768 - val_loss: 2.2862 - val_mean_absolute_error: 2.2862
# Epoch 223/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1147 - mean_absolute_error: 1.1147 - val_loss: 2.2678 - val_mean_absolute_error: 2.2678
# Epoch 224/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1011 - mean_absolute_error: 1.1011 - val_loss: 2.2527 - val_mean_absolute_error: 2.2527
# Epoch 225/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0935 - mean_absolute_error: 1.0935 - val_loss: 2.2469 - val_mean_absolute_error: 2.2469
# Epoch 226/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1113 - mean_absolute_error: 1.1113 - val_loss: 2.2717 - val_mean_absolute_error: 2.2717
# Epoch 227/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.2081 - mean_absolute_error: 1.2081 - val_loss: 2.2770 - val_mean_absolute_error: 2.2770
# Epoch 228/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1270 - mean_absolute_error: 1.1270 - val_loss: 2.2881 - val_mean_absolute_error: 2.2881
# Epoch 229/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1122 - mean_absolute_error: 1.1122 - val_loss: 2.3166 - val_mean_absolute_error: 2.3166
# Epoch 230/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0792 - mean_absolute_error: 1.0792 - val_loss: 2.1844 - val_mean_absolute_error: 2.1844
# Epoch 231/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0743 - mean_absolute_error: 1.0743 - val_loss: 2.2938 - val_mean_absolute_error: 2.2938
# Epoch 232/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1360 - mean_absolute_error: 1.1360 - val_loss: 2.1860 - val_mean_absolute_error: 2.1860
# Epoch 233/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1003 - mean_absolute_error: 1.1003 - val_loss: 2.2663 - val_mean_absolute_error: 2.2663
# Epoch 234/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1093 - mean_absolute_error: 1.1093 - val_loss: 2.2486 - val_mean_absolute_error: 2.2486
# Epoch 235/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1955 - mean_absolute_error: 1.1955 - val_loss: 2.2094 - val_mean_absolute_error: 2.2094
# Epoch 236/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1313 - mean_absolute_error: 1.1313 - val_loss: 2.2598 - val_mean_absolute_error: 2.2598
# Epoch 237/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1664 - mean_absolute_error: 1.1664 - val_loss: 2.2114 - val_mean_absolute_error: 2.2114
# Epoch 238/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1140 - mean_absolute_error: 1.1140 - val_loss: 2.1872 - val_mean_absolute_error: 2.1872
# Epoch 239/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.1092 - mean_absolute_error: 1.1092 - val_loss: 2.2861 - val_mean_absolute_error: 2.2861
# Epoch 240/500
# 19/19 [==============================] - 0s 3ms/step - loss: 1.0796 - mean_absolute_error: 1.0796 - val_loss: 2.2705 - val_mean_absolute_error: 2.2705
# Epoch 241/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0751 - mean_absolute_error: 1.0751 - val_loss: 2.2504 - val_mean_absolute_error: 2.2504
# Epoch 242/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0188 - mean_absolute_error: 1.0188 - val_loss: 2.2735 - val_mean_absolute_error: 2.2735
# Epoch 243/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.0612 - mean_absolute_error: 1.0612 - val_loss: 2.2385 - val_mean_absolute_error: 2.2385
# Epoch 244/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0334 - mean_absolute_error: 1.0334 - val_loss: 2.2418 - val_mean_absolute_error: 2.2418
# Epoch 245/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.0636 - mean_absolute_error: 1.0636 - val_loss: 2.2671 - val_mean_absolute_error: 2.2671
# Epoch 246/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1079 - mean_absolute_error: 1.1079 - val_loss: 2.2317 - val_mean_absolute_error: 2.2317
# Epoch 247/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0737 - mean_absolute_error: 1.0737 - val_loss: 2.1648 - val_mean_absolute_error: 2.1648
# Epoch 248/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.2423 - mean_absolute_error: 1.2423 - val_loss: 2.2848 - val_mean_absolute_error: 2.2848
# Epoch 249/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0829 - mean_absolute_error: 1.0829 - val_loss: 2.3420 - val_mean_absolute_error: 2.3420
# Epoch 250/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.0550 - mean_absolute_error: 1.0550 - val_loss: 2.2562 - val_mean_absolute_error: 2.2562
# Epoch 251/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1897 - mean_absolute_error: 1.1897 - val_loss: 2.2311 - val_mean_absolute_error: 2.2311
# Epoch 252/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0634 - mean_absolute_error: 1.0634 - val_loss: 2.2830 - val_mean_absolute_error: 2.2830
# Epoch 253/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1008 - mean_absolute_error: 1.1008 - val_loss: 2.2740 - val_mean_absolute_error: 2.2740
# Epoch 254/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0708 - mean_absolute_error: 1.0708 - val_loss: 2.2293 - val_mean_absolute_error: 2.2293
# Epoch 255/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0234 - mean_absolute_error: 1.0234 - val_loss: 2.2639 - val_mean_absolute_error: 2.2639
# Epoch 256/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0630 - mean_absolute_error: 1.0630 - val_loss: 2.3113 - val_mean_absolute_error: 2.3113
# Epoch 257/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0740 - mean_absolute_error: 1.0740 - val_loss: 2.2510 - val_mean_absolute_error: 2.2510
# Epoch 258/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0702 - mean_absolute_error: 1.0702 - val_loss: 2.2525 - val_mean_absolute_error: 2.2525
# Epoch 259/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0023 - mean_absolute_error: 1.0023 - val_loss: 2.2334 - val_mean_absolute_error: 2.2334
# Epoch 260/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1597 - mean_absolute_error: 1.1597 - val_loss: 2.2158 - val_mean_absolute_error: 2.2158
# Epoch 261/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0959 - mean_absolute_error: 1.0959 - val_loss: 2.2685 - val_mean_absolute_error: 2.2685
# Epoch 262/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1538 - mean_absolute_error: 1.1538 - val_loss: 2.2256 - val_mean_absolute_error: 2.2256
# Epoch 263/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1585 - mean_absolute_error: 1.1585 - val_loss: 2.1676 - val_mean_absolute_error: 2.1676
# Epoch 264/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0393 - mean_absolute_error: 1.0393 - val_loss: 2.2451 - val_mean_absolute_error: 2.2451
# Epoch 265/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1747 - mean_absolute_error: 1.1747 - val_loss: 2.2842 - val_mean_absolute_error: 2.2842
# Epoch 266/500
# 19/19 [==============================] - 0s 4ms/step - loss: 1.1675 - mean_absolute_error: 1.1675 - val_loss: 2.2973 - val_mean_absolute_error: 2.2973
# Epoch 267/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.1107 - mean_absolute_error: 1.1107 - val_loss: 2.2106 - val_mean_absolute_error: 2.2106
# Epoch 268/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0958 - mean_absolute_error: 1.0958 - val_loss: 2.2728 - val_mean_absolute_error: 2.2728
# Epoch 269/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0649 - mean_absolute_error: 1.0649 - val_loss: 2.2372 - val_mean_absolute_error: 2.2372
# Epoch 270/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0371 - mean_absolute_error: 1.0371 - val_loss: 2.2796 - val_mean_absolute_error: 2.2796
# Epoch 271/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1791 - mean_absolute_error: 1.1791 - val_loss: 2.1894 - val_mean_absolute_error: 2.1894
# Epoch 272/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0623 - mean_absolute_error: 1.0623 - val_loss: 2.3060 - val_mean_absolute_error: 2.3060
# Epoch 273/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0442 - mean_absolute_error: 1.0442 - val_loss: 2.2087 - val_mean_absolute_error: 2.2087
# Epoch 274/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1075 - mean_absolute_error: 1.1075 - val_loss: 2.3381 - val_mean_absolute_error: 2.3381
# Epoch 275/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0610 - mean_absolute_error: 1.0610 - val_loss: 2.2836 - val_mean_absolute_error: 2.2836
# Epoch 276/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0376 - mean_absolute_error: 1.0376 - val_loss: 2.1924 - val_mean_absolute_error: 2.1924
# Epoch 277/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0583 - mean_absolute_error: 1.0583 - val_loss: 2.3991 - val_mean_absolute_error: 2.3991
# Epoch 278/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0801 - mean_absolute_error: 1.0801 - val_loss: 2.2609 - val_mean_absolute_error: 2.2609
# Epoch 279/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0255 - mean_absolute_error: 1.0255 - val_loss: 2.3039 - val_mean_absolute_error: 2.3039
# Epoch 280/500
# 19/19 [==============================] - 0s 7ms/step - loss: 1.0396 - mean_absolute_error: 1.0396 - val_loss: 2.2367 - val_mean_absolute_error: 2.2367
# Epoch 281/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0049 - mean_absolute_error: 1.0049 - val_loss: 2.2752 - val_mean_absolute_error: 2.2752
# Epoch 282/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0368 - mean_absolute_error: 1.0368 - val_loss: 2.2606 - val_mean_absolute_error: 2.2606
# Epoch 283/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0038 - mean_absolute_error: 1.0038 - val_loss: 2.2662 - val_mean_absolute_error: 2.2662
# Epoch 284/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0029 - mean_absolute_error: 1.0029 - val_loss: 2.2606 - val_mean_absolute_error: 2.2606
# Epoch 285/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0110 - mean_absolute_error: 1.0110 - val_loss: 2.1955 - val_mean_absolute_error: 2.1955
# Epoch 286/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0030 - mean_absolute_error: 1.0030 - val_loss: 2.2681 - val_mean_absolute_error: 2.2681
# Epoch 287/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9906 - mean_absolute_error: 0.9906 - val_loss: 2.1971 - val_mean_absolute_error: 2.1971
# Epoch 288/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0197 - mean_absolute_error: 1.0197 - val_loss: 2.2700 - val_mean_absolute_error: 2.2700
# Epoch 289/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0174 - mean_absolute_error: 1.0174 - val_loss: 2.2442 - val_mean_absolute_error: 2.2442
# Epoch 290/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.9899 - mean_absolute_error: 0.9899 - val_loss: 2.2868 - val_mean_absolute_error: 2.2868
# Epoch 291/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0061 - mean_absolute_error: 1.0061 - val_loss: 2.2001 - val_mean_absolute_error: 2.2001
# Epoch 292/500
# ...
# Epoch 405/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8174 - mean_absolute_error: 0.8174 - val_loss: 2.2761 - val_mean_absolute_error: 2.2761
# Epoch 406/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8393 - mean_absolute_error: 0.8393 - val_loss: 2.1655 - val_mean_absolute_error: 2.1655
# Epoch 407/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8260 - mean_absolute_error: 0.8260 - val_loss: 2.1851 - val_mean_absolute_error: 2.1851
# Epoch 408/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8261 - mean_absolute_error: 0.8261 - val_loss: 2.1455 - val_mean_absolute_error: 2.1455
# Epoch 409/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8230 - mean_absolute_error: 0.8230 - val_loss: 2.2121 - val_mean_absolute_error: 2.2121
# Epoch 410/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8166 - mean_absolute_error: 0.8166 - val_loss: 2.2240 - val_mean_absolute_error: 2.2240
# Epoch 411/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7905 - mean_absolute_error: 0.7905 - val_loss: 2.1597 - val_mean_absolute_error: 2.1597
# Epoch 412/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8059 - mean_absolute_error: 0.8059 - val_loss: 2.2053 - val_mean_absolute_error: 2.2053
# Epoch 413/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7962 - mean_absolute_error: 0.7962 - val_loss: 2.2032 - val_mean_absolute_error: 2.2032
# Epoch 414/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7851 - mean_absolute_error: 0.7851 - val_loss: 2.2603 - val_mean_absolute_error: 2.2603
# Epoch 415/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8743 - mean_absolute_error: 0.8743 - val_loss: 2.1768 - val_mean_absolute_error: 2.1768
# Epoch 416/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7872 - mean_absolute_error: 0.7872 - val_loss: 2.2106 - val_mean_absolute_error: 2.2106
# Epoch 417/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8023 - mean_absolute_error: 0.8023 - val_loss: 2.1701 - val_mean_absolute_error: 2.1701
# Epoch 418/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7968 - mean_absolute_error: 0.7968 - val_loss: 2.3292 - val_mean_absolute_error: 2.3292
# Epoch 419/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8428 - mean_absolute_error: 0.8428 - val_loss: 2.1902 - val_mean_absolute_error: 2.1902
# Epoch 420/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8439 - mean_absolute_error: 0.8439 - val_loss: 2.3541 - val_mean_absolute_error: 2.3541
# Epoch 421/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8353 - mean_absolute_error: 0.8353 - val_loss: 2.2117 - val_mean_absolute_error: 2.2117
# Epoch 422/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8292 - mean_absolute_error: 0.8292 - val_loss: 2.1964 - val_mean_absolute_error: 2.1964
# Epoch 423/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9597 - mean_absolute_error: 0.9597 - val_loss: 2.2889 - val_mean_absolute_error: 2.2889
# Epoch 424/500
# 19/19 [==============================] - 0s 5ms/step - loss: 1.0917 - mean_absolute_error: 1.0917 - val_loss: 2.3033 - val_mean_absolute_error: 2.3033
# Epoch 425/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.8624 - mean_absolute_error: 0.8624 - val_loss: 2.1831 - val_mean_absolute_error: 2.1831
# Epoch 426/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8078 - mean_absolute_error: 0.8078 - val_loss: 2.1716 - val_mean_absolute_error: 2.1716
# Epoch 427/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8242 - mean_absolute_error: 0.8242 - val_loss: 2.1953 - val_mean_absolute_error: 2.1953
# Epoch 428/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7716 - mean_absolute_error: 0.7716 - val_loss: 2.2412 - val_mean_absolute_error: 2.2412
# Epoch 429/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7840 - mean_absolute_error: 0.7840 - val_loss: 2.2410 - val_mean_absolute_error: 2.2410
# Epoch 430/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7798 - mean_absolute_error: 0.7798 - val_loss: 2.1682 - val_mean_absolute_error: 2.1682
# Epoch 431/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7711 - mean_absolute_error: 0.7711 - val_loss: 2.2424 - val_mean_absolute_error: 2.2424
# Epoch 432/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7856 - mean_absolute_error: 0.7856 - val_loss: 2.1690 - val_mean_absolute_error: 2.1690
# Epoch 433/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7927 - mean_absolute_error: 0.7927 - val_loss: 2.2445 - val_mean_absolute_error: 2.2445
# Epoch 434/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8225 - mean_absolute_error: 0.8225 - val_loss: 2.1978 - val_mean_absolute_error: 2.1978
# Epoch 435/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8081 - mean_absolute_error: 0.8081 - val_loss: 2.2204 - val_mean_absolute_error: 2.2204
# Epoch 436/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7652 - mean_absolute_error: 0.7652 - val_loss: 2.1836 - val_mean_absolute_error: 2.1836
# Epoch 437/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7760 - mean_absolute_error: 0.7760 - val_loss: 2.1871 - val_mean_absolute_error: 2.1871
# Epoch 438/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7412 - mean_absolute_error: 0.7412 - val_loss: 2.1833 - val_mean_absolute_error: 2.1833
# Epoch 439/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7681 - mean_absolute_error: 0.7681 - val_loss: 2.1965 - val_mean_absolute_error: 2.1965
# Epoch 440/500
# 19/19 [==============================] - 0s 8ms/step - loss: 0.7364 - mean_absolute_error: 0.7364 - val_loss: 2.2179 - val_mean_absolute_error: 2.2179
# Epoch 441/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.8074 - mean_absolute_error: 0.8074 - val_loss: 2.2154 - val_mean_absolute_error: 2.2154
# Epoch 442/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7605 - mean_absolute_error: 0.7605 - val_loss: 2.1767 - val_mean_absolute_error: 2.1767
# Epoch 443/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7460 - mean_absolute_error: 0.7460 - val_loss: 2.4182 - val_mean_absolute_error: 2.4182
# Epoch 444/500
# 19/19 [==============================] - 0s 6ms/step - loss: 1.0123 - mean_absolute_error: 1.0123 - val_loss: 2.2329 - val_mean_absolute_error: 2.2329
# Epoch 445/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7519 - mean_absolute_error: 0.7519 - val_loss: 2.2036 - val_mean_absolute_error: 2.2036
# Epoch 446/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7909 - mean_absolute_error: 0.7909 - val_loss: 2.2397 - val_mean_absolute_error: 2.2397
# Epoch 447/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7578 - mean_absolute_error: 0.7578 - val_loss: 2.1843 - val_mean_absolute_error: 2.1843
# Epoch 448/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7321 - mean_absolute_error: 0.7321 - val_loss: 2.2087 - val_mean_absolute_error: 2.2087
# Epoch 449/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7525 - mean_absolute_error: 0.7525 - val_loss: 2.1854 - val_mean_absolute_error: 2.1854
# Epoch 450/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7579 - mean_absolute_error: 0.7579 - val_loss: 2.2061 - val_mean_absolute_error: 2.2061
# Epoch 451/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7425 - mean_absolute_error: 0.7425 - val_loss: 2.2111 - val_mean_absolute_error: 2.2111
# Epoch 452/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7497 - mean_absolute_error: 0.7497 - val_loss: 2.2095 - val_mean_absolute_error: 2.2095
# Epoch 453/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7413 - mean_absolute_error: 0.7413 - val_loss: 2.2462 - val_mean_absolute_error: 2.2462
# Epoch 454/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7342 - mean_absolute_error: 0.7342 - val_loss: 2.1773 - val_mean_absolute_error: 2.1773
# Epoch 455/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8006 - mean_absolute_error: 0.8006 - val_loss: 2.2711 - val_mean_absolute_error: 2.2711
# Epoch 456/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7688 - mean_absolute_error: 0.7688 - val_loss: 2.1770 - val_mean_absolute_error: 2.1770
# Epoch 457/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7444 - mean_absolute_error: 0.7444 - val_loss: 2.2325 - val_mean_absolute_error: 2.2325
# Epoch 458/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7213 - mean_absolute_error: 0.7213 - val_loss: 2.2009 - val_mean_absolute_error: 2.2009
# Epoch 459/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7234 - mean_absolute_error: 0.7234 - val_loss: 2.1462 - val_mean_absolute_error: 2.1462
# Epoch 460/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7795 - mean_absolute_error: 0.7795 - val_loss: 2.1955 - val_mean_absolute_error: 2.1955
# Epoch 461/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7473 - mean_absolute_error: 0.7473 - val_loss: 2.2640 - val_mean_absolute_error: 2.2640
# Epoch 462/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7786 - mean_absolute_error: 0.7786 - val_loss: 2.2589 - val_mean_absolute_error: 2.2589
# Epoch 463/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.8173 - mean_absolute_error: 0.8173 - val_loss: 2.1475 - val_mean_absolute_error: 2.1475
# Epoch 464/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7177 - mean_absolute_error: 0.7177 - val_loss: 2.2385 - val_mean_absolute_error: 2.2385
# Epoch 465/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7480 - mean_absolute_error: 0.7480 - val_loss: 2.1725 - val_mean_absolute_error: 2.1725
# Epoch 466/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7603 - mean_absolute_error: 0.7603 - val_loss: 2.1901 - val_mean_absolute_error: 2.1901
# Epoch 467/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7134 - mean_absolute_error: 0.7134 - val_loss: 2.2196 - val_mean_absolute_error: 2.2196
# Epoch 468/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7391 - mean_absolute_error: 0.7391 - val_loss: 2.1675 - val_mean_absolute_error: 2.1675
# Epoch 469/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7535 - mean_absolute_error: 0.7535 - val_loss: 2.1880 - val_mean_absolute_error: 2.1880
# Epoch 470/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6925 - mean_absolute_error: 0.6925 - val_loss: 2.1699 - val_mean_absolute_error: 2.1699
# Epoch 471/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7144 - mean_absolute_error: 0.7144 - val_loss: 2.2052 - val_mean_absolute_error: 2.2052
# Epoch 472/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6994 - mean_absolute_error: 0.6994 - val_loss: 2.1685 - val_mean_absolute_error: 2.1685
# Epoch 473/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7446 - mean_absolute_error: 0.7446 - val_loss: 2.2457 - val_mean_absolute_error: 2.2457
# Epoch 474/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7158 - mean_absolute_error: 0.7158 - val_loss: 2.1971 - val_mean_absolute_error: 2.1971
# Epoch 475/500
# 19/19 [==============================] - 0s 7ms/step - loss: 0.7469 - mean_absolute_error: 0.7469 - val_loss: 2.1824 - val_mean_absolute_error: 2.1824
# Epoch 476/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7040 - mean_absolute_error: 0.7040 - val_loss: 2.1426 - val_mean_absolute_error: 2.1426
# Epoch 477/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6986 - mean_absolute_error: 0.6986 - val_loss: 2.1954 - val_mean_absolute_error: 2.1954
# Epoch 478/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6873 - mean_absolute_error: 0.6873 - val_loss: 2.2636 - val_mean_absolute_error: 2.2636
# Epoch 479/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6844 - mean_absolute_error: 0.6844 - val_loss: 2.2027 - val_mean_absolute_error: 2.2027
# Epoch 480/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6884 - mean_absolute_error: 0.6884 - val_loss: 2.1893 - val_mean_absolute_error: 2.1893
# Epoch 481/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6893 - mean_absolute_error: 0.6893 - val_loss: 2.2597 - val_mean_absolute_error: 2.2597
# Epoch 482/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7339 - mean_absolute_error: 0.7339 - val_loss: 2.1808 - val_mean_absolute_error: 2.1808
# Epoch 483/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6922 - mean_absolute_error: 0.6922 - val_loss: 2.1803 - val_mean_absolute_error: 2.1803
# Epoch 484/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7093 - mean_absolute_error: 0.7093 - val_loss: 2.2417 - val_mean_absolute_error: 2.2417
# Epoch 485/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7302 - mean_absolute_error: 0.7302 - val_loss: 2.1868 - val_mean_absolute_error: 2.1868
# Epoch 486/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7265 - mean_absolute_error: 0.7265 - val_loss: 2.2065 - val_mean_absolute_error: 2.2065
# Epoch 487/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7133 - mean_absolute_error: 0.7133 - val_loss: 2.2294 - val_mean_absolute_error: 2.2294
# Epoch 488/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7391 - mean_absolute_error: 0.7391 - val_loss: 2.2454 - val_mean_absolute_error: 2.2454
# Epoch 489/500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6893 - mean_absolute_error: 0.6893 - val_loss: 2.2299 - val_mean_absolute_error: 2.2299
# Epoch 490/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7249 - mean_absolute_error: 0.7249 - val_loss: 2.2667 - val_mean_absolute_error: 2.2667
# Epoch 491/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7356 - mean_absolute_error: 0.7356 - val_loss: 2.1549 - val_mean_absolute_error: 2.1549
# Epoch 492/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7797 - mean_absolute_error: 0.7797 - val_loss: 2.2115 - val_mean_absolute_error: 2.2115
# Epoch 493/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.7133 - mean_absolute_error: 0.7133 - val_loss: 2.1619 - val_mean_absolute_error: 2.1619
# Epoch 494/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7065 - mean_absolute_error: 0.7065 - val_loss: 2.2455 - val_mean_absolute_error: 2.2455
# Epoch 495/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6911 - mean_absolute_error: 0.6911 - val_loss: 2.1973 - val_mean_absolute_error: 2.1973
# Epoch 496/500
# 19/19 [==============================] - 0s 5ms/step - loss: 0.6922 - mean_absolute_error: 0.6922 - val_loss: 2.1926 - val_mean_absolute_error: 2.1926
# Epoch 497/500
# 19/19 [==============================] - 0s 4ms/step - loss: 0.6885 - mean_absolute_error: 0.6885 - val_loss: 2.1600 - val_mean_absolute_error: 2.1600
# Epoch 498/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6704 - mean_absolute_error: 0.6704 - val_loss: 2.2348 - val_mean_absolute_error: 2.2348
# Epoch 499/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.6772 - mean_absolute_error: 0.6772 - val_loss: 2.2255 - val_mean_absolute_error: 2.2255
# Epoch 500/500
# 19/19 [==============================] - 0s 6ms/step - loss: 0.7044 - mean_absolute_error: 0.7044 - val_loss: 2.1947 - val_mean_absolute_error: 2.1947
# 47/47 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 2ms/step
# MAE Train : 1.0000
# MAE Test  : 2.4955

# %%
# Define MAE values for training and test sets from the models created
mae_train = [
    mae_train_baseline, mae_train_lg, mae_train_dt, mae_train_dt_cv, 
    mae_train_rf, mae_train_rf_cv, mae_train_ab, mae_train_ab_cv, 
    mae_train_gb, mae_train_gb_cv, mae_train_xgb, mae_train_xgb_random_cv, 
    mae_train_lgb, mae_train_lgb_cv, mae_train_dl
]

mae_test = [
    mae_test_baseline, mae_test_lg, mae_test_dt, mae_test_dt_cv, 
    mae_test_rf, mae_test_rf_cv, mae_test_ab, mae_test_ab_cv, 
    mae_test_gb, mae_test_gb_cv, mae_test_xgb, mae_test_xgb_random_cv, 
    mae_test_lgb, mae_test_lgb_cv, mae_test_dl
]

# Define indexes for the summary DataFrame
indexes = [
    'baseline', 'linear regression', 'Decision Tree', 'Decision Tree CV', 
    'Random Forest', 'Random Forest CV', 'AdaBoost', 'AdaBoost CV', 
    'Gradient Boosting', 'Gradient Boosting CV', 'XGBoost', 'XGBoost CV', 
    'LightGBM', 'LightGBM CV', 'Simple Neural Network'
]

# Create a summary DataFrame with MAE values for training and test sets
summary_df = pd.DataFrame({
    "MAE Train": mae_train,
    "MAE Test": mae_test
}, index=indexes)

# Display the summary DataFrame
summary_df
# Out:
#                        MAE Train  MAE Test
# baseline                3.396175  3.446654
# linear regression       2.542921  2.628480
# Decision Tree           1.103943  2.289824
# Decision Tree CV        1.408020  2.305384
# Random Forest           1.124311  1.995803
# Random Forest CV        1.177555  1.998604
# AdaBoost                2.635539  2.694151
# AdaBoost CV             2.422286  2.497703
# Gradient Boosting       1.606564  2.051462
# Gradient Boosting CV    0.555250  1.872450
# XGBoost                 0.223495  1.909553
# XGBoost CV              0.225720  1.742926
# LightGBM                0.732164  1.935902
# LightGBM CV             0.556907  1.898578
# Simple Neural Network   1.000000  2.495455

# %%
# Sorted by MAE Test (Ascending)
summary_df.sort_values(by='MAE Test')
# Out:
#                        MAE Train  MAE Test
# XGBoost CV              0.225720  1.742926
# Gradient Boosting CV    0.555250  1.872450
# LightGBM CV             0.556907  1.898578
# XGBoost                 0.223495  1.909553
# LightGBM                0.732164  1.935902
# Random Forest           1.124311  1.995803
# Random Forest CV        1.177555  1.998604
# Gradient Boosting       1.606564  2.051462
# Decision Tree           1.103943  2.289824
# Decision Tree CV        1.408020  2.305384
# Simple Neural Network   1.000000  2.495455
# AdaBoost CV             2.422286  2.497703
# linear regression       2.542921  2.628480
# AdaBoost                2.635539  2.694151
# baseline                3.396175  3.446654

# %% [markdown]
# ## Error Analysis

# %%
y_pred_test_best_gb = best_gb.predict(X_test_clean)

# %%
#Scatter plot data faktual dan data prediksi
plt.scatter(y_test, y_pred_test_best_gb)
plt.plot([0, 100], [0,100], "--r")

plt.xlabel("Average Body Weight Actual")
plt.ylabel("Average Body Weight Prediction")
plt.xlim(0, 50)
plt.ylim(0, 50)
#plt.savefig("predict.png")
plt.show()

# %% [markdown]
# ## Save Best Model

# %%
import pickle

# Define the file path where the model will be saved
best_gb_cv = 'model/best_model_gb_abw.pkl'

# Open the file in write-binary mode and save the best XGBoost model
with open(best_gb_cv, 'wb') as file:
    pickle.dump(best_gb, file)

# %% [markdown]
# ## Load Model

# %%
import pickle

# Load the XGBoost model from the file
with open("model/best_model_gb_abw.pkl", "rb") as file:
    loaded_model = pickle.load(file)

# Use the loaded model to make predictions on the test data
y_pred_loaded_model = loaded_model.predict(X_test_clean)
