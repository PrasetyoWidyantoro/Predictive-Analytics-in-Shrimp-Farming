# %% [markdown]
# # Biomass Prediction
#
# ### Business Understanding
#
# The prediction of Biomass in kilograms is a crucial task in shrimp aquaculture, as it provides insights into the total weight of harvested shrimp. Biomass represents the cumulative weight of shrimp produced in aquaculture ponds, serving as a key performance indicator for farm productivity and profitability. Accurate prediction of Biomass enables aquaculture professionals to optimize feeding regimes, monitor stock levels, and plan harvesting schedules effectively.
#
# ### Problem Statement
#
# Given the Shrimp Aquaculture dataset, our objective is to develop a machine learning regression model capable of accurately predicting the Biomass of shrimp in kilograms. The model will utilize various features such as pond dimensions, environmental parameters, feeding quantities, and cultivation duration to make predictions. The primary evaluation metric for the model will be the Mean Absolute Error (MAE), which measures the average absolute difference between predicted and actual Biomass values.
#
# ### Business Objective
#
# The primary business objective is to create a robust predictive model for estimating the Biomass of shrimp in aquaculture ponds. This model will enable stakeholders to:
#
# 1. Optimize feeding strategies and nutrient management to achieve target Biomass levels.
# 2. Monitor stock levels and plan harvesting schedules efficiently to maximize farm productivity.
# 3. Improve decision-making regarding resource allocation and operational planning based on accurate Biomass predictions.
#
# ### Business Metrics
#
# To assess the effectiveness of our predictive model and its impact on business objectives, we will focus on the following metrics:
#
# 1. **Prediction Accuracy**: The degree to which the predicted Biomass values align with actual measurements, ensuring reliable estimates for farm management decisions.
# 2. **Productivity Enhancement**: The improvements in farm productivity and yield resulting from optimized feeding practices guided by the model predictions.
# 3. **Operational Efficiency**: The optimization of resource allocation and harvesting schedules based on accurate Biomass predictions, leading to cost savings and enhanced operational efficiency.
#
# ### Machine Learning Metrics
#
# For evaluating and refining our machine learning model, we will primarily rely on the following metric:
#
# 1. **Mean Absolute Error (MAE)**: The primary evaluation metric, MAE measures the average absolute difference between predicted and actual Biomass values. A lower MAE indicates higher prediction accuracy and model performance.curacy and model performance.

# %%
# Import libraries for data preparation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Import libraries for saving and loading model and column files
import pickle
import copy

# Import train_test_split for splitting data
from sklearn.model_selection import train_test_split

# %%
# Read Data
df = pd.read_csv('Data/2_processed_data/biomass_prediction_data.csv')

# %%
# Sanity Check
df
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 0         331920  4030.00          0.0                   2.00
# 1         357570  2000.00          0.0                   1.25
# 2         168275  1512.00          0.0                   1.25
# 3         188000  1225.00          0.0                   1.25
# 4         200128   803.84          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1839      226284  1400.00          0.0                   1.25
# 1840      300000  4999.90          0.0                   1.25
# 1841      100000   900.00          0.0                   1.25
# 1842       30716    86.00          0.0                   1.25
# 1843      384000  2915.00          0.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 0                      110.0         35.0        65.00       62.00
# 1                      120.0         20.0        50.00       40.00
# 2                      100.0         55.0        54.00       28.00
# 3                      100.0         55.0        35.00       35.00
# 4                      120.0         55.0        32.00       32.00
# ...                      ...          ...          ...         ...
# 1839                   120.0         55.0        40.00       35.00
# 1840                    88.0         55.0        70.71       70.71
# 1841                   120.0         55.0        45.00       20.00
# 1842                   120.0         20.0        10.71        8.03
# 1843                   100.0         40.0        55.00       53.00
#
#       pond_depth    size  ...   nitrate   nitrite  alkalinity    hardness  \
# 0            1.0   83.00  ...  0.000000  0.000000    0.000000    0.000000
# 1            1.4   72.48  ...  0.011111  0.008200   17.044444  680.555556
# 2            1.5  105.94  ...  0.000000  0.030822   17.671233  126.602740
# 3            1.2   93.00  ...  0.000000  0.044667    9.813333  176.000000
# 4            1.5   89.24  ...  0.000000  0.000000    0.000000    0.000000
# ...          ...     ...  ...       ...       ...         ...         ...
# 1839         1.2   87.00  ...  0.000000  0.000000   13.072165    0.000000
# 1840         1.5   18.40  ...  0.000000  0.097528   23.820225    0.000000
# 1841         1.5  120.00  ...  0.000000  0.004145   22.309091  771.454545
# 1842         1.0  280.00  ...  0.125000  0.000208    5.416667    0.000000
# 1843         1.7  105.00  ...  0.000000  0.000000   24.000000    0.000000
#
#          calcium   magnesium  carbonate  bicarbonate  transparency  \
# 0       0.000000    0.000000   0.000000     0.000000     45.327103
# 1     119.855556  575.700000   0.000000    15.777778     68.916667
# 2      50.753425  140.136986   0.821918    16.849315     45.205479
# 3      29.333333  146.666667   0.160000     9.733333      0.000000
# 4       0.000000    0.000000   0.000000     0.000000     41.421569
# ...          ...         ...        ...          ...           ...
# 1839    0.000000    0.000000   0.000000     6.845361     58.314433
# 1840    0.000000    0.000000   0.000000     0.000000     41.853933
# 1841   95.890909  300.436364   0.436364    16.418182      0.000000
# 1842    3.437500    9.479167   1.166667     9.208333      0.000000
# 1843    0.000000    0.000000   0.857143     6.571429      0.000000
#
#       total_plankton_
# 0            0.000000
# 1       212305.555556
# 2        66952.191781
# 3        22466.666667
# 4            0.000000
# ...               ...
# 1839     44536.082474
# 1840     46118.573034
# 1841     49785.490909
# 1842      5416.666667
# 1843    107857.142857
#
# [1844 rows x 35 columns]

# %%
# Check Null Values
df.isnull().sum()
# Out:
# total_seed                0
# area                      0
# initial_age               0
# limit_weight_per_area     0
# target_cultivation_day    0
# target_size               0
# pond_length               0
# pond_width                0
# pond_depth                0
# size                      0
# weight                    0
# biomass                   0
# survival_rate             0
# cycle_duration_days       0
# average_daily_gain        0
# average_body_weight       0
# feed_quantity_kg          0
# feed_conversion_ratio     0
# morning_temperature       0
# evening_temperature       0
# morning_do                0
# evening_do                0
# morning_salinity          0
# evening_salinity          0
# ammonia                   0
# nitrate                   0
# nitrite                   0
# alkalinity                0
# hardness                  0
# calcium                   0
# magnesium                 0
# carbonate                 0
# bicarbonate               0
# transparency              0
# total_plankton_           0
# dtype: int64

# %%
# Check Duplicated Value
df.duplicated().sum()
# Out:
# 0

# %%
# Check Data Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_seed              1844 non-null   int64
#  1   area                    1844 non-null   float64
#  2   initial_age             1844 non-null   float64
#  3   limit_weight_per_area   1844 non-null   float64
#  4   target_cultivation_day  1844 non-null   float64
#  5   target_size             1844 non-null   float64
#  6   pond_length             1844 non-null   float64
#  7   pond_width              1844 non-null   float64
#  8   pond_depth              1844 non-null   float64
#  9   size                    1844 non-null   float64
#  10  weight                  1844 non-null   float64
#  11  biomass                 1844 non-null   float64
#  12  survival_rate           1844 non-null   float64
#  13  cycle_duration_days     1844 non-null   int64
#  14  average_daily_gain      1844 non-null   float64
#  15  average_body_weight     1844 non-null   float64
#  16  feed_quantity_kg        1844 non-null   float64
#  17  feed_conversion_ratio   1844 non-null   float64
#  18  morning_temperature     1844 non-null   float64
#  19  evening_temperature     1844 non-null   float64
#  20  morning_do              1844 non-null   float64
#  21  evening_do              1844 non-null   float64
#  22  morning_salinity        1844 non-null   float64
#  23  evening_salinity        1844 non-null   float64
#  24  ammonia                 1844 non-null   float64
#  25  nitrate                 1844 non-null   float64
#  26  nitrite                 1844 non-null   float64
#  27  alkalinity              1844 non-null   float64
#  28  hardness                1844 non-null   float64
#  29  calcium                 1844 non-null   float64
#  30  magnesium               1844 non-null   float64
#  31  carbonate               1844 non-null   float64
#  32  bicarbonate             1844 non-null   float64
#  33  transparency            1844 non-null   float64
#  34  total_plankton_         1844 non-null   float64
# dtypes: float64(33), int64(2)
# memory usage: 504.3 KB

# %% [markdown]
# ## Data Definition

# %% [markdown]
# # Biomass Prediction in Shrimp Aquaculture
#
# ### Brief Narrative about the Shrimp Aquaculture Biomass Dataset:
#
# The Shrimp Aquaculture Biomass dataset is a comprehensive dataset utilized for regression tasks, specifically aimed at predicting the biomass of shrimp in kilograms in aquaculture ponds. This dataset encompasses various attributes related to pond characteristics, water quality, feeding practices, and other environmental factors pertinent to shrimp cultivation. The primary objective of leveraging this dataset is to develop predictive models capable of accurately estimating the biomass of shrimp, which is critical for assessing farm productivity, optimizing feeding strategies, and ensuring the overall health and sustainability of shrimp populations in aquaculture ponds.
#
# The dataset consists of 1844 entries and 35 columns, including attributes such as total seed, pond dimensions, cultivation duration, feed quantity, water temperature, dissolved oxygen levels, salinity, nutrient concentrations, and the target variable, `biomass`, representing the cumulative weight of harvested shrimp in kilograms. This dataset serves as a valuable resource for researchers, aquaculture professionals, and shrimp farmers to enhance production efficiency, improve farm management practices, and maximize profitability in shrimp aquaculture operations.
#
# ### Data Definitions:
#
# 1. **total_seed**: Total number of shrimp seeds stocked in the pond. Data type: `int64`.
# 2. **area**: Area of the pond in square meters. Data type: `float64`.
# 3. **initial_age**: Initial age of the shrimp seeds in days. Data type: `float64`.
# 4. **limit_weight_per_area**: Limit weight of shrimp per unit area in kg/m². Data type: `float64`.
# 5. **target_cultivation_day**: Target number of cultivation days. Data type: `float64`.
# 6. **target_size**: Target size of shrimp at harvest in grams. Data type: `float64`.
# 7. **pond_length**: Length of the pond in meters. Data type: `float64`.
# 8. **pond_width**: Width of the pond in meters. Data type: `float64`.
# 9. **pond_depth**: Depth of the pond in meters. Data type: `float64`.
# 10. **size**: Average size of shrimp at stocking in grams. Data type: `float64`.
# 11. **weight**: Average weight of shrimp at stocking in grams. Data type: `float64`.
# 12. **biomass**: Biomass of shrimp at harvest in kilograms (target variable). Data type: `float64`.
# 13. **survival_rate**: Survival rate of shrimp in percentage. Data type: `float64`.
# 14. **cycle_duration_days**: Duration of the cultivation cycle in days. Data type: `int64`.
# 15. **average_daily_gain**: Average daily weight gain of shrimp in grams. Data type: `float64`.
# 16. **average_body_weight**: Average body weight of shrimp at harvest in grams. Data type: `float64`.
# 17. **feed_quantity_kg**: Total feed quantity used during the cycle in kilograms. Data type: `float64`.
# 18. **feed_conversion_ratio**: Feed conversion ratio, a measure of the efficiency of feed usage. Data type: `float64`.
# 19. **morning_temperature**: Morning water temperature in degrees Celsius. Data type: `float64`.
# 20. **evening_temperature**: Evening water temperature in degrees Celsius. Data type: `float64`.
# 21. **morning_do**: Morning dissolved oxygen level in mg/L. Data type: `float64`.
# 22. **evening_do**: Evening dissolved oxygen level in mg/L. Data type: `float64`.
# 23. **morning_salinity**: Morning water salinity in ppt (parts per thousand). Data type: `float64`.
# 24. **evening_salinity**: Evening water salinity in ppt (parts per thousand). Data type: `float64`.
# 25. **ammonia**: Ammonia concentration in the water in mg/L. Data type: `float64`.
# 26. **nitrate**: Nitrate concentration in the water in mg/L. Data type: `float64`.
# 27. **nitrite**: Nitrite concentration in the water in mg/L. Data type: `float64`.
# 28. **alkalinity**: Water alkalinity in mg/L CaCO3. Data type: `float64`.
# 29. **hardness**: Water hardness in mg/L CaCO3. Data type: `float64`.
# 30. **calcium**: Calcium concentration in the water in mg/L. Data type: `float64`.
# 31. **magnesium**: Magnesium concentration in the water in mg/L. Data type: `float64`.
# 32. **carbonate**: Carbonate concentration in the water in mg/L. Data type: `float64`.
# 33. **bicarbonate**: Bicarbonate concentration in the water in mg/L. Data type: `float64`.
# 34. **transparency**: Water transparency in centimeters. Data type: `float64`.
# 35. **total_plankton_**: Total plankton concentration in cells/mL. Data type: `float64`.
#
# This dataset provides valuable insights into the factors influencing the biomass of shrimp in aquaculture ponds, facilitating the development of factors that affect shrimp survival rates.

# %%
# Iterate through each column in the DataFrame
for column in df.columns:
    # Print the column name along with its minimum and maximum values
    print(f"{column}: min = {df[column].min()}, max = {df[column].max()}")
# Out:
# total_seed: min = 1272, max = 1800000
# area: min = 1.02, max = 249998.0
# initial_age: min = 0.0, max = 69.0
# limit_weight_per_area: min = 0.6, max = 270.0
# target_cultivation_day: min = 0.0, max = 348.0
# target_size: min = 0.0, max = 120.0
# pond_length: min = 3.0, max = 577.35
# pond_width: min = 1.5, max = 433.01
# pond_depth: min = 0.7, max = 300.0
# size: min = 10.0, max = 1000.0
# weight: min = 0.0, max = 11521.86
# biomass: min = 0.0, max = 752840.0
# survival_rate: min = 0.0, max = 99.46474713916574
# cycle_duration_days: min = 19, max = 348
# average_daily_gain: min = -0.2250000000000001, max = 2.066666666666667
# average_body_weight: min = 0.02, max = 85.0
# feed_quantity_kg: min = 3.0, max = 219525.5
# feed_conversion_ratio: min = 0.0, max = inf
# morning_temperature: min = 0.0, max = 543.305396226415
# evening_temperature: min = 0.0, max = 75.968125
# morning_do: min = -0.0665376344086021, max = 605.935925
# evening_do: min = 0.0, max = 71.40357
# morning_salinity: min = 0.0, max = 181.059320754717
# evening_salinity: min = 0.0, max = 411.6472349397591
# ammonia: min = 0.0, max = 23.11573033707865
# nitrate: min = 0.0, max = 29.58139534883721
# nitrite: min = 0.0, max = 527.8157582417583
# alkalinity: min = 0.0, max = 388.2332075471698
# hardness: min = 0.0, max = 22349.84946236559
# calcium: min = 0.0, max = 1877.7777777777776
# magnesium: min = 0.0, max = 4533.333333333333
# carbonate: min = 0.0, max = 127.5
# bicarbonate: min = 0.0, max = 373.9811320754717
# transparency: min = 0.0, max = 80.0
# total_plankton_: min = 0.0, max = 3818013.060240964

# %%
# Viewing descriptive statistics using describe()
df.describe()
# Out:
#          total_seed           area  initial_age  limit_weight_per_area  \
# count  1.844000e+03    1844.000000  1844.000000            1844.000000
# mean   2.312755e+05    1956.546372     0.405098               1.671838
# std    1.668845e+05    6134.900851     3.367232               7.891358
# min    1.272000e+03       1.020000     0.000000               0.600000
# 25%    1.073812e+05     900.000000     0.000000               1.250000
# 50%    2.000000e+05    1483.890000     0.000000               1.250000
# 75%    3.125000e+05    2381.030000     0.000000               1.250000
# max    1.800000e+06  249998.000000    69.000000             270.000000
#
#        target_cultivation_day  target_size  pond_length   pond_width  \
# count             1844.000000  1844.000000  1844.000000  1844.000000
# mean               114.105206    51.217462    44.179225    36.736876
# std                 17.869388    10.358045    22.467105    17.417913
# min                  0.000000     0.000000     3.000000     1.500000
# 25%                100.000000    45.000000    32.000000    27.390000
# 50%                120.000000    55.000000    43.200000    35.000000
# 75%                120.000000    55.000000    51.900000    45.000000
# max                348.000000   120.000000   577.350000   433.010000
#
#         pond_depth         size  ...      nitrate      nitrite   alkalinity  \
# count  1844.000000  1844.000000  ...  1844.000000  1844.000000  1844.000000
# mean      4.533286   109.633991  ...     0.294301     1.059649    12.145470
# std      20.914900    63.580495  ...     1.625180    17.461910    22.315192
# min       0.700000    10.000000  ...     0.000000     0.000000     0.000000
# 25%       1.100000    72.225000  ...     0.000000     0.000000     0.000000
# 50%       1.300000    99.475000  ...     0.000000     0.000000     4.840734
# 75%       1.500000   132.050000  ...     0.000000     0.020152    17.297517
# max     300.000000  1000.000000  ...    29.581395   527.815758   388.233208
#
#            hardness      calcium    magnesium    carbonate  bicarbonate  \
# count   1844.000000  1844.000000  1844.000000  1844.000000  1844.000000
# mean     214.294393    31.277816   104.635494     0.679188     7.643328
# std      712.476011    86.575328   274.404552     4.175689    17.812209
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        0.000000     0.000000     0.000000     0.000000     0.000000
# 50%        0.000000     0.000000     0.000000     0.000000     0.000000
# 75%      163.591270    41.701299   117.466685     0.134576    12.193106
# max    22349.849462  1877.777778  4533.333333   127.500000   373.981132
#
#        transparency  total_plankton_
# count   1844.000000     1.844000e+03
# mean      21.294418     4.854437e+04
# std       21.731054     1.516362e+05
# min        0.000000     0.000000e+00
# 25%        0.000000     0.000000e+00
# 50%       17.916667     0.000000e+00
# 75%       40.611358     3.638279e+04
# max       80.000000     3.818013e+06
#
# [8 rows x 35 columns]

# %% [markdown]
# ## Data Splitting

# %%
# Separating the feature variables (X) and the target variable (y)
X = df.drop(columns=['feed_conversion_ratio', 'biomass','size','weight','survival_rate'])
y = df['biomass']

# %%
# Split the data into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=123)

# %%
# Sanity Check
X_train
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 1373      200000  2660.00          0.0                   1.25
# 1186      325000  2500.00          0.0                   1.25
# 814        50000  1000.00          0.0                   1.25
# 1244      383358  2560.00          1.0                   1.25
# 410       400000  1500.00          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1122      436424  1962.50          0.0                   1.25
# 1346       72314   600.00          0.0                   1.25
# 1406      115000  1000.00          0.0                   1.20
# 1389       84000  1064.18          0.0                   1.25
# 1534        9820    19.62          1.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                   100.0         55.0        95.00       28.00
# 1186                   120.0         55.0        50.00       50.00
# 814                    120.0         45.0        36.51       27.39
# 1244                   120.0         55.0        50.60       50.60
# 410                    100.0         55.0        44.72       33.54
# ...                      ...          ...          ...         ...
# 1122                   120.0         50.0        50.00       50.00
# 1346                   120.0         45.0        28.28       21.21
# 1406                   110.0         30.0        37.67       28.25
# 1389                   130.0         55.0        37.67       28.25
# 1534                   100.0         55.0         5.00        5.00
#
#       pond_depth  cycle_duration_days  ...   nitrate    nitrite  alkalinity  \
# 1373        1.50                   66  ...  0.000000   0.001409    2.909091
# 1186        1.20                  110  ...  0.000000   0.469855   23.772727
# 814         1.30                  109  ...  0.000000   0.000000    0.000000
# 1244        1.20                   93  ...  0.000000   0.000000    0.000000
# 410         1.50                   91  ...  0.002895  55.283026    8.671053
# ...          ...                  ...  ...       ...        ...         ...
# 1122        1.20                   85  ...  0.000000   0.015541   23.581081
# 1346        1.25                  120  ...  0.000000   0.000000    0.000000
# 1406        1.10                   87  ...  0.000000   0.013000   25.129630
# 1389        1.10                   58  ...  0.000000   0.012754   12.114754
# 1534        1.00                   67  ...  0.000000   0.000000    0.000000
#
#         hardness     calcium   magnesium  carbonate  bicarbonate  \
# 1373   37.878788    9.090909   28.787879   0.363636     2.545455
# 1186  881.818182   65.818182  165.214545   0.036364    23.736364
# 814     0.000000    0.000000    0.000000   0.000000     0.000000
# 1244    0.000000    0.000000    0.000000   0.000000     0.000000
# 410   209.013158   64.105263  200.157895   0.815789     9.592105
# ...          ...         ...         ...        ...          ...
# 1122    0.000000   67.554054  135.810811   0.000000     0.000000
# 1346    0.000000    0.000000    0.000000   0.000000     0.000000
# 1406  932.907407   13.555556   42.018519   1.333333     3.111111
# 1389  409.245902  111.606557  381.360656   1.180328    10.934426
# 1534    0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency  total_plankton_
# 1373      0.000000      7121.212121
# 1186     41.636364     80590.909091
# 814       0.000000         0.000000
# 1244     44.000000         0.000000
# 410      48.766447     25907.368421
# ...            ...              ...
# 1122      9.162162         0.000000
# 1346      0.000000         0.000000
# 1406     50.092593       740.740741
# 1389     49.139344     41516.557377
# 1534     30.955882         0.000000
#
# [1475 rows x 30 columns]

# %%
# Sanity Check
X_test
# Out:
#       total_seed    area  initial_age  limit_weight_per_area  \
# 12        100000  1050.0          0.0                   2.00
# 533       123816  1600.0          0.0                   1.25
# 1227      325000  2500.0          0.0                   1.25
# 319       340200  4030.0          0.0                   2.00
# 1386      600000  1023.0          4.0                   1.25
# ...          ...     ...          ...                    ...
# 988        50000   256.0          0.0                   2.25
# 938       183464  2319.0          0.0                   1.25
# 0         331920  4030.0          0.0                   2.00
# 637       102609  1300.0          0.0                   1.25
# 798        75000   500.0          0.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 12                     120.0         45.0        35.00       30.00
# 533                    100.0         55.0        40.00       40.00
# 1227                   100.0         55.0        50.00       50.00
# 319                    111.0         35.0        65.00       62.00
# 1386                   120.0         55.0        31.00       33.00
# ...                      ...          ...          ...         ...
# 988                     99.0         45.0        16.00       16.00
# 938                    100.0         55.0        54.59       40.94
# 0                      110.0         35.0        65.00       62.00
# 637                    100.0         55.0        40.00       40.00
# 798                    120.0         55.0        25.00       20.00
#
#       pond_depth  cycle_duration_days  ...   nitrate   nitrite  alkalinity  \
# 12           1.0                  108  ...  0.000000  0.000000    0.000000
# 533          1.0                   54  ...  0.000000  0.000741   19.740000
# 1227         1.2                   74  ...  0.000000  0.004786   19.957143
# 319          1.0                  111  ...  0.000000  0.000000    0.000000
# 1386         1.5                  110  ...  0.000000  1.657895   13.484211
# ...          ...                  ...  ...       ...       ...         ...
# 988          1.2                   55  ...  0.000000  0.000000    0.000000
# 938          1.2                   72  ...  0.000000  0.010519   21.123457
# 0            1.0                  107  ...  0.000000  0.000000    0.000000
# 637          1.0                   68  ...  0.142857  0.002614   23.919143
# 798          1.3                   71  ...  0.000000  0.000000    0.000000
#
#          hardness     calcium   magnesium  carbonate  bicarbonate  \
# 12       0.000000    0.000000    0.000000   0.000000     0.000000
# 533     51.206897   34.293103   79.844828  27.034483    10.385690
# 1227  1015.328571  178.400000  836.957143   1.014286    18.885714
# 319      0.000000    0.000000    0.000000   0.000000     0.000000
# 1386     0.000000    0.000000    0.000000   0.000000     2.294737
# ...           ...         ...         ...        ...          ...
# 988      0.000000    0.000000    0.000000   0.000000     0.000000
# 938    831.481481   64.962963  186.271605   2.308642    18.790123
# 0        0.000000    0.000000    0.000000   0.000000     0.000000
# 637     63.171429   40.821429   94.592857   0.000000     7.802000
# 798      0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency  total_plankton_
# 12       39.150000         0.000000
# 533      13.431034     28103.452586
# 1227     36.285714     83294.214286
# 319      40.486486         0.000000
# 1386      0.000000         0.000000
# ...            ...              ...
# 988      39.528302         0.000000
# 938      66.851852     95679.012346
# 0        45.327103         0.000000
# 637      20.507143      5071.428571
# 798       0.000000         0.000000
#
# [369 rows x 30 columns]

# %%
# Sanity Check
y_train
# Out:
# 1373     9800.000
# 1186    61765.110
# 814     15984.000
# 1244    60173.568
# 410     32676.260
#           ...
# 1122    70377.750
# 1346     8364.000
# 1406    27304.200
# 1389     2700.000
# 1534     4972.840
# Name: biomass, Length: 1475, dtype: float64

# %%
# Sanity Check
y_test
# Out:
# 12       15150.0000
# 533      26445.2900
# 1227    200333.2800
# 319     181799.0000
# 1386    220000.0000
#            ...
# 988      48840.0000
# 938     116712.9036
# 0       144046.5000
# 637      29143.8000
# 798       7500.0000
# Name: biomass, Length: 369, dtype: float64

# %%
# create x_train_copy
X_train_copy = X_train.copy()

# %%
# create x_test_copy
X_test_copy = X_test.copy()

# %% [markdown]
# ## Simple EDA

# %%
# Combine X_train and y_train for EDA purposes
train_set = pd.merge(X_train, y_train, left_index=True, right_index=True)

# Sanity check the data
train_set
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 1373      200000  2660.00          0.0                   1.25
# 1186      325000  2500.00          0.0                   1.25
# 814        50000  1000.00          0.0                   1.25
# 1244      383358  2560.00          1.0                   1.25
# 410       400000  1500.00          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1122      436424  1962.50          0.0                   1.25
# 1346       72314   600.00          0.0                   1.25
# 1406      115000  1000.00          0.0                   1.20
# 1389       84000  1064.18          0.0                   1.25
# 1534        9820    19.62          1.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                   100.0         55.0        95.00       28.00
# 1186                   120.0         55.0        50.00       50.00
# 814                    120.0         45.0        36.51       27.39
# 1244                   120.0         55.0        50.60       50.60
# 410                    100.0         55.0        44.72       33.54
# ...                      ...          ...          ...         ...
# 1122                   120.0         50.0        50.00       50.00
# 1346                   120.0         45.0        28.28       21.21
# 1406                   110.0         30.0        37.67       28.25
# 1389                   130.0         55.0        37.67       28.25
# 1534                   100.0         55.0         5.00        5.00
#
#       pond_depth  cycle_duration_days  ...    nitrite  alkalinity    hardness  \
# 1373        1.50                   66  ...   0.001409    2.909091   37.878788
# 1186        1.20                  110  ...   0.469855   23.772727  881.818182
# 814         1.30                  109  ...   0.000000    0.000000    0.000000
# 1244        1.20                   93  ...   0.000000    0.000000    0.000000
# 410         1.50                   91  ...  55.283026    8.671053  209.013158
# ...          ...                  ...  ...        ...         ...         ...
# 1122        1.20                   85  ...   0.015541   23.581081    0.000000
# 1346        1.25                  120  ...   0.000000    0.000000    0.000000
# 1406        1.10                   87  ...   0.013000   25.129630  932.907407
# 1389        1.10                   58  ...   0.012754   12.114754  409.245902
# 1534        1.00                   67  ...   0.000000    0.000000    0.000000
#
#          calcium   magnesium  carbonate  bicarbonate  transparency  \
# 1373    9.090909   28.787879   0.363636     2.545455      0.000000
# 1186   65.818182  165.214545   0.036364    23.736364     41.636364
# 814     0.000000    0.000000   0.000000     0.000000      0.000000
# 1244    0.000000    0.000000   0.000000     0.000000     44.000000
# 410    64.105263  200.157895   0.815789     9.592105     48.766447
# ...          ...         ...        ...          ...           ...
# 1122   67.554054  135.810811   0.000000     0.000000      9.162162
# 1346    0.000000    0.000000   0.000000     0.000000      0.000000
# 1406   13.555556   42.018519   1.333333     3.111111     50.092593
# 1389  111.606557  381.360656   1.180328    10.934426     49.139344
# 1534    0.000000    0.000000   0.000000     0.000000     30.955882
#
#       total_plankton_    biomass
# 1373      7121.212121   9800.000
# 1186     80590.909091  61765.110
# 814          0.000000  15984.000
# 1244         0.000000  60173.568
# 410      25907.368421  32676.260
# ...               ...        ...
# 1122         0.000000  70377.750
# 1346         0.000000   8364.000
# 1406       740.740741  27304.200
# 1389     41516.557377   2700.000
# 1534         0.000000   4972.840
#
# [1475 rows x 31 columns]

# %%
# Setting the number of rows and columns for subplots
num_rows = 12 
num_cols = 3 

# Calculating the total number of subplots
total_subplots = num_rows * num_cols

# Adjusting aspect ratio based on number of rows and columns
fig_width = 15 
fig_height = 5 * num_rows  

# Adjusting the figure size with aspect ratio
plt.figure(figsize=(fig_width, fig_height))

# Initializing the subplot index
subplot_index = 1

# Looping through each column to visualize the data distribution
for col in train_set.columns:
    if train_set[col].dtype != 'object':
        # Creating a subplot
        plt.subplot(num_rows, num_cols, subplot_index)

        # Using kdeplot to visualize the distribution
        ax = sns.kdeplot(train_set[col], shade=True)

        # Calculating mean, median, and mode
        mean_val = train_set[col].mean()
        median_val = train_set[col].median()
        mode_val = stats.mode(train_set[col])[0]

        # Adding lines for mean, median, and mode
        ax.axvline(mean_val, color='red', linestyle='--', label=f'Mean ({mean_val:.2f})')
        ax.axvline(median_val, color='green', linestyle='--', label=f'Median ({median_val:.2f})')
        ax.axvline(mode_val, color='blue', linestyle='--', label=f'Mode ({mode_val[0]:.2f})')

        # Setting the title
        ax.set_title(col, fontsize=14)

        # Adding a legend
        plt.legend(fontsize=12)

        # Incrementing the subplot index
        subplot_index += 1

        # Stop creating subplots if already reached the total number of subplots
        if subplot_index > total_subplots:
            break

# Adjusting the layout of subplots for better readability
plt.tight_layout(pad=3.0)

# Showing the plot
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:25: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(train_set[col], shade=True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_6960\2196530832.py:30: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_val = stats.mode(train_set[col])[0]

# %%
train_set.columns
# Out:
# Index(['total_seed', 'area', 'initial_age', 'limit_weight_per_area',
#        'target_cultivation_day', 'target_size', 'pond_length', 'pond_width',
#        'pond_depth', 'cycle_duration_days', 'average_daily_gain',
#        'average_body_weight', 'feed_quantity_kg', 'morning_temperature',
#        'evening_temperature', 'morning_do', 'evening_do', 'morning_salinity',
#        'evening_salinity', 'ammonia', 'nitrate', 'nitrite', 'alkalinity',
#        'hardness', 'calcium', 'magnesium', 'carbonate', 'bicarbonate',
#        'transparency', 'total_plankton_', 'biomass'],
#       dtype='object')

# %%
# List of provided features
features = [
       'total_seed', 'area', 'initial_age', 'limit_weight_per_area',
       'target_cultivation_day', 'target_size', 'pond_length', 'pond_width',
       'pond_depth', 'cycle_duration_days', 'average_daily_gain',
       'average_body_weight', 'feed_quantity_kg', 'morning_temperature',
       'evening_temperature', 'morning_do', 'evening_do', 'morning_salinity',
       'evening_salinity', 'ammonia', 'nitrate', 'nitrite', 'alkalinity',
       'hardness', 'calcium', 'magnesium', 'carbonate', 'bicarbonate',
       'transparency', 'total_plankton_', 'biomass'
]

# Calculate the correlation matrix using the Spearman method
correlation_matrix = train_set[features].corr(method='spearman')

# Flatten the correlation matrix and convert it to a DataFrame
correlation_df = correlation_matrix.unstack().reset_index()

# Rename columns
correlation_df.columns = ['Feature 1', 'Feature 2', 'Correlation']

# Remove duplicate pairs and self-correlations
correlation_df = correlation_df[correlation_df['Feature 1'] != correlation_df['Feature 2']]

# Remove duplicates (reverse correlations) by keeping one side of the pair
correlation_df['abs_correlation'] = correlation_df['Correlation'].abs()
correlation_df = correlation_df.drop_duplicates(subset=['Feature 1', 'abs_correlation'])

# Sort the DataFrame by correlation values in descending order
correlation_df_sorted = correlation_df.sort_values(by='Correlation', ascending=False)

# Display the sorted correlation DataFrame
print(correlation_df_sorted[['Feature 1', 'Feature 2', 'Correlation']])
# Out:
#                   Feature 1               Feature 2  Correlation
# 769                 calcium               magnesium     0.993671
# 799               magnesium                 calcium     0.993671
# 798               magnesium                hardness     0.885802
# 738                hardness               magnesium     0.885802
# 737                hardness                 calcium     0.881018
# ..                      ...                     ...          ...
# 748                 calcium  target_cultivation_day    -0.240464
# 149  target_cultivation_day               magnesium    -0.246973
# 779               magnesium  target_cultivation_day    -0.246973
# 717                hardness  target_cultivation_day    -0.259470
# 147  target_cultivation_day                hardness    -0.259470
#
# [930 rows x 3 columns]

# %%
# Sanity Check
correlation_df_sorted
# Out:
#                   Feature 1               Feature 2  Correlation  \
# 769                 calcium               magnesium     0.993671
# 799               magnesium                 calcium     0.993671
# 798               magnesium                hardness     0.885802
# 738                hardness               magnesium     0.885802
# 737                hardness                 calcium     0.881018
# ..                      ...                     ...          ...
# 748                 calcium  target_cultivation_day    -0.240464
# 149  target_cultivation_day               magnesium    -0.246973
# 779               magnesium  target_cultivation_day    -0.246973
# 717                hardness  target_cultivation_day    -0.259470
# 147  target_cultivation_day                hardness    -0.259470
#
#      abs_correlation
# 769         0.993671
# 799         0.993671
# 798         0.885802
# 738         0.885802
# 737         0.881018
# ..               ...
# 748         0.240464
# 149         0.246973
# 779         0.246973
# 717         0.259470
# 147         0.259470
#
# [930 rows x 4 columns]

# %%
# Filter the correlation dataframe for rows where 'Feature 1' or 'Feature 2' is 'survival_rate'
survival_rate_correlations = correlation_df_sorted[(correlation_df_sorted['Feature 1'] == 'biomass') | (correlation_df_sorted['Feature 2'] == 'biomass')]

# Display the filtered dataframe
survival_rate_correlations.head(30)
# Out:
#             Feature 1         Feature 2  Correlation  abs_correlation
# 930           biomass        total_seed     0.623068         0.623068
# 30         total_seed           biomass     0.623068         0.623068
# 942           biomass  feed_quantity_kg     0.548942         0.548942
# 402  feed_quantity_kg           biomass     0.548942         0.548942
# 937           biomass        pond_width     0.538120         0.538120
# 247        pond_width           biomass     0.538120         0.538120
# 61               area           biomass     0.502412         0.502412
# 931           biomass              area     0.502412         0.502412
# 936           biomass       pond_length     0.420416         0.420416
# 216       pond_length           biomass     0.420416         0.420416
# 951           biomass           nitrite     0.294454         0.294454
# 681           nitrite           biomass     0.294454         0.294454
# 952           biomass        alkalinity     0.273422         0.273422
# 712        alkalinity           biomass     0.273422         0.273422
# 938           biomass        pond_depth     0.207409         0.207409
# 278        pond_depth           biomass     0.207409         0.207409
# 959           biomass   total_plankton_     0.154438         0.154438
# 929   total_plankton_           biomass     0.154438         0.154438
# 650           nitrate           biomass     0.151996         0.151996
# 950           biomass           nitrate     0.151996         0.151996
# 898      transparency           biomass     0.119148         0.119148
# 958           biomass      transparency     0.119148         0.119148
# 619           ammonia           biomass     0.110160         0.110160
# 949           biomass           ammonia     0.110160         0.110160
# 957           biomass       bicarbonate     0.107257         0.107257
# 867       bicarbonate           biomass     0.107257         0.107257
# 932           biomass       initial_age     0.106549         0.106549
# 92        initial_age           biomass     0.106549         0.106549
# 954           biomass           calcium     0.099813         0.099813
# 774           calcium           biomass     0.099813         0.099813

# %% [markdown]
# ## Data Preprocessing

# %%
# Import necessary libraries
import os
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# %%
import os
import pickle
from sklearn.preprocessing import RobustScaler

# Columns to scale
columns_to_scale = [
       'total_seed', 'area', 'initial_age', 'limit_weight_per_area',
       'target_cultivation_day', 'target_size', 'pond_length', 'pond_width',
       'pond_depth', 'cycle_duration_days', 'average_daily_gain',
       'average_body_weight', 'feed_quantity_kg', 'morning_temperature',
       'evening_temperature', 'morning_do', 'evening_do', 'morning_salinity',
       'evening_salinity', 'ammonia', 'nitrate', 'nitrite', 'alkalinity',
       'hardness', 'calcium', 'magnesium', 'carbonate', 'bicarbonate',
       'transparency', 'total_plankton_'
]

def fit_scaler(train_data):
    """
    Fit a RobustScaler to the training data.

    Parameters:
    train_data (DataFrame): The training data.

    Returns:
    scaler (RobustScaler): The fitted scaler object.
    """
    scaler = RobustScaler()
    scaler.fit(train_data.loc[:, columns_to_scale])
    # Save scaler
    with open('model/biomass_scaler_first.pkl', 'wb') as f:
        pickle.dump(scaler, f)
    return scaler

def load_scaler(folder_path):
    """
    Load a saved scaler object from a folder.

    Parameters:
    folder_path (str): The path to the folder containing the saved scaler.

    Returns:
    scaler (RobustScaler): The loaded scaler object.
    """
    # Load scaler
    file_path = os.path.join(folder_path, 'biomass_scaler_first.pkl')
    with open(file_path, 'rb') as f:
        scaler = pickle.load(f)
    return scaler

def transform_data(data, scaler):
    """
    Scale the data using a given scaler.

    Parameters:
    data (DataFrame): The data to be scaled.
    scaler (RobustScaler): The scaler object to use for scaling.

    Returns:
    scaled_data (DataFrame): The scaled data.
    """
    scaled_data = scaler.transform(data.loc[:, columns_to_scale])
    data.loc[:, columns_to_scale] = scaled_data
    return data

# %%
# Fit a RobustScaler to the training data
scaler = fit_scaler(X_train_copy)

# %%
# Load the scaler from the specified folder path
scaling = load_scaler('model/')

# %%
# Transform the training and testing data using the loaded scaler
X_train_scaled = transform_data(X_train_copy, scaling)
X_test_scaled = transform_data(X_test_copy, scaling)

# %%
# Sanity check
X_train_scaled
# Out:
#       total_seed      area  initial_age  limit_weight_per_area  \
# 1373   -0.019512  0.793333          0.0                   0.00
# 1186    0.590244  0.686667          0.0                   0.00
# 814    -0.751220 -0.313333          0.0                   0.00
# 1244    0.874917  0.726667          1.0                   0.00
# 410     0.956098  0.020000          0.0                   0.00
# ...          ...       ...          ...                    ...
# 1122    1.133776  0.328333          0.0                   0.00
# 1346   -0.642371 -0.580000          0.0                   0.00
# 1406   -0.434146 -0.313333          0.0                  -0.05
# 1389   -0.585366 -0.270547          0.0                   0.00
# 1534   -0.947220 -0.966920          1.0                   0.00
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                    -1.0          0.0     2.397711   -0.397501
# 1186                     0.0          0.0     0.251788    0.851789
# 814                      0.0         -1.0    -0.391512   -0.432141
# 1244                     0.0          0.0     0.280401    0.885860
# 410                     -1.0          0.0     0.000000   -0.082907
# ...                      ...          ...          ...         ...
# 1122                     0.0         -0.5     0.251788    0.851789
# 1346                     0.0         -1.0    -0.783977   -0.783078
# 1406                    -0.5         -2.5    -0.336195   -0.383305
# 1389                     0.5          0.0    -0.336195   -0.383305
# 1534                    -1.0          0.0    -1.894134   -1.703578
#
#       pond_depth  cycle_duration_days  ...   nitrate      nitrite  alkalinity  \
# 1373       0.500            -0.558824  ...  0.000000     0.073480   -0.104713
# 1186      -0.250             0.735294  ...  0.000000    24.501642    1.117233
# 814        0.000             0.705882  ...  0.000000     0.000000   -0.275093
# 1244      -0.250             0.235294  ...  0.000000     0.000000   -0.275093
# 410        0.500             0.176471  ...  0.002895  2882.860053    0.232755
# ...          ...                  ...  ...       ...          ...         ...
# 1122      -0.250             0.000000  ...  0.000000     0.810397    1.106009
# 1346      -0.125             1.029412  ...  0.000000     0.000000   -0.275093
# 1406      -0.500             0.058824  ...  0.000000     0.677915    1.196704
# 1389      -0.500            -0.794118  ...  0.000000     0.665092    0.434446
# 1534      -0.750            -0.529412  ...  0.000000     0.000000   -0.275093
#
#       hardness   calcium  magnesium  carbonate  bicarbonate  transparency  \
# 1373  0.230550  0.218482   0.240157   2.556768     0.210595     -0.371293
# 1186  5.367208  1.581809   1.378267   0.255677     1.963797      0.659327
# 814   0.000000  0.000000   0.000000   0.000000     0.000000     -0.371293
# 1244  0.000000  0.000000   0.000000   0.000000     0.000000      0.717834
# 410   1.272164  1.540643   1.669775   5.735906     0.793590      0.835817
# ...        ...       ...        ...        ...          ...           ...
# 1122  0.000000  1.623528   1.132973   0.000000     0.000000     -0.144503
# 1346  0.000000  0.000000   0.000000   0.000000     0.000000     -0.371293
# 1406  5.678163  0.325781   0.350531   9.374815     0.257394      0.868643
# 1389  2.490885  2.682242   3.181420   8.299016     0.904645      0.845048
# 1534  0.000000  0.000000   0.000000   0.000000     0.000000      0.394954
#
#       total_plankton_
# 1373         0.187206
# 1186         2.118610
# 814          0.000000
# 1244         0.000000
# 410          0.681065
# ...               ...
# 1122         0.000000
# 1346         0.000000
# 1406         0.019473
# 1389         1.091406
# 1534         0.000000
#
# [1475 rows x 30 columns]

# %%
# Sanity Check
X_test_scaled
# Out:
#       total_seed      area  initial_age  limit_weight_per_area  \
# 12     -0.507317 -0.280000          0.0                   0.75
# 533    -0.391141  0.086667          0.0                   0.00
# 1227    0.590244  0.686667          0.0                   0.00
# 319     0.664390  1.706667          0.0                   0.75
# 1386    1.931707 -0.298000          4.0                   0.00
# ...          ...       ...          ...                    ...
# 988    -0.751220 -0.809333          0.0                   1.00
# 938    -0.100176  0.566000          0.0                   0.00
# 0       0.624000  1.706667          0.0                   0.75
# 637    -0.494590 -0.113333          0.0                   0.00
# 798    -0.629268 -0.646667          0.0                   0.00
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 12                      0.00         -1.0    -0.463519   -0.283930
# 533                    -1.00          0.0    -0.225083    0.283930
# 1227                   -1.00          0.0     0.251788    0.851789
# 319                    -0.45         -2.0     0.967096    1.533220
# 1386                    0.00          0.0    -0.654268   -0.113572
# ...                      ...          ...          ...         ...
# 988                    -1.05         -1.0    -1.369576   -1.078932
# 938                    -1.00          0.0     0.470672    0.337308
# 0                      -0.50         -2.0     0.967096    1.533220
# 637                    -1.00          0.0    -0.225083    0.283930
# 798                     0.00          0.0    -0.940391   -0.851789
#
#       pond_depth  cycle_duration_days  ...   nitrate    nitrite  alkalinity  \
# 12         -0.75             0.676471  ...  0.000000   0.000000   -0.275093
# 533        -0.75            -0.911765  ...  0.000000   0.038661    0.881043
# 1227       -0.25            -0.323529  ...  0.000000   0.249562    0.893761
# 319        -0.75             0.764706  ...  0.000000   0.000000   -0.275093
# 1386        0.50             0.735294  ...  0.000000  86.454719    0.514653
# ...          ...                  ...  ...       ...        ...         ...
# 988        -0.25            -0.882353  ...  0.000000   0.000000   -0.275093
# 938        -0.25            -0.382353  ...  0.000000   0.548512    0.962070
# 0          -0.75             0.647059  ...  0.000000   0.000000   -0.275093
# 637        -0.75            -0.500000  ...  0.142857   0.136328    1.125808
# 798         0.00            -0.411765  ...  0.000000   0.000000   -0.275093
#
#       hardness   calcium  magnesium   carbonate  bicarbonate  transparency  \
# 12    0.000000  0.000000   0.000000    0.000000     0.000000      0.597782
# 533   0.311672  0.824167   0.666088  190.082452     0.859246     -0.038836
# 1227  6.179822  4.287490   6.982136    7.131556     1.562485      0.526883
# 319   0.000000  0.000000   0.000000    0.000000     0.000000      0.630864
# 1386  0.000000  0.000000   0.000000    0.000000     0.189852     -0.371293
# ...        ...       ...        ...         ...          ...           ...
# 988   0.000000  0.000000   0.000000    0.000000     0.000000      0.607146
# 938   5.060832  1.561256   1.553931   16.232318     1.554576      1.283483
# 0     0.000000  0.000000   0.000000    0.000000     0.000000      0.750684
# 637   0.384494  0.981062   0.789121    0.000000     0.645488      0.136318
# 798   0.000000  0.000000   0.000000    0.000000     0.000000     -0.371293
#
#       total_plankton_
# 12           0.000000
# 533          0.738796
# 1227         2.189676
# 319          0.000000
# 1386         0.000000
# ...               ...
# 988          0.000000
# 938          2.515253
# 0            0.000000
# 637          0.133320
# 798          0.000000
#
# [369 rows x 30 columns]

# %% [markdown]
# ## Feature Selection

# %%
# Copy X_train_scaled
X_train_clean = X_train_scaled.copy()

# %%
# Copy X_test_clean
X_test_clean = X_test_scaled.copy()

# %%
# Import necessary libraries for data preparation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import libraries for data splitting
from sklearn.model_selection import train_test_split

# Import library for data scaling
from sklearn.preprocessing import StandardScaler

# Import library for calculating mean absolute error (MAE)
from sklearn.metrics import mean_absolute_error

# Import libraries for model creation
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE

# %%
# Initialize RandomForestRegressor model with specified parameters
random_forest = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=123)

# Initialize RFE with RandomForestRegressor as estimator and desired number of features
rfe = RFE(estimator=random_forest, n_features_to_select=24)

# Train RFE on the training data
rfe.fit(X_train_clean, y_train)

# Get the mask of selected features
selected_features = rfe.support_

# Get the ranking of each feature
feature_ranking = rfe.ranking_

# Selected features
selected_feature_names = X_train_clean.columns[selected_features]

print(f"Selected features: {selected_feature_names}")

# Transform the training and testing data using the selected features
X_train_rfe = rfe.transform(X_train_clean)
X_test_rfe = rfe.transform(X_test_clean)

# Fit the RandomForestRegressor model on the transformed training data
random_forest.fit(X_train_rfe, y_train)

# Make predictions on the training data
y_pred_train = random_forest.predict(X_train_rfe)

# Make predictions on the testing data
y_pred_test = random_forest.predict(X_test_rfe)

# Calculate Mean Absolute Error (MAE) for training and testing data
mae_train_rf = mean_absolute_error(y_train, y_pred_train)
mae_test_rf = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_rf:.4f}")
print(f"MAE Test  : {mae_test_rf:.4f}")
# Out:
# Selected features: Index(['total_seed', 'area', 'target_size', 'pond_length', 'pond_width',
#        'pond_depth', 'cycle_duration_days', 'average_daily_gain',
#        'average_body_weight', 'feed_quantity_kg', 'morning_temperature',
#        'evening_temperature', 'morning_do', 'evening_do', 'morning_salinity',
#        'evening_salinity', 'ammonia', 'nitrite', 'alkalinity', 'calcium',
#        'magnesium', 'carbonate', 'bicarbonate', 'transparency'],
#       dtype='object')
# MAE Train : 14647.7505
# MAE Test  : 24685.5210

# %%
# Assume random_forest has been trained and selected_feature_names is available
# Get feature importance from the model
feature_importances = random_forest.feature_importances_

# Create a DataFrame for feature importance
feature_importance_df = pd.DataFrame({
    'Feature': selected_feature_names,
    'Importance': feature_importances
})

# Sort the feature importance from most to least important
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the top 20 important features
top_20_feature_importance_df = feature_importance_df.head(24)
print(top_20_feature_importance_df)

# Visualize the top 20 important features
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=top_20_feature_importance_df)
plt.title('Top 20 Feature Importances')
plt.show()
# Out:
#                 Feature  Importance
# 0            total_seed    0.300967
# 9      feed_quantity_kg    0.135625
# 22          bicarbonate    0.112496
# 18           alkalinity    0.066170
# 6   cycle_duration_days    0.062121
# 8   average_body_weight    0.031553
# 13           evening_do    0.028298
# 20            magnesium    0.027872
# 3           pond_length    0.027522
# 1                  area    0.027116
# 14     morning_salinity    0.026261
# 10  morning_temperature    0.020343
# 7    average_daily_gain    0.017307
# 4            pond_width    0.017282
# 2           target_size    0.016275
# 15     evening_salinity    0.014937
# 11  evening_temperature    0.013037
# 23         transparency    0.011880
# 5            pond_depth    0.010075
# 17              nitrite    0.008472
# 12           morning_do    0.007994
# 19              calcium    0.006420
# 16              ammonia    0.005654
# 21            carbonate    0.004322

# %%
# Using the variable feature_importances and RFE
feature_importances = top_20_feature_importance_df['Feature'].unique()
RFE = selected_feature_names

# Convert lists to sets for easier set operations
set_feature_importances = set(feature_importances)
set_RFE = set(RFE)

# Features that are in 'feature_importances' but not in 'RFE'
only_in_feature_importances = set_feature_importances - set_RFE

# Features that are in 'RFE' but not in 'feature_importances'
only_in_RFE = set_RFE - set_feature_importances

# Features that are in both sets
in_both = set_feature_importances & set_RFE

print("Features only in 'feature_importances':", only_in_feature_importances)
print("Features only in 'RFE':", only_in_RFE)
print("Features in both sets:", in_both)
# Out:
# Features only in 'feature_importances': set()
# Features only in 'RFE': set()
# Features in both sets: {'morning_do', 'evening_do', 'pond_length', 'magnesium', 'pond_width', 'calcium', 'target_size', 'alkalinity', 'average_daily_gain', 'ammonia', 'total_seed', 'cycle_duration_days', 'feed_quantity_kg', 'morning_salinity', 'evening_salinity', 'area', 'morning_temperature', 'evening_temperature', 'nitrite', 'bicarbonate', 'pond_depth', 'transparency', 'carbonate', 'average_body_weight'}

# %% [markdown]
# ## Training Data

# %%
# Sanity Check (selected feature)
feature_importance_df.Feature.unique()
# Out:
# array(['total_seed', 'feed_quantity_kg', 'bicarbonate', 'alkalinity',
#        'cycle_duration_days', 'average_body_weight', 'evening_do',
#        'magnesium', 'pond_length', 'area', 'morning_salinity',
#        'morning_temperature', 'average_daily_gain', 'pond_width',
#        'target_size', 'evening_salinity', 'evening_temperature',
#        'transparency', 'pond_depth', 'nitrite', 'morning_do', 'calcium',
#        'ammonia', 'carbonate'], dtype=object)

# %%
# Sanity Check
X_train
# Out:
#       total_seed     area  initial_age  limit_weight_per_area  \
# 1373      200000  2660.00          0.0                   1.25
# 1186      325000  2500.00          0.0                   1.25
# 814        50000  1000.00          0.0                   1.25
# 1244      383358  2560.00          1.0                   1.25
# 410       400000  1500.00          0.0                   1.25
# ...          ...      ...          ...                    ...
# 1122      436424  1962.50          0.0                   1.25
# 1346       72314   600.00          0.0                   1.25
# 1406      115000  1000.00          0.0                   1.20
# 1389       84000  1064.18          0.0                   1.25
# 1534        9820    19.62          1.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 1373                   100.0         55.0        95.00       28.00
# 1186                   120.0         55.0        50.00       50.00
# 814                    120.0         45.0        36.51       27.39
# 1244                   120.0         55.0        50.60       50.60
# 410                    100.0         55.0        44.72       33.54
# ...                      ...          ...          ...         ...
# 1122                   120.0         50.0        50.00       50.00
# 1346                   120.0         45.0        28.28       21.21
# 1406                   110.0         30.0        37.67       28.25
# 1389                   130.0         55.0        37.67       28.25
# 1534                   100.0         55.0         5.00        5.00
#
#       pond_depth  cycle_duration_days  ...   nitrate    nitrite  alkalinity  \
# 1373        1.50                   66  ...  0.000000   0.001409    2.909091
# 1186        1.20                  110  ...  0.000000   0.469855   23.772727
# 814         1.30                  109  ...  0.000000   0.000000    0.000000
# 1244        1.20                   93  ...  0.000000   0.000000    0.000000
# 410         1.50                   91  ...  0.002895  55.283026    8.671053
# ...          ...                  ...  ...       ...        ...         ...
# 1122        1.20                   85  ...  0.000000   0.015541   23.581081
# 1346        1.25                  120  ...  0.000000   0.000000    0.000000
# 1406        1.10                   87  ...  0.000000   0.013000   25.129630
# 1389        1.10                   58  ...  0.000000   0.012754   12.114754
# 1534        1.00                   67  ...  0.000000   0.000000    0.000000
#
#         hardness     calcium   magnesium  carbonate  bicarbonate  \
# 1373   37.878788    9.090909   28.787879   0.363636     2.545455
# 1186  881.818182   65.818182  165.214545   0.036364    23.736364
# 814     0.000000    0.000000    0.000000   0.000000     0.000000
# 1244    0.000000    0.000000    0.000000   0.000000     0.000000
# 410   209.013158   64.105263  200.157895   0.815789     9.592105
# ...          ...         ...         ...        ...          ...
# 1122    0.000000   67.554054  135.810811   0.000000     0.000000
# 1346    0.000000    0.000000    0.000000   0.000000     0.000000
# 1406  932.907407   13.555556   42.018519   1.333333     3.111111
# 1389  409.245902  111.606557  381.360656   1.180328    10.934426
# 1534    0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency  total_plankton_
# 1373      0.000000      7121.212121
# 1186     41.636364     80590.909091
# 814       0.000000         0.000000
# 1244     44.000000         0.000000
# 410      48.766447     25907.368421
# ...            ...              ...
# 1122      9.162162         0.000000
# 1346      0.000000         0.000000
# 1406     50.092593       740.740741
# 1389     49.139344     41516.557377
# 1534     30.955882         0.000000
#
# [1475 rows x 30 columns]

# %%
# Sanity Check
X_test
# Out:
#       total_seed    area  initial_age  limit_weight_per_area  \
# 12        100000  1050.0          0.0                   2.00
# 533       123816  1600.0          0.0                   1.25
# 1227      325000  2500.0          0.0                   1.25
# 319       340200  4030.0          0.0                   2.00
# 1386      600000  1023.0          4.0                   1.25
# ...          ...     ...          ...                    ...
# 988        50000   256.0          0.0                   2.25
# 938       183464  2319.0          0.0                   1.25
# 0         331920  4030.0          0.0                   2.00
# 637       102609  1300.0          0.0                   1.25
# 798        75000   500.0          0.0                   1.25
#
#       target_cultivation_day  target_size  pond_length  pond_width  \
# 12                     120.0         45.0        35.00       30.00
# 533                    100.0         55.0        40.00       40.00
# 1227                   100.0         55.0        50.00       50.00
# 319                    111.0         35.0        65.00       62.00
# 1386                   120.0         55.0        31.00       33.00
# ...                      ...          ...          ...         ...
# 988                     99.0         45.0        16.00       16.00
# 938                    100.0         55.0        54.59       40.94
# 0                      110.0         35.0        65.00       62.00
# 637                    100.0         55.0        40.00       40.00
# 798                    120.0         55.0        25.00       20.00
#
#       pond_depth  cycle_duration_days  ...   nitrate   nitrite  alkalinity  \
# 12           1.0                  108  ...  0.000000  0.000000    0.000000
# 533          1.0                   54  ...  0.000000  0.000741   19.740000
# 1227         1.2                   74  ...  0.000000  0.004786   19.957143
# 319          1.0                  111  ...  0.000000  0.000000    0.000000
# 1386         1.5                  110  ...  0.000000  1.657895   13.484211
# ...          ...                  ...  ...       ...       ...         ...
# 988          1.2                   55  ...  0.000000  0.000000    0.000000
# 938          1.2                   72  ...  0.000000  0.010519   21.123457
# 0            1.0                  107  ...  0.000000  0.000000    0.000000
# 637          1.0                   68  ...  0.142857  0.002614   23.919143
# 798          1.3                   71  ...  0.000000  0.000000    0.000000
#
#          hardness     calcium   magnesium  carbonate  bicarbonate  \
# 12       0.000000    0.000000    0.000000   0.000000     0.000000
# 533     51.206897   34.293103   79.844828  27.034483    10.385690
# 1227  1015.328571  178.400000  836.957143   1.014286    18.885714
# 319      0.000000    0.000000    0.000000   0.000000     0.000000
# 1386     0.000000    0.000000    0.000000   0.000000     2.294737
# ...           ...         ...         ...        ...          ...
# 988      0.000000    0.000000    0.000000   0.000000     0.000000
# 938    831.481481   64.962963  186.271605   2.308642    18.790123
# 0        0.000000    0.000000    0.000000   0.000000     0.000000
# 637     63.171429   40.821429   94.592857   0.000000     7.802000
# 798      0.000000    0.000000    0.000000   0.000000     0.000000
#
#       transparency  total_plankton_
# 12       39.150000         0.000000
# 533      13.431034     28103.452586
# 1227     36.285714     83294.214286
# 319      40.486486         0.000000
# 1386      0.000000         0.000000
# ...            ...              ...
# 988      39.528302         0.000000
# 938      66.851852     95679.012346
# 0        45.327103         0.000000
# 637      20.507143      5071.428571
# 798       0.000000         0.000000
#
# [369 rows x 30 columns]

# %%
import os
import pickle
from sklearn.preprocessing import RobustScaler

# Columns to scale
columns_to_scale = [
       'total_seed', 'feed_quantity_kg', 'bicarbonate', 'alkalinity',
       'cycle_duration_days', 'average_body_weight', 'evening_do',
       'magnesium', 'pond_length', 'area', 'morning_salinity',
       'morning_temperature', 'average_daily_gain', 'pond_width',
       'target_size', 'evening_salinity', 'evening_temperature',
       'transparency', 'pond_depth', 'nitrite', 'morning_do', 'calcium',
       'ammonia', 'carbonate'
]

def fit_scaler(train_data):
    """
    Fit a RobustScaler to the training data.

    Parameters:
    train_data (DataFrame): The training data.

    Returns:
    scaler (RobustScaler): The fitted scaler object.
    """
    scaler = RobustScaler()
    scaler.fit(train_data.loc[:, columns_to_scale])
    # Save scaler
    with open('model/biomass_scaler.pkl', 'wb') as f:
        pickle.dump(scaler, f)
    return scaler

def load_scaler(folder_path):
    """
    Load a saved scaler object from a folder.

    Parameters:
    folder_path (str): The path to the folder containing the saved scaler.

    Returns:
    scaler (RobustScaler): The loaded scaler object.
    """
    # Load scaler
    file_path = os.path.join(folder_path, 'biomass_scaler.pkl')
    with open(file_path, 'rb') as f:
        scaler = pickle.load(f)
    return scaler

def transform_data(data, scaler):
    """
    Scale the data using a given scaler.

    Parameters:
    data (DataFrame): The data to be scaled.
    scaler (RobustScaler): The scaler object to use for scaling.

    Returns:
    scaled_data (DataFrame): The scaled data.
    """
    scaled_data = scaler.transform(data.loc[:, columns_to_scale])
    data.loc[:, columns_to_scale] = scaled_data
    return data

# %%
X_train_feature_importances = X_train[[
       'total_seed', 'feed_quantity_kg', 'bicarbonate', 'alkalinity',
       'cycle_duration_days', 'average_body_weight', 'evening_do',
       'magnesium', 'pond_length', 'area', 'morning_salinity',
       'morning_temperature', 'average_daily_gain', 'pond_width',
       'target_size', 'evening_salinity', 'evening_temperature',
       'transparency', 'pond_depth', 'nitrite', 'morning_do', 'calcium',
       'ammonia', 'carbonate'
]].copy()
X_test_feature_importances = X_test[[
       'total_seed', 'feed_quantity_kg', 'bicarbonate', 'alkalinity',
       'cycle_duration_days', 'average_body_weight', 'evening_do',
       'magnesium', 'pond_length', 'area', 'morning_salinity',
       'morning_temperature', 'average_daily_gain', 'pond_width',
       'target_size', 'evening_salinity', 'evening_temperature',
       'transparency', 'pond_depth', 'nitrite', 'morning_do', 'calcium',
       'ammonia', 'carbonate'
]].copy()

# %%
# Sorted Columns
X_train_feature_importances = X_train_feature_importances[sorted(X_train_feature_importances.columns)]

# %%
# Sorted Columns
X_test_feature_importances = X_test_feature_importances[sorted(X_test_feature_importances.columns)]

# %%
# Fit a RobustScaler to the training data
scaler = fit_scaler(X_train_feature_importances)

# %%
# Load the scaler from the specified folder path
scaling = load_scaler('model/')

# %%
# Transform the training and testing data using the loaded scaler
X_train_clean = transform_data(X_train_feature_importances, scaling)
X_test_clean = transform_data(X_test_feature_importances, scaling)

# %%
X_train_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1475 entries, 1373 to 1534
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   alkalinity           1475 non-null   float64
#  1   ammonia              1475 non-null   float64
#  2   area                 1475 non-null   float64
#  3   average_body_weight  1475 non-null   float64
#  4   average_daily_gain   1475 non-null   float64
#  5   bicarbonate          1475 non-null   float64
#  6   calcium              1475 non-null   float64
#  7   carbonate            1475 non-null   float64
#  8   cycle_duration_days  1475 non-null   float64
#  9   evening_do           1475 non-null   float64
#  10  evening_salinity     1475 non-null   float64
#  11  evening_temperature  1475 non-null   float64
#  12  feed_quantity_kg     1475 non-null   float64
#  13  magnesium            1475 non-null   float64
#  14  morning_do           1475 non-null   float64
#  15  morning_salinity     1475 non-null   float64
#  16  morning_temperature  1475 non-null   float64
#  17  nitrite              1475 non-null   float64
#  18  pond_depth           1475 non-null   float64
#  19  pond_length          1475 non-null   float64
#  20  pond_width           1475 non-null   float64
#  21  target_size          1475 non-null   float64
#  22  total_seed           1475 non-null   float64
#  23  transparency         1475 non-null   float64
# dtypes: float64(24)
# memory usage: 320.4 KB

# %% [markdown]
# ## Baseline

# %%
# Baseline
y_baseline_predict = y_train.mean()
y_baseline_predict
# Out:
# 64257.480868949155

# %%
# Viewing Mean Absolute Error for the baseline Model
mae_train_baseline = mean_absolute_error(y_train, y_baseline_predict * np.ones(len(y_train)))
mae_test_baseline = mean_absolute_error(y_test, y_baseline_predict * np.ones(len(y_test)))

# Viewing mae train baseline and mae test baseline
mae_train_baseline, mae_test_baseline
# Out:
# (49524.90258003535, 49931.37197339819)

# %% [markdown]
# ## Linear Regression

# %%
# Build LinearRegression
lin_reg = LinearRegression()

# %%
#Fitting Model LinearRegression
lin_reg.fit(X_train_clean, y_train)
# Out:
# LinearRegression()

# %%
# Predict
y_pred_train = lin_reg.predict(X_train_clean)
y_pred_test = lin_reg.predict(X_test_clean)

# MAE
mae_train_lg = mean_absolute_error(y_train, y_pred_train)
mae_test_lg = mean_absolute_error(y_test, y_pred_test)

# Viewing the results of mae train lg and mae test lg
mae_train_lg, mae_test_lg
# Out:
# (35286.72954933077, 38370.307634898745)

# %% [markdown]
# ## Dectree

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

# Initialize the DecisionTreeRegressor model with specified parameters
dec_tree = DecisionTreeRegressor(max_depth=10, random_state=123)

# Train the model on the training data
dec_tree.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = dec_tree.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = dec_tree.predict(X_test_clean)

# Calculate the Mean Absolute Error (MAE) for the training and test data
mae_train_dt = mean_absolute_error(y_train, y_pred_train)
mae_test_dt = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_dt:.4f}")
print(f"MAE Test  : {mae_test_dt:.4f}")
# Out:
# MAE Train : 12369.3726
# MAE Test  : 27353.9537

# %%
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for key parameters of DecisionTreeRegressor
params = {
    "max_depth": [3, 5, 7, 9, 11],
    "min_samples_split": [2, 10, 20],
    "min_samples_leaf": [1, 5, 10]
}

# Initialize the DecisionTreeRegressor model
dec_tree = DecisionTreeRegressor(random_state=123)

# Initialize GridSearchCV
dec_tree_cv = GridSearchCV(estimator=dec_tree,
                           param_grid=params,
                           cv=7,
                           scoring="neg_mean_absolute_error")

# Train GridSearchCV
dec_tree_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = dec_tree_cv.best_params_

# Train the model with the best parameters
best_dec_tree = DecisionTreeRegressor(max_depth=best_params["max_depth"],
                                      min_samples_split=best_params["min_samples_split"],
                                      min_samples_leaf=best_params["min_samples_leaf"],
                                      random_state=123)

best_dec_tree.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_dec_tree.predict(X_train_clean)
y_pred_test = best_dec_tree.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_dt_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_dt_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and best parameters
print(f"MAE Train : {mae_train_dt_cv:.4f}")
print(f"MAE Test  : {mae_test_dt_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 18653.6672
# MAE Test  : 27307.2190
# Best Parameters: {'max_depth': 11, 'min_samples_leaf': 5, 'min_samples_split': 2}

# %% [markdown]
# ## RandomForest

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Initialize the RandomForestRegressor model with specified parameters
random_forest = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=123)

# Train the model on the training data
random_forest.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = random_forest.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = random_forest.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_rf = mean_absolute_error(y_train, y_pred_train)
mae_test_rf = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_rf:.4f}")
print(f"MAE Test  : {mae_test_rf:.4f}")
# Out:
# MAE Train : 14638.6484
# MAE Test  : 24707.1751

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for RandomForestRegressor
params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 5, 7, 9, 11],
    "min_samples_split": [2, 10, 20],
    "min_samples_leaf": [1, 5, 10]
}

# Initialize RandomForestRegressor model
random_forest = RandomForestRegressor(random_state=123)

# Initialize RandomizedSearchCV
rf_cv = RandomizedSearchCV(estimator=random_forest,
                           param_distributions=params,
                           n_iter=50,
                           cv=7,
                           scoring="neg_mean_absolute_error",
                           random_state=123,
                           n_jobs=-1)

# Train RandomizedSearchCV
rf_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = rf_cv.best_params_

# Train the model with the best parameters
best_rf = RandomForestRegressor(n_estimators=best_params["n_estimators"],
                                max_depth=best_params["max_depth"],
                                min_samples_split=best_params["min_samples_split"],
                                min_samples_leaf=best_params["min_samples_leaf"],
                                random_state=123)

best_rf.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_rf.predict(X_train_clean)
y_pred_test = best_rf.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_rf_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_rf_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and best parameters
print(f"MAE Train : {mae_train_rf_cv:.4f}")
print(f"MAE Test  : {mae_test_rf_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 16316.3503
# MAE Test  : 24899.8684
# Best Parameters: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 9}

# %% [markdown]
# ## Adaboost

# %%
import numpy as np
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_absolute_error

# Initialize AdaBoostRegressor model with specified parameters
adaboost = AdaBoostRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
adaboost.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = adaboost.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = adaboost.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_ab = mean_absolute_error(y_train, y_pred_train)
mae_test_ab = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_ab:.4f}")
print(f"MAE Test  : {mae_test_ab:.4f}")
# Out:
# MAE Train : 53871.4658
# MAE Test  : 53919.2921

# %%
import numpy as np
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for some key parameters of AdaBoostRegressor
params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0]
}

# Initialize AdaBoostRegressor model
adaboost = AdaBoostRegressor(random_state=123)

# Initialize GridSearchCV
ab_cv = GridSearchCV(estimator=adaboost,
                     param_grid=params,
                     cv=7,
                     scoring="neg_mean_absolute_error")

# Train GridSearchCV
ab_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = ab_cv.best_params_

# Train the model with the best parameters
best_ab = AdaBoostRegressor(n_estimators=best_params["n_estimators"],
                            learning_rate=best_params["learning_rate"],
                            random_state=123)

best_ab.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_ab.predict(X_train_clean)
y_pred_test = best_ab.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_ab_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_ab_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and best parameters
print(f"MAE Train : {mae_train_ab_cv:.4f}")
print(f"MAE Test  : {mae_test_ab_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 32670.8687
# MAE Test  : 34923.2467
# Best Parameters: {'learning_rate': 0.01, 'n_estimators': 50}

# %% [markdown]
# ## Gradient Boosting

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# Initialize the GradientBoostingRegressor model with specified parameters
gradient_boosting = GradientBoostingRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
gradient_boosting.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = gradient_boosting.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = gradient_boosting.predict(X_test_clean)

# Calculate the Mean Absolute Error (MAE) for the training and test data
mae_train_gb = mean_absolute_error(y_train, y_pred_train)
mae_test_gb = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_gb:.4f}")
print(f"MAE Test  : {mae_test_gb:.4f}")
# Out:
# MAE Train : 19528.3350
# MAE Test  : 26726.7747

# %%
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for key parameters of GradientBoostingRegressor
params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0],
    "max_depth": [3, 5, 7, 9]
}

# Initialize the GradientBoostingRegressor model
gradient_boosting = GradientBoostingRegressor(random_state=123)

# Initialize GridSearchCV
gb_cv = GridSearchCV(estimator=gradient_boosting,
                     param_grid=params,
                     cv=7,
                     scoring="neg_mean_absolute_error")

# Train the GridSearchCV
gb_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = gb_cv.best_params_

# Train the model with the best parameters
best_gb = GradientBoostingRegressor(n_estimators=best_params["n_estimators"],
                                    learning_rate=best_params["learning_rate"],
                                    max_depth=best_params["max_depth"],
                                    random_state=123)

best_gb.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_gb.predict(X_train_clean)
y_pred_test = best_gb.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_gb_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_gb_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and the best parameters
print(f"MAE Train : {mae_train_gb_cv:.4f}")
print(f"MAE Test  : {mae_test_gb_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# MAE Train : 268.1772
# MAE Test  : 22208.3549
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 200}

# %% [markdown]
# ## Xgboost

# %%
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error

# Initialize the XGBoost model with specified parameters
xgboost = xgb.XGBRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
xgboost.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = xgboost.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = xgboost.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_xgb = mean_absolute_error(y_train, y_pred_train)
mae_test_xgb = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_xgb:.4f}")
print(f"MAE Test  : {mae_test_xgb:.4f}")
# Out:
# MAE Train : 2035.5690
# MAE Test  : 23190.8952

# %%
import numpy as np
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
from scipy.stats import uniform, randint

# Define distributions for key XGBoost parameters
param_distributions = {
    'n_estimators': randint(50, 300),
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.1),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 0.3),
    'reg_alpha': uniform(0, 0.5),
    'reg_lambda': uniform(1, 2)
}

# Initialize the XGBoost model
xgboost = xgb.XGBRegressor(random_state=123)

# Initialize RandomizedSearchCV
xgb_random_cv = RandomizedSearchCV(estimator=xgboost,
                                   param_distributions=param_distributions,
                                   n_iter=50,
                                   cv=7,
                                   scoring="neg_mean_absolute_error",
                                   random_state=123,
                                   n_jobs=-1,
                                   verbose=2)

# Train the RandomizedSearchCV
xgb_random_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = xgb_random_cv.best_params_

# Train the model with the best parameters
best_xgb = xgb.XGBRegressor(**best_params, random_state=123)
best_xgb.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_xgb.predict(X_train_clean)
y_pred_test = best_xgb.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for training and test data
mae_train_xgb_random_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_xgb_random_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and the best parameters
print(f"MAE Train : {mae_train_xgb_random_cv:.4f}")
print(f"MAE Test  : {mae_test_xgb_random_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# MAE Train : 2571.0931
# MAE Test  : 21845.2108
# Best Parameters: {'colsample_bytree': 0.7637561650372233, 'gamma': 0.11175581731337346, 'learning_rate': 0.04399701713068947, 'max_depth': 9, 'n_estimators': 274, 'reg_alpha': 0.26410276303555574, 'reg_lambda': 2.1076542139879675, 'subsample': 0.6468827351478023}

# %% [markdown]
# ## Lightgbm

# %%
import numpy as np
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error

# Initialize the LightGBM model with specified parameters
lightgbm = lgb.LGBMRegressor(n_estimators=100, random_state=123)

# Train the model on the training data
lightgbm.fit(X_train_clean, y_train)

# Make predictions on the training data
y_pred_train = lightgbm.predict(X_train_clean)

# Make predictions on the test data
y_pred_test = lightgbm.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_lgb = mean_absolute_error(y_train, y_pred_train)
mae_test_lgb = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results
print(f"MAE Train : {mae_train_lgb:.4f}")
print(f"MAE Test  : {mae_test_lgb:.4f}")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 12.0.1. Please consider upgrading.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003240 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4910
# [LightGBM] [Info] Number of data points in the train set: 1475, number of used features: 24
# [LightGBM] [Info] Start training from score 64257.480859
# MAE Train : 10165.3364
# MAE Test  : 23504.0357

# %%
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# Parameter grid for key LightGBM parameters
params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1.0],
    "max_depth": [3, 5, 7, 9]
}

# Initialize the LightGBM model
lightgbm = lgb.LGBMRegressor(random_state=123)

# Initialize GridSearchCV
lgb_cv = GridSearchCV(estimator=lightgbm,
                      param_grid=params,
                      cv=7,
                      scoring="neg_mean_absolute_error")

# Train the GridSearchCV
lgb_cv.fit(X_train_clean, y_train)

# Get the best parameters
best_params = lgb_cv.best_params_

# Train the model with the best parameters
best_lgb = lgb.LGBMRegressor(n_estimators=best_params["n_estimators"],
                             learning_rate=best_params["learning_rate"],
                             max_depth=best_params["max_depth"],
                             random_state=123)

best_lgb.fit(X_train_clean, y_train)

# Make predictions on the training and test data
y_pred_train = best_lgb.predict(X_train_clean)
y_pred_test = best_lgb.predict(X_test_clean)

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_lgb_cv = mean_absolute_error(y_train, y_pred_train)
mae_test_lgb_cv = mean_absolute_error(y_test, y_pred_test)

# Print the MAE results and the best parameters
print(f"MAE Train : {mae_train_lgb_cv:.4f}")
print(f"MAE Test  : {mae_test_lgb_cv:.4f}")
print(f"Best Parameters: {best_params}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4595
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 64391.503855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4606
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 63609.246405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4640
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 64854.881928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4605
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 64586.245673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000413 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4582
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 63997.400122
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4582
# [LightGBM] [Info] Number of data points in the train set: 1265, number of used features: 24
# [LightGBM] [Info] Start training from score 63022.595193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4608
# [LightGBM] [Info] Number of data points in the train set: 1265, number of used features: 24
# [LightGBM] [Info] Start training from score 65340.612898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000316 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4595
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 64391.503855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000269 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4606
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 63609.246405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000300 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4640
# [LightGBM] [Info] Number of data points in the train set: 1264, number of used features: 24
# [LightGBM] [Info] Start training from score 64854.881928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4910
# [LightGBM] [Info] Number of data points in the train set: 1475, number of used features: 24
# [LightGBM] [Info] Start training from score 64257.480859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# MAE Train : 8872.3745
# MAE Test  : 22670.8388
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 200}

# %% [markdown]
# ## Simple Deep Leaning

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.metrics import MeanAbsoluteError as MAE
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(123)
tf.random.set_seed(123)

# Determine input dimension
input_dim = X_train_clean.shape[1]

# Build the model
model = Sequential()
model.add(Dense(128, input_dim=input_dim, activation='relu'))  # First hidden layer
model.add(Dense(64, activation='relu'))  # Second hidden layer
model.add(Dense(32, activation='relu'))  # Third hidden layer
model.add(Dense(1))  # Output layer

# Compile the model with specified learning rate
model.compile(optimizer=Adam(learning_rate=0.001), loss=MeanAbsoluteError(), metrics=[MAE()])

# Train the model with specified number of epochs
history = model.fit(X_train_clean, y_train, epochs=500, batch_size=64, validation_split=0.2, verbose=1)

# Make predictions on the training and test data
y_pred_train = model.predict(X_train_clean)
y_pred_test = model.predict(X_test_clean)

# Flatten the predictions
y_pred_train_flat = y_pred_train.flatten()
y_pred_test_flat = y_pred_test.flatten()

# Calculate Mean Absolute Error (MAE) for the training and test data
mae_train_dl = np.mean(np.abs(y_train - y_pred_train_flat))
mae_test_dl = np.mean(np.abs(y_test - y_pred_test_flat))

# Print the MAE results
print(f"MAE Train : {mae_train_dl:.4f}")
print(f"MAE Test  : {mae_test_dl:.4f}")

# Visualize model performance over epochs
# Plot loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot MAE
plt.subplot(1, 2, 2)
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title('Model MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

plt.show()
# Out:
# Epoch 1/500
# 19/19 [==============================] - 2s 17ms/step - loss: 66141.6172 - mean_absolute_error: 66141.6172 - val_loss: 56636.3945 - val_mean_absolute_error: 56636.3945
# Epoch 2/500
# 19/19 [==============================] - 0s 5ms/step - loss: 66069.3438 - mean_absolute_error: 66069.3438 - val_loss: 56578.7812 - val_mean_absolute_error: 56578.7812
# Epoch 3/500
# 19/19 [==============================] - 0s 4ms/step - loss: 65987.2656 - mean_absolute_error: 65987.2656 - val_loss: 56508.9141 - val_mean_absolute_error: 56508.9141
# Epoch 4/500
# 19/19 [==============================] - 0s 5ms/step - loss: 65926.6562 - mean_absolute_error: 65926.6562 - val_loss: 56466.3555 - val_mean_absolute_error: 56466.3555
# Epoch 5/500
# 19/19 [==============================] - 0s 6ms/step - loss: 65842.3359 - mean_absolute_error: 65842.3359 - val_loss: 56370.8555 - val_mean_absolute_error: 56370.8555
# Epoch 6/500
# 19/19 [==============================] - 0s 7ms/step - loss: 65683.2578 - mean_absolute_error: 65683.2578 - val_loss: 56202.2656 - val_mean_absolute_error: 56202.2656
500
# 19/19 [==============================] - 0s 5ms/step - loss: 30983.7754 - mean_absolute_error: 30983.7754 - val_loss: 31594.0586 - val_mean_absolute_error: 31594.0586
# Epoch 127/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30971.4551 - mean_absolute_error: 30971.4551 - val_loss: 31589.6875 - val_mean_absolute_error: 31589.6875
# Epoch 128/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30954.0039 - mean_absolute_error: 30954.0039 - val_loss: 31447.4277 - val_mean_absolute_error: 31447.4277
# Epoch 129/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30981.4980 - mean_absolute_error: 30981.4980 - val_loss: 31719.8516 - val_mean_absolute_error: 31719.8516
# Epoch 130/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30873.5488 - mean_absolute_error: 30873.5488 - val_loss: 31555.1895 - val_mean_absolute_error: 31555.1895
# Epoch 131/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30866.5703 - mean_absolute_error: 30866.5703 - val_loss: 31510.5391 - val_mean_absolute_error: 31510.5391
# Epoch 132/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30816.2305 - mean_absolute_error: 30816.2305 - val_loss: 31488.4570 - val_mean_absolute_error: 31488.4570
# Epoch 133/500
# 19/19 [==============================] - 0s 8ms/step - loss: 31067.2812 - mean_absolute_error: 31067.2812 - val_loss: 31565.6914 - val_mean_absolute_error: 31565.6914
# Epoch 134/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30841.9121 - mean_absolute_error: 30841.9121 - val_loss: 31653.4160 - val_mean_absolute_error: 31653.4160
# Epoch 135/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30867.6816 - mean_absolute_error: 30867.6816 - val_loss: 31697.4570 - val_mean_absolute_error: 31697.4570
# Epoch 136/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30815.4980 - mean_absolute_error: 30815.4980 - val_loss: 31513.1113 - val_mean_absolute_error: 31513.1113
# Epoch 137/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30759.6953 - mean_absolute_error: 30759.6953 - val_loss: 31521.0820 - val_mean_absolute_error: 31521.0820
# Epoch 138/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30857.3145 - mean_absolute_error: 30857.3145 - val_loss: 31556.1992 - val_mean_absolute_error: 31556.1992
# Epoch 139/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30760.8477 - mean_absolute_error: 30760.8477 - val_loss: 31508.0508 - val_mean_absolute_error: 31508.0508
# Epoch 140/500
# 19/19 [==============================] - 0s 3ms/step - loss: 30726.8887 - mean_absolute_error: 30726.8887 - val_loss: 31447.2539 - val_mean_absolute_error: 31447.2539
# Epoch 141/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30684.2344 - mean_absolute_error: 30684.2344 - val_loss: 31381.7598 - val_mean_absolute_error: 31381.7598
# Epoch 142/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30721.7363 - mean_absolute_error: 30721.7363 - val_loss: 31448.4883 - val_mean_absolute_error: 31448.4883
# Epoch 143/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30708.7148 - mean_absolute_error: 30708.7148 - val_loss: 31456.2637 - val_mean_absolute_error: 31456.2637
# Epoch 144/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30695.9531 - mean_absolute_error: 30695.9531 - val_loss: 31268.2715 - val_mean_absolute_error: 31268.2715
# Epoch 145/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30702.8438 - mean_absolute_error: 30702.8438 - val_loss: 31459.8203 - val_mean_absolute_error: 31459.8203
# Epoch 146/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30610.1348 - mean_absolute_error: 30610.1348 - val_loss: 31379.5117 - val_mean_absolute_error: 31379.5117
# Epoch 147/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30638.6230 - mean_absolute_error: 30638.6230 - val_loss: 31323.1289 - val_mean_absolute_error: 31323.1289
# Epoch 148/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30533.4844 - mean_absolute_error: 30533.4844 - val_loss: 31336.7363 - val_mean_absolute_error: 31336.7363
# Epoch 149/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30534.3145 - mean_absolute_error: 30534.3145 - val_loss: 31202.2773 - val_mean_absolute_error: 31202.2773
# Epoch 150/500
# 19/19 [==============================] - 0s 8ms/step - loss: 30531.6309 - mean_absolute_error: 30531.6309 - val_loss: 31242.1289 - val_mean_absolute_error: 31242.1289
# Epoch 151/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30497.6777 - mean_absolute_error: 30497.6777 - val_loss: 31278.7051 - val_mean_absolute_error: 31278.7051
# Epoch 152/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30524.0508 - mean_absolute_error: 30524.0508 - val_loss: 31194.1113 - val_mean_absolute_error: 31194.1113
# Epoch 153/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30531.8438 - mean_absolute_error: 30531.8438 - val_loss: 31410.7871 - val_mean_absolute_error: 31410.7871
# Epoch 154/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30456.5449 - mean_absolute_error: 30456.5449 - val_loss: 31183.3359 - val_mean_absolute_error: 31183.3359
# Epoch 155/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30445.4160 - mean_absolute_error: 30445.4160 - val_loss: 31303.2617 - val_mean_absolute_error: 31303.2617
# Epoch 156/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30458.5293 - mean_absolute_error: 30458.5293 - val_loss: 31230.8613 - val_mean_absolute_error: 31230.8613
# Epoch 157/500
# 19/19 [==============================] - 0s 7ms/step - loss: 30461.2891 - mean_absolute_error: 30461.2891 - val_loss: 31315.3867 - val_mean_absolute_error: 31315.3867
# Epoch 158/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30417.4844 - mean_absolute_error: 30417.4844 - val_loss: 31175.2207 - val_mean_absolute_error: 31175.2207
# Epoch 159/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30841.8789 - mean_absolute_error: 30841.8789 - val_loss: 31095.5527 - val_mean_absolute_error: 31095.5527
# Epoch 160/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30459.5117 - mean_absolute_error: 30459.5117 - val_loss: 31499.2715 - val_mean_absolute_error: 31499.2715
# Epoch 161/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30485.7520 - mean_absolute_error: 30485.7520 - val_loss: 31333.3398 - val_mean_absolute_error: 31333.3398
# Epoch 162/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30378.9355 - mean_absolute_error: 30378.9355 - val_loss: 31289.5625 - val_mean_absolute_error: 31289.5625
# Epoch 163/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30386.6914 - mean_absolute_error: 30386.6914 - val_loss: 31309.9629 - val_mean_absolute_error: 31309.9629
# Epoch 164/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30348.9629 - mean_absolute_error: 30348.9629 - val_loss: 31267.9297 - val_mean_absolute_error: 31267.9297
# Epoch 165/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30323.7871 - mean_absolute_error: 30323.7871 - val_loss: 31169.8652 - val_mean_absolute_error: 31169.8652
# Epoch 166/500
# 19/19 [==============================] - 0s 6ms/step - loss: 
# Epoch 188/500
# 19/19 [==============================] - 0s 4ms/step - loss: 30053.1738 - mean_absolute_error: 30053.1738 - val_loss: 30952.8750 - val_mean_absolute_error: 30952.8750
# Epoch 189/500
# 19/19 [==============================] - 0s 4ms/step - loss: 29927.1191 - mean_absolute_error: 29927.1191 - val_loss: 30921.4922 - val_mean_absolute_error: 30921.4922
# Epoch 190/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29940.8848 - mean_absolute_error: 29940.8848 - val_loss: 30919.1934 - val_mean_absolute_error: 30919.1934
# Epoch 191/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30040.8203 - mean_absolute_error: 30040.8203 - val_loss: 31002.8652 - val_mean_absolute_error: 31002.8652
# Epoch 192/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29942.3281 - mean_absolute_error: 29942.3281 - val_loss: 30860.3867 - val_mean_absolute_error: 30860.3867
# Epoch 193/500
# 19/19 [==============================] - 0s 5ms/step - loss: 30037.2305 - mean_absolute_error: 30037.2305 - val_loss: 30722.3223 - val_mean_absolute_error: 30722.3223
# Epoch 194/500
# 19/19 [==============================] - 0s 6ms/step - loss: 30011.6738 - mean_absolute_error: 30011.6738 - val_loss: 31006.7559 - val_mean_absolute_error: 31006.7559
# Epoch 195/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29901.9453 - mean_absolute_error: 29901.9453 - val_loss: 30972.3594 - val_mean_absolute_error: 30972.3594
# Epoch 196/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29902.9629 - mean_absolute_error: 29902.9629 - val_loss: 30745.4512 - val_mean_absolute_error: 30745.4512
# Epoch 197/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29908.0586 - mean_absolute_error: 29908.0586 - val_loss: 30795.7422 - val_mean_absolute_error: 30795.7422
# Epoch 198/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29868.1250 - mean_absolute_error: 29868.1250 - val_loss: 30726.4805 - val_mean_absolute_error: 30726.4805
# Epoch 199/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29925.1562 - mean_absolute_error: 29925.1562 - val_loss: 30690.9121 - val_mean_absolute_error: 30690.9121
# Epoch 200/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29839.9766 - mean_absolute_error: 29839.9766 - val_loss: 30800.5625 - val_mean_absolute_error: 30800.5625
# Epoch 201/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29821.3320 - mean_absolute_error: 29821.3320 - val_loss: 30875.5938 - val_mean_absolute_error: 30875.5938
# Epoch 202/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29865.7559 - mean_absolute_error: 29865.7559 - val_loss: 30870.2617 - val_mean_absolute_error: 30870.2617
# Epoch 203/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29793.0410 - mean_absolute_error: 29793.0410 - val_loss: 30746.4688 - val_mean_absolute_error: 30746.4688
# Epoch 204/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29937.6953 - mean_absolute_error: 29937.6953 - val_loss: 30513.1699 - val_mean_absolute_error: 30513.1699
# Epoch 205/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29870.7793 - mean_absolute_error: 29870.7793 - val_loss: 30754.3145 - val_mean_absolute_error: 30754.3145
# Epoch 206/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29814.0176 - mean_absolute_error: 29814.0176 - val_loss: 30946.7090 - val_mean_absolute_error: 30946.7090
# Epoch 207/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29790.6230 - mean_absolute_error: 29790.6230 - val_loss: 30804.5801 - val_mean_absolute_error: 30804.5801
# Epoch 208/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29760.6992 - mean_absolute_error: 29760.6992 - val_loss: 30858.4473 - val_mean_absolute_error: 30858.4473
# Epoch 209/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29732.5898 - mean_absolute_error: 29732.5898 - val_loss: 30796.7891 - val_mean_absolute_error: 30796.7891
# Epoch 210/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29759.0371 - mean_absolute_error: 29759.0371 - val_loss: 30997.5566 - val_mean_absolute_error: 30997.5566
# Epoch 211/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29801.9668 - mean_absolute_error: 29801.9668 - val_loss: 30738.6504 - val_mean_absolute_error: 30738.6504
# Epoch 212/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29690.5488 - mean_absolute_error: 29690.5488 - val_loss: 30785.4375 - val_mean_absolute_error: 30785.4375
# Epoch 213/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29698.1484 - mean_absolute_error: 29698.1484 - val_loss: 30799.4570 - val_mean_absolute_error: 30799.4570
# Epoch 214/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29715.0371 - mean_absolute_error: 29715.0371 - val_loss: 30659.2109 - val_mean_absolute_error: 30659.2109
# Epoch 215/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29797.1660 - mean_absolute_error: 29797.1660 - val_loss: 30638.1387 - val_mean_absolute_error: 30638.1387
# Epoch 216/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29811.0312 - mean_absolute_error: 29811.0312 - val_loss: 30652.3008 - val_mean_absolute_error: 30652.3008
# Epoch 217/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29756.3965 - mean_absolute_error: 29756.3965 - val_loss: 30675.9121 - val_mean_absolute_error: 30675.9121
# Epoch 218/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29643.5801 - mean_absolute_error: 29643.5801 - val_loss: 30722.4980 - val_mean_absolute_error: 30722.4980
# Epoch 219/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29603.0000 - mean_absolute_error: 29603.0000 - val_loss: 30665.4199 - val_mean_absolute_error: 30665.4199
# Epoch 220/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29545.8711 - mean_absolute_error: 29545.8711 - val_loss: 30559.7871 - val_mean_absolute_error: 30559.7871
# Epoch 221/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29599.0645 - mean_absolute_error: 29599.0645 - val_loss: 30458.9863 - val_mean_absolute_error: 30458.9863
# Epoch 222/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29627.5020 - mean_absolute_error: 29627.5020 - val_loss: 30699.1660 - val_mean_absolute_error: 30699.1660
# Epoch 223/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29647.4570 - mean_absolute_error: 29647.4570 - val_loss: 30682.1094 - val_mean_absolute_error: 30682.1094
# Epoch 224/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29551.2852 - mean_absolute_error: 29551.2852 - val_loss: 30767.0273 - val_mean_absolute_error: 30767.0273
# Epoch 225/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29542.9395 - mean_absolute_error: 29542.9395 - val_loss: 30716.5723 - val_mean_absolute_error: 30716.5723
# Epoch 226/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29571.4688 - mean_absolute_error: 29571.4688 - val_loss: 30514.2363 - val_mean_absolute_error: 30514.2363
# Epoch 227/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29600.7383 - mean_absolute_error: 29600.7383 - val_loss: 30398.7148 - val_mean_absolute_error: 30398.7148
# Epoch 228/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29602.0137 - mean_absolute_error: 29602.0137 - val_loss: 30667.1621 - val_mean_absolute_error: 30667.1621
# Epoch 229/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29564.7637 - mean_absolute_error: 29564.7637 - val_loss: 30515.1523 - val_mean_absolute_error: 30515.1523
# Epoch 230/500
# 19/19 [==============================] - 0s 4ms/step - loss: 29474.6270 - mean_absolute_error: 29474.6270 - val_loss: 30649.4004 - val_mean_absolute_error: 30649.4004
# Epoch 231/500
# 19/19 [==============================] - 0s 4ms/step - loss: 29494.9453 - mean_absolute_error: 29494.9453 - val_loss: 30426.8398 - val_mean_absolute_error: 30426.8398
# Epoch 232/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29498.9805 - mean_absolute_error: 29498.9805 - val_loss: 30537.7656 - val_mean_absolute_error: 30537.7656
# Epoch 233/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29441.3828 - mean_absolute_error: 29441.3828 - val_loss: 30464.5898 - val_mean_absolute_error: 30464.5898
# Epoch 234/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29461.1094 - mean_absolute_error: 29461.1094 - val_loss: 30472.8945 - val_mean_absolute_error: 30472.8945
# Epoch 235/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29428.6855 - mean_absolute_error: 29428.6855 - val_loss: 30483.5566 - val_mean_absolute_error: 30483.5566
# Epoch 236/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29486.3359 - mean_absolute_error: 29486.3359 - val_loss: 30389.3008 - val_mean_absolute_error: 30389.3008
# Epoch 237/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29395.8105 - mean_absolute_error: 29395.8105 - val_loss: 30414.9043 - val_mean_absolute_error: 30414.9043
# Epoch 238/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29391.3594 - mean_absolute_error: 29391.3594 - val_loss: 30354.2812 - val_mean_absolute_error: 30354.2812
# Epoch 239/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29372.6953 - mean_absolute_error: 29372.6953 - val_loss: 30539.2441 - val_mean_absolute_error: 30539.2441
# Epoch 240/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29321.4473 - mean_absolute_error: 29321.4473 - val_loss: 30174.1855 - val_mean_absolute_error: 30174.1855
# Epoch 241/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29456.6855 - mean_absolute_error: 29456.6855 - val_loss: 30350.8203 - val_mean_absolute_error: 30350.8203
# Epoch 242/500
# 19/19 [==============================] - 0s 7ms/step - loss: 29363.1250 - mean_absolute_error: 29363.1250 - val_loss: 30379.5156 - val_mean_absolute_error: 30379.5156
# Epoch 243/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29354.0703 - mean_absolute_error: 29354.0703 - val_loss: 30383.6680 - val_mean_absolute_error: 30383.6680
# Epoch 244/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29335.0332 - mean_absolute_error: 29335.0332 - val_loss: 30349.3867 - val_mean_absolute_error: 30349.3867
# Epoch 245/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29307.3359 - mean_absolute_error: 29307.3359 - val_loss: 30339.3398 - val_mean_absolute_error: 30339.3398
# Epoch 246/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29330.0586 - mean_absolute_error: 29330.0586 - val_loss: 30434.5020 - val_mean_absolute_error: 30434.5020
# Epoch 247/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29292.6738 - mean_absolute_error: 29292.6738 - val_loss: 30298.1621 - val_mean_absolute_error: 30298.1621
# Epoch 248/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29287.8574 - mean_absolute_error: 29287.8574 - val_loss: 30174.4551 - val_mean_absolute_error: 30174.4551
# Epoch 249/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29328.0605 - mean_absolute_error: 29328.0605 - val_loss: 30192.7832 - val_mean_absolute_error: 30192.7832
# Epoch 250/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29303.0703 - mean_absolute_error: 29303.0703 - val_loss: 30423.9258 - val_mean_absolute_error: 30423.9258
# Epoch 251/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29271.5156 - mean_absolute_error: 29271.5156 - val_loss: 30149.8203 - val_mean_absolute_error: 30149.8203
# Epoch 252/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29309.9453 - mean_absolute_error: 29309.9453 - val_loss: 30235.5078 - val_mean_absolute_error: 30235.5078
# Epoch 253/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29259.7422 - mean_absolute_error: 29259.7422 - val_loss: 30218.2031 - val_mean_absolute_error: 30218.2031
# Epoch 254/500
# 19/19 [==============================] - 0s 6ms/step - loss: 29218.2754 - mean_absolute_error: 29218.2754 - val_loss: 30187.9160 - val_mean_absolute_error: 30187.9160
# Epoch 255/500
# 19/19 [==============================] - 0s 5ms/step - loss: 29216.0332 - mean_absolute_error: 29216.0332 - val_loss: 30158.5801 - val_mean_absolute_error: 30158.5801
# Epoch 256/500
# 19/19 [==============================] - 0s 5ms/step - loss: 
500
# 19/19 [==============================] - 0s 6ms/step - loss: 26792.9219 - mean_absolute_error: 26792.9219 - val_loss: 28220.8613 - val_mean_absolute_error: 28220.8613
# Epoch 444/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26769.0371 - mean_absolute_error: 26769.0371 - val_loss: 28365.7109 - val_mean_absolute_error: 28365.7109
# Epoch 445/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26748.7871 - mean_absolute_error: 26748.7871 - val_loss: 28214.5117 - val_mean_absolute_error: 28214.5117
# Epoch 446/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26760.6035 - mean_absolute_error: 26760.6035 - val_loss: 28087.7129 - val_mean_absolute_error: 28087.7129
# Epoch 447/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26723.3184 - mean_absolute_error: 26723.3184 - val_loss: 28044.4629 - val_mean_absolute_error: 28044.4629
# Epoch 448/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26670.3828 - mean_absolute_error: 26670.3828 - val_loss: 28161.2559 - val_mean_absolute_error: 28161.2559
# Epoch 449/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26762.8750 - mean_absolute_error: 26762.8750 - val_loss: 28038.5195 - val_mean_absolute_error: 28038.5195
# Epoch 450/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26669.2051 - mean_absolute_error: 26669.2051 - val_loss: 28177.9961 - val_mean_absolute_error: 28177.9961
# Epoch 451/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26709.5605 - mean_absolute_error: 26709.5605 - val_loss: 28032.0742 - val_mean_absolute_error: 28032.0742
# Epoch 452/500
# 19/19 [==============================] - 0s 8ms/step - loss: 26758.7266 - mean_absolute_error: 26758.7266 - val_loss: 28077.0977 - val_mean_absolute_error: 28077.0977
# Epoch 453/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26594.9961 - mean_absolute_error: 26594.9961 - val_loss: 28039.8438 - val_mean_absolute_error: 28039.8438
# Epoch 454/500
# 19/19 [==============================] - 0s 8ms/step - loss: 26620.2227 - mean_absolute_error: 26620.2227 - val_loss: 28009.4199 - val_mean_absolute_error: 28009.4199
# Epoch 455/500
# 19/19 [==============================] - 0s 8ms/step - loss: 26612.7734 - mean_absolute_error: 26612.7734 - val_loss: 28064.5801 - val_mean_absolute_error: 28064.5801
# Epoch 456/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26553.0840 - mean_absolute_error: 26553.0840 - val_loss: 28196.0020 - val_mean_absolute_error: 28196.0020
# Epoch 457/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26573.3789 - mean_absolute_error: 26573.3789 - val_loss: 28082.1309 - val_mean_absolute_error: 28082.1309
# Epoch 458/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26487.5488 - mean_absolute_error: 26487.5488 - val_loss: 28116.4180 - val_mean_absolute_error: 28116.4180
# Epoch 459/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26569.9453 - mean_absolute_error: 26569.9453 - val_loss: 28046.6191 - val_mean_absolute_error: 28046.6191
# Epoch 460/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26556.2051 - mean_absolute_error: 26556.2051 - val_loss: 28005.6797 - val_mean_absolute_error: 28005.6797
# Epoch 461/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26433.6621 - mean_absolute_error: 26433.6621 - val_loss: 28026.6992 - val_mean_absolute_error: 28026.6992
# Epoch 462/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26494.1602 - mean_absolute_error: 26494.1602 - val_loss: 27960.3145 - val_mean_absolute_error: 27960.3145
# Epoch 463/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26451.3594 - mean_absolute_error: 26451.3594 - val_loss: 28168.9102 - val_mean_absolute_error: 28168.9082
# Epoch 464/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26544.4688 - mean_absolute_error: 26544.4688 - val_loss: 27842.5312 - val_mean_absolute_error: 27842.5312
# Epoch 465/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26563.0039 - mean_absolute_error: 26563.0039 - val_loss: 27943.8789 - val_mean_absolute_error: 27943.8789
# Epoch 466/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26437.2539 - mean_absolute_error: 26437.2539 - val_loss: 27900.6816 - val_mean_absolute_error: 27900.6816
# Epoch 467/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26401.1543 - mean_absolute_error: 26401.1543 - val_loss: 27952.6309 - val_mean_absolute_error: 27952.6309
# Epoch 468/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26481.8164 - mean_absolute_error: 26481.8164 - val_loss: 27852.4414 - val_mean_absolute_error: 27852.4414
# Epoch 469/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26483.1113 - mean_absolute_error: 26483.1113 - val_loss: 28034.1602 - val_mean_absolute_error: 28034.1602
# Epoch 470/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26405.4707 - mean_absolute_error: 26405.4707 - val_loss: 27543.1250 - val_mean_absolute_error: 27543.1250
# Epoch 471/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26488.2695 - mean_absolute_error: 26488.2695 - val_loss: 27730.1895 - val_mean_absolute_error: 27730.1895
# Epoch 472/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26340.2812 - mean_absolute_error: 26340.2812 - val_loss: 27868.5273 - val_mean_absolute_error: 27868.5273
# Epoch 473/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26375.7969 - mean_absolute_error: 26375.7969 - val_loss: 27923.9219 - val_mean_absolute_error: 27923.9219
# Epoch 474/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26433.7559 - mean_absolute_error: 26433.7559 - val_loss: 28081.3633 - val_mean_absolute_error: 28081.3633
# Epoch 475/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26463.8965 - mean_absolute_error: 26463.8965 - val_loss: 27877.9023 - val_mean_absolute_error: 27877.9023
# Epoch 476/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26414.7051 - mean_absolute_error: 26414.7051 - val_loss: 28068.8145 - val_mean_absolute_error: 28068.8145
# Epoch 477/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26377.0703 - mean_absolute_error: 26377.0703 - val_loss: 27672.1719 - val_mean_absolute_error: 27672.1719
# Epoch 478/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26318.9863 - mean_absolute_error: 26318.9863 - val_loss: 27649.9863 - val_mean_absolute_error: 27649.9863
# Epoch 479/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26291.7754 - mean_absolute_error: 26291.7754 - val_loss: 27865.3906 - val_mean_absolute_error: 27865.3906
# Epoch 480/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26214.6934 - mean_absolute_error: 26214.6934 - val_loss: 27807.2383 - val_mean_absolute_error: 27807.2383
# Epoch 481/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26301.5703 - mean_absolute_error: 26301.5703 - val_loss: 27819.8008 - val_mean_absolute_error: 27819.8008
# Epoch 482/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26238.7324 - mean_absolute_error: 26238.7324 - val_loss: 27680.8789 - val_mean_absolute_error: 27680.8789
# Epoch 483/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26210.8145 - mean_absolute_error: 26210.8145 - val_loss: 27912.6094 - val_mean_absolute_error: 27912.6094
# Epoch 484/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26165.5645 - mean_absolute_error: 26165.5645 - val_loss: 28077.6855 - val_mean_absolute_error: 28077.6855
# Epoch 485/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26057.6465 - mean_absolute_error: 26057.6465 - val_loss: 27684.5938 - val_mean_absolute_error: 27684.5938
# Epoch 486/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26195.4805 - mean_absolute_error: 26195.4805 - val_loss: 27905.8555 - val_mean_absolute_error: 27905.8555
# Epoch 487/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26136.1973 - mean_absolute_error: 26136.1973 - val_loss: 27758.9492 - val_mean_absolute_error: 27758.9492
# Epoch 488/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26113.1582 - mean_absolute_error: 26113.1582 - val_loss: 27746.9004 - val_mean_absolute_error: 27746.9004
# Epoch 489/500
# 19/19 [==============================] - 0s 5ms/step - loss: 26047.7559 - mean_absolute_error: 26047.7559 - val_loss: 27705.1602 - val_mean_absolute_error: 27705.1602
# Epoch 490/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26313.5957 - mean_absolute_error: 26313.5957 - val_loss: 27959.4746 - val_mean_absolute_error: 27959.4746
# Epoch 491/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26107.2324 - mean_absolute_error: 26107.2324 - val_loss: 27790.1328 - val_mean_absolute_error: 27790.1328
# Epoch 492/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26020.9980 - mean_absolute_error: 26020.9980 - val_loss: 27668.1699 - val_mean_absolute_error: 27668.1699
# Epoch 493/500
# 19/19 [==============================] - 0s 7ms/step - loss: 25974.2480 - mean_absolute_error: 25974.2480 - val_loss: 27760.2090 - val_mean_absolute_error: 27760.2090
# Epoch 494/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26098.3652 - mean_absolute_error: 26098.3652 - val_loss: 27633.2500 - val_mean_absolute_error: 27633.2500
# Epoch 495/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25976.8672 - mean_absolute_error: 25976.8672 - val_loss: 27904.4316 - val_mean_absolute_error: 27904.4316
# Epoch 496/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26144.0762 - mean_absolute_error: 26144.0762 - val_loss: 27699.3242 - val_mean_absolute_error: 27699.3242
# Epoch 497/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26072.4766 - mean_absolute_error: 26072.4766 - val_loss: 27659.4434 - val_mean_absolute_error: 27659.4434
# Epoch 498/500
# 19/19 [==============================] - 0s 7ms/step - loss: 26175.8008 - mean_absolute_error: 26175.8008 - val_loss: 27746.5039 - val_mean_absolute_error: 27746.5039
# Epoch 499/500
# 19/19 [==============================] - 0s 6ms/step - loss: 26013.9805 - mean_absolute_error: 26013.9805 - val_loss: 27666.3145 - val_mean_absolute_error: 27666.3145
# Epoch 500/500
# 19/19 [==============================] - 0s 6ms/step - loss: 25951.1348 - mean_absolute_error: 25951.1348 - val_loss: 27686.7559 - val_mean_absolute_error: 27686.7559
# 47/47 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step
# MAE Train : 26202.1507
# MAE Test  : 31769.1514

# %%
# Define MAE values for training and test sets from the models created
mae_train = [
    mae_train_baseline, mae_train_lg, mae_train_dt, mae_train_dt_cv, 
    mae_train_rf, mae_train_rf_cv, mae_train_ab, mae_train_ab_cv, 
    mae_train_gb, mae_train_gb_cv, mae_train_xgb, mae_train_xgb_random_cv, 
    mae_train_lgb, mae_train_lgb_cv, mae_train_dl
]

mae_test = [
    mae_test_baseline, mae_test_lg, mae_test_dt, mae_test_dt_cv, 
    mae_test_rf, mae_test_rf_cv, mae_test_ab, mae_test_ab_cv, 
    mae_test_gb, mae_test_gb_cv, mae_test_xgb, mae_test_xgb_random_cv, 
    mae_test_lgb, mae_test_lgb_cv, mae_test_dl
]

# Define indexes for the summary DataFrame
indexes = [
    'baseline', 'linear regression', 'Decision Tree', 'Decision Tree CV', 
    'Random Forest', 'Random Forest CV', 'AdaBoost', 'AdaBoost CV', 
    'Gradient Boosting', 'Gradient Boosting CV', 'XGBoost', 'XGBoost CV', 
    'LightGBM', 'LightGBM CV', 'Simple Neural Network'
]

# Create a summary DataFrame with MAE values for training and test sets
summary_df = pd.DataFrame({
    "MAE Train": mae_train,
    "MAE Test": mae_test
}, index=indexes)

# Display the summary DataFrame
summary_df
# Out:
#                           MAE Train      MAE Test
# baseline               49524.902580  49931.371973
# linear regression      35286.729549  38370.307635
# Decision Tree          12369.372592  27353.953676
# Decision Tree CV       18653.667184  27307.218983
# Random Forest          14638.648410  24707.175065
# Random Forest CV       16316.350336  24899.868355
# AdaBoost               53871.465772  53919.292141
# AdaBoost CV            32670.868710  34923.246705
# Gradient Boosting      19528.334966  26726.774690
# Gradient Boosting CV     268.177188  22208.354852
# XGBoost                 2035.569049  23190.895197
# XGBoost CV              2571.093054  21845.210827
# LightGBM               10165.336381  23504.035703
# LightGBM CV             8872.374512  22670.838786
# Simple Neural Network  26202.150661  31769.151392

# %%
# Sorted by MAE Test (Ascending)
summary_df.sort_values(by='MAE Test')
# Out:
#                           MAE Train      MAE Test
# XGBoost CV              2571.093054  21845.210827
# Gradient Boosting CV     268.177188  22208.354852
# LightGBM CV             8872.374512  22670.838786
# XGBoost                 2035.569049  23190.895197
# LightGBM               10165.336381  23504.035703
# Random Forest          14638.648410  24707.175065
# Random Forest CV       16316.350336  24899.868355
# Gradient Boosting      19528.334966  26726.774690
# Decision Tree CV       18653.667184  27307.218983
# Decision Tree          12369.372592  27353.953676
# Simple Neural Network  26202.150661  31769.151392
# AdaBoost CV            32670.868710  34923.246705
# linear regression      35286.729549  38370.307635
# baseline               49524.902580  49931.371973
# AdaBoost               53871.465772  53919.292141

# %% [markdown]
# ## Error Analysis

# %%
y_pred_test_best_xgb = best_xgb.predict(X_test_clean)

# %%
#Scatter plot data faktual dan data prediksi
plt.scatter(y_test, y_pred_test_best_xgb)
plt.plot([0, 1000000], [0,1000000], "--r")

plt.xlabel("Biomass Actual")
plt.ylabel("Biomass Prediction")
plt.xlim(0, 1000000)
plt.ylim(0, 1000000)
#plt.savefig("predict.png")
plt.show()

# %% [markdown]
# ## Save Best Model

# %%
import pickle

# Define the file path where the model will be saved
best_xgb_cv = 'model/best_model_xgb_biomass.pkl'

# Open the file in write-binary mode and save the best XGBoost model
with open(best_xgb_cv, 'wb') as file:
    pickle.dump(best_xgb, file)

# %% [markdown]
# ## Load Model

# %%
import pickle

# Load the XGBoost model from the file
with open("model/best_model_xgb_biomass.pkl", "rb") as file:
    loaded_model = pickle.load(file)

# Use the loaded model to make predictions on the test data
y_pred_loaded_model = loaded_model.predict(X_test_clean)
